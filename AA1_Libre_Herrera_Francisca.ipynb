# %% [markdown]
# #Trabajo Práctico para condición de Libre: Predicción de lluvia en Australia

# %% [markdown]
# ### 1. Introducción y objetivos

# %% [markdown]
# Durante el trabajo se utilizará un dataset llamado weatherAUS.csv que contiene información climática de Australia de los últimos diez años, incluyendo si para el día siguiente llovió o no y la cantidad de lluvia, en las columnas ‘RainTomorrow’ y ‘RainfallTomorrow’ respectivamente.
#
# El objetivo es la predicción de estas dos variables en función del resto de las características que se consideren adecuadas.
#
# Para ello nos valdremos de la biblioteca scikit-learn y las herramientas que brinda para el pre-procesamiento de datos, la implementación de modelos y la evaluación de métricas, con TensorFlow para el entrenamiento de redes neuronales y con Docker para la puesta en producción del modelo seleccionado como el más adecuado, entre otras.
#
# El dataset contiene información sobre distintas ciudades, las cuales se encuentran en la columna ‘Location’. Solamente se utilizarán para las predicciones las siguientes: Albury, Sydney, SydneyAirport, Canberra, Melbourne y MelbourneAirport.

# %% [markdown]
# ### 2. Dependencias utilizadas

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.14.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from geopy.distance import geodesic
import folium
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Evaluación de modelos
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer, r2_score
from sklearn.metrics import f1_score, recall_score
from sklearn.metrics import roc_curve

# Regresión
from sklearn.linear_model import LinearRegression
from joblib import Parallel, delayed # ejecutación de código en paralelo
from tqdm import tqdm # barra de progreso
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV

# Clasificación
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import roc_curve, roc_auc_score

# Redes Neuronales
import random
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2
from keras.losses import MeanSquaredError, BinaryCrossentropy
from keras.metrics import MeanSquaredError as MSE
import optuna

#Explicabilidad
import shap

# %%
semilla = 37

# %% [markdown]
# ### 3. Preprocesamiento de datos (df_train)

# %% [markdown]
# #### Carga de datos

# %%
# Carga del csv
file_path= 'weatherAUS.csv'
df = pd.read_csv(file_path, sep=',',engine='python')
df.head()
# Out:
#    Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0           0  2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1           1  2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2           2  2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3           3  2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4           4  2008-12-05   Albury     17.5     32.3       1.0          NaN
#
#    Sunshine WindGustDir  WindGustSpeed  ... Humidity3pm Pressure9am  \
# 0       NaN           W           44.0  ...        22.0      1007.7
# 1       NaN         WNW           44.0  ...        25.0      1010.6
# 2       NaN         WSW           46.0  ...        30.0      1007.6
# 3       NaN          NE           24.0  ...        16.0      1017.6
# 4       NaN           W           41.0  ...        33.0      1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0       1007.1       8.0       NaN     16.9     21.8         No            No
# 1       1007.8       NaN       NaN     17.2     24.3         No            No
# 2       1008.7       NaN       2.0     21.0     23.2         No            No
# 3       1012.8       NaN       NaN     18.1     26.5         No            No
# 4       1006.0       7.0       8.0     17.8     29.7         No            No
#
#    RainfallTomorrow
# 0               0.0
# 1               0.0
# 2               0.0
# 3               1.0
# 4               0.2
#
# [5 rows x 25 columns]

# %%
# Se elimina la primera columna con el índice
df = df.drop('Unnamed: 0', axis=1)

# %%
# Se genera un dataframe reducido que contiene las ciudades de interés (df), pero se conserva el df original (ahora df_full).
df_full = df.copy()

# Lista de ubicaciones admitidas
locations = ['Albury', 'Sydney', 'SydneyAirport', 'Canberra', 'Melbourne', 'MelbourneAirport']

# Filtrar el dataframe para mantener solo las ubicaciones admitidas
df = df[df['Location'].isin(locations)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19025 entries, 0 to 70370
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              19025 non-null  object
#  1   Location          19025 non-null  object
#  2   MinTemp           18523 non-null  float64
#  3   MaxTemp           18528 non-null  float64
#  4   Rainfall          18209 non-null  float64
#  5   Evaporation       14280 non-null  float64
#  6   Sunshine          14038 non-null  float64
#  7   WindGustDir       17536 non-null  object
#  8   WindGustSpeed     17538 non-null  float64
#  9   WindDir9am        17805 non-null  object
#  10  WindDir3pm        18690 non-null  object
#  11  WindSpeed9am      18755 non-null  float64
#  12  WindSpeed3pm      18765 non-null  float64
#  13  Humidity9am       18446 non-null  float64
#  14  Humidity3pm       18492 non-null  float64
#  15  Pressure9am       18285 non-null  float64
#  16  Pressure3pm       18291 non-null  float64
#  17  Cloud9am          14597 non-null  float64
#  18  Cloud3pm          14480 non-null  float64
#  19  Temp9am           18511 non-null  float64
#  20  Temp3pm           18521 non-null  float64
#  21  RainToday         18209 non-null  object
#  22  RainTomorrow      18209 non-null  object
#  23  RainfallTomorrow  18209 non-null  float64
# dtypes: float64(17), object(7)
# memory usage: 3.6+ MB

# %%
# Se comprueba la cantidad de nulos
df.isnull().sum()
# Out:
# Date                   0
# Location               0
# MinTemp              502
# MaxTemp              497
# Rainfall             816
# Evaporation         4745
# Sunshine            4987
# WindGustDir         1489
# WindGustSpeed       1487
# WindDir9am          1220
# WindDir3pm           335
# WindSpeed9am         270
# WindSpeed3pm         260
# Humidity9am          579
# Humidity3pm          533
# Pressure9am          740
# Pressure3pm          734
# Cloud9am            4428
# Cloud3pm            4545
# Temp9am              514
# Temp3pm              504
# RainToday            816
# RainTomorrow         816
# RainfallTomorrow     816
# dtype: int64

# %% [markdown]
# Tratamiento de faltantes en las columnas target

# %%
# Obtener los índices de los valores faltantes en cada columna
null_RainTomorrow = df[df['RainTomorrow'].isna()].index
null_RainfallTomorrow = df[df['RainfallTomorrow'].isna()].index

# Comparar si los índices de los valores faltantes son los mismos
coinciden2 = null_RainTomorrow.equals(null_RainfallTomorrow)

#print(f"¿Los registros faltantes coinciden? {coinciden1}")
print(f"¿Los registros faltantes coinciden? {coinciden2}")
# Out:
# ¿Los registros faltantes coinciden? True

# %%
# Se eliminan los registros donde RainfallTomorrow y RainTomorrow tienen valores faltantes (816)
df = df.dropna(subset=['RainfallTomorrow', 'RainTomorrow'])
df.isnull().sum()
# Out:
# Date                   0
# Location               0
# MinTemp               16
# MaxTemp                7
# Rainfall             183
# Evaporation         4704
# Sunshine            4949
# WindGustDir         1455
# WindGustSpeed       1453
# WindDir9am          1195
# WindDir3pm           330
# WindSpeed9am         264
# WindSpeed3pm         256
# Humidity9am           92
# Humidity3pm           49
# Pressure9am          253
# Pressure3pm          249
# Cloud9am            3770
# Cloud3pm            3878
# Temp9am               28
# Temp3pm               20
# RainToday            183
# RainTomorrow           0
# RainfallTomorrow       0
# dtype: int64

# %% [markdown]
# Transformación de RainToday y RainTomorrow: Conversión a tipo booleano.

# %%
# Se reemplaza 'Yes' por 1 y 'No' por 0 en las columnas RainToday y RainTomorrow
# errors='coerce' permite conservar los nan aún cambiando el tipo de datos a booleano
df['RainToday'] = pd.to_numeric(df['RainToday'].replace({'Yes': 1, 'No': 0}), errors='coerce').astype('boolean')
df['RainTomorrow'] = pd.to_numeric(df['RainTomorrow'].replace({'Yes': 1, 'No': 0}), errors='coerce').astype('boolean')

# %% [markdown]
# #### Partición del Dataframe

# %% [markdown]
# Se particiona el df en una proporción aproximada de 70% 15% 15%, correspondiendo los datos del df_train a los datos cronológicamente más antiguos.

# %%
# Ordenamiento por la columna 'Date'
df = df.sort_values('Date')

# Calcular los índices que corresponden al 70% y 85% del DataFrame
index_at_70_percent = int(len(df) * 0.7)
index_at_85_percent = int(len(df) * 0.85)

# Usar los índices para obtener las fechas en esos puntos
date_at_70_percent = df.iloc[index_at_70_percent]['Date']
date_at_85_percent = df.iloc[index_at_85_percent]['Date']

# Crear df_train, df_val y df_test basado en estas fechas
df_train = df[df['Date'] <= date_at_70_percent]
df_val = df[(df['Date'] > date_at_70_percent) & (df['Date'] <= date_at_85_percent)]
df_test = df[df['Date'] > date_at_85_percent]

# Almacenar los largos de df_train, df_val y df_test
df_train_len = len(df_train)
df_val_len = len(df_val)
df_test_len = len(df_test)

# Mostrar el número de registros en cada conjunto
print(f"Entrenamiento: {df_train_len} registros")
print(f"Validación: {df_val_len} registros")
print(f"Prueba: {df_test_len} registros")
print(f"Suma de registros (Entrenamiento + Validación + Prueba): {df_train_len + df_val_len + df_test_len} registros")
print(f"Cantidad total de registros en df original: {df.shape[0]} registros")
# Out:
# Entrenamiento: 12749 registros
# Validación: 2729 registros
# Prueba: 2731 registros
# Suma de registros (Entrenamiento + Validación + Prueba): 18209 registros
# Cantidad total de registros en df original: 18209 registros

# %% [markdown]
# #### Exploración de los datos en df_train

# %%
def hist_sns(df, bins=20, kde=True, figsize=(15, 10)):
    """
    Genera histogramas para todas las columnas numéricas de un DataFrame.

    Parámetros:
    - df: DataFrame de pandas
    - bins: Número de intervalos en el histograma
    - kde: Si es True, añade una curva de densidad (KDE)
    - figsize: Tamaño de la figura
    """
    # Filtrar solo columnas numéricas
    columnas_numericas = df.select_dtypes(include=['float64', 'int64']).columns

    # Calcular el número de filas y columnas para los subgráficos
    n = len(columnas_numericas)
    ncols = 3  # Número de columnas de subgráficos
    nrows = (n // ncols) + (1 if n % ncols != 0 else 0)  # Número de filas necesarias

    # Crear la figura y los subgráficos
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize)
    fig.tight_layout(pad=4.0)  # Espacio entre subgráficos

    # Convierte la matriz en un array plano para facilitar la iteración
    axes = axes.flatten()

    # Iterar sobre las columnas numéricas y graficar histogramas
    for i, col in enumerate(columnas_numericas):
        sns.histplot(df[col], ax=axes[i], bins=bins, kde=kde, color='skyblue')
        axes[i].set_title(f'Histograma de {col}')
        axes[i].set_xlabel('Valores')
        axes[i].set_ylabel('Frecuencia')

    # Ocultar ejes vacíos si hay más subgráficos que columnas
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.show()

# %%
def boxplot_sns(df, figsize=(15, 10)):
    """
    Genera diagramas de caja para todas las columnas numéricas del DataFrame que recibe como argumento.

    Parámetros:
    - df: DataFrame de pandas
    - figsize: Tamaño de la figura
    """
    # Filtrar solo columnas numéricas
    columnas_numericas = df.select_dtypes(include=['float64', 'int64']).columns

    # Calcular el número de filas y columnas para los subgráficos
    n = len(columnas_numericas)
    ncols = 3  # Número de columnas de subgráficos
    nrows = (n // ncols) + (1 if n % ncols != 0 else 0)  # Número de filas necesarias

    # Crear la figura y los subgráficos
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize)
    fig.tight_layout(pad=4.0)  # Espacio entre subgráficos

    # Convierte la matriz en un array plano para facilitar la iteración
    axes = axes.flatten()

    # Iterar sobre las columnas numéricas y graficar boxplots
    for i, col in enumerate(columnas_numericas):
        sns.boxplot(x=df[col], ax=axes[i], color='skyblue')
        axes[i].set_title(f'Boxplot de {col}')
        axes[i].set_xlabel('Valores')

    # Ocultar ejes vacíos si hay más subgráficos que columnas
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.show()

# %%
hist_sns(df_train, bins=15, kde=True, figsize=(15, 20))

# %%
boxplot_sns(df_train, figsize=(15, 20))

# %%
# Heatmap de matriz de correlación (sólo columnas numéricas)
df_numeric = df_train.select_dtypes(include=['float64', 'int64'])
matriz_correlacion = df_numeric.corr()
plt.figure(figsize=(20, 15))
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Matriz de Correlación de Variables Numéricas en df_train')
plt.show()

# %% [markdown]
# Se encuentran correlaciones muy altas (arriba de 0.9) entre MaxTemp y Temp3pm, Pressure9am y Pressure3pm, y MinTemp y Temp9am. Se eliminan las variables Temp9am, Temp3pm y Pressure9am.

# %%
df_train = df_train.drop(columns=['Temp9am'])
df_train = df_train.drop(columns=['Temp3pm'])
df_train = df_train.drop(columns=['Pressure9am'])

# %%
df_train.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'RainToday', 'RainTomorrow',
#        'RainfallTomorrow'],
#       dtype='object')

# %% [markdown]
# #### Balance de los datos target

# %%
# Contar el número de ocurrencias de cada categoría en la columna 'RainTomorrow'
conteo_categorias = df_train['RainTomorrow'].value_counts() # False 9814 vs. True 2935

# Calcular la proporción de cada categoría
proporcion_no = round(conteo_categorias[0] / len(df_train), 2)
proporcion_yes = round(conteo_categorias[1] / len(df_train), 2)
print("Proporción de 'RainTomorrow' igual a 0 (No):", proporcion_no)
print("Proporción de 'RainTomorrow' igual a 1 (Yes):", proporcion_yes)
# Out:
# Proporción de 'RainTomorrow' igual a 0 (No): 0.77
# Proporción de 'RainTomorrow' igual a 1 (Yes): 0.23

# %% [markdown]
# Se observa que el conjunto de datos está desbalanceado, con una gran disparidad entre las clases 0 y 1 de RainTomorrow. Esto puede sesgar los modelos de ML hacia la clase mayoritaria, afectando su capacidad para predecir correctamente la clase minoritaria.

# %% [markdown]
# #### Tratamiento de valores atípicos en df_train

# %% [markdown]
# Se analizan los valores atípicos de **Rainfall** y **Evaporation**.
#
# *Nota: Se admite un máximo del 5% de los datos para ser eliminados, ya sea por la presencia de valores atípicos o valores nulos.*

# %% [markdown]
# ##### **Rainfall**

# %% [markdown]
# Para la variable Rainfall, se calcula la proporción de valores que superan a la media más 3 desviaciones standard:

# %%
# Calcula el límite superior, que es la media más 3 desviaciones estándar
upper_limit = df_train['Rainfall'].mean() + 3 * df_train['Rainfall'].std()
# Usa este límite para contar cuántos valores están por encima
count_above_upper_limit = (df_train['Rainfall'] > upper_limit).sum()
print(f"Proporción de valores sobre 3 desviaciones stantard para 'Rainfall': {count_above_upper_limit/df_train_len}")
# Out:
# Proporción de valores sobre 3 desviaciones stantard para 'Rainfall': 0.02031531884853714

# %% [markdown]
# Se remueve sólo el 1% de los datos (no el 2%) para dejar un margen disponible de datos a borrar.

# %%
df_train_sorted = df_train.sort_values(by='Rainfall', ascending=False) # Ordenar df_train por 'Rainfall' descendente
num_to_remove = int(len(df_train) * 0.01) # Calcular la cantidad de filas a eliminar (1% del total)
df_train_filtered = df_train_sorted.iloc[num_to_remove:] # Eliminar solo el 1% más alto
print(f"Cantidad de filas después de eliminar atípicos: {len(df_train_filtered)}")
# Out:
# Cantidad de filas después de eliminar atípicos: 12622

# %% [markdown]
# ***Comparación de distribuciones***

# %%
plt.figure(figsize=(12, 6))
# Boxplot de 'Rainfall' en df_train
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer subgráfico
sns.boxplot(x=df_train['Rainfall'], color='skyblue')
plt.title('Boxplot de Rainfall (Original)')
plt.xlabel('Rainfall')

# Boxplot de 'Rainfall' en df_train_filtered
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo subgráfico
sns.boxplot(x=df_train_filtered['Rainfall'], color='lightgreen')
plt.title('Boxplot de Rainfall (Filtrado)')
plt.xlabel('Rainfall')

# Ajustar el espacio entre subgráficos
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %% [markdown]
# Se observa una mejora en la distribución de los datos ✅

# %%
# Se actualiza df_train
df_train=df_train_filtered

# %% [markdown]
# ##### **Evaporation**

# %%
# Calcula el límite superior, que es la media más 3 desviaciones estándar
upper_limit = df_train['Evaporation'].mean() + 3 * df_train['Evaporation'].std()
# Usa este límite para contar cuántos valores están por encima
count_above_upper_limit = (df['Evaporation'] > upper_limit).sum()
print(f"Proporción de valores sobre 3 desviaciones stantard para 'Evaporation': {count_above_upper_limit/df_train_len}")
# Out:
# Proporción de valores sobre 3 desviaciones stantard para 'Evaporation': 0.013648129265040396

# %% [markdown]
# Se remueve sólo el 1% de los datos (no el 1.36%), para dejar un margen disponible de datos a borrar.

# %%
df_train_sorted = df_train.sort_values(by='Evaporation', ascending=False) # Ordenar df_train por 'Evaporation' descendente
num_to_remove = int(len(df_train) * 0.01) # Calcular la cantidad de filas a eliminar (1% del total)
df_train_filtered = df_train_sorted.iloc[num_to_remove:] # Eliminar solo el 1% más alto
print(f"Cantidad de filas después de eliminar atípicos: {len(df_train_filtered)}")
# Out:
# Cantidad de filas después de eliminar atípicos: 12496

# %% [markdown]
# ***Comparación de distribuciones***

# %%
plt.figure(figsize=(12, 6))
# Boxplot de 'Evaporation' en df_train
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer subgráfico
sns.boxplot(x=df_train['Evaporation'], color='skyblue')
plt.title('Boxplot de Evaporation (Original)')
plt.xlabel('Evaporation')

# Boxplot de 'Evaporation' en df_train_filtered
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo subgráfico
sns.boxplot(x=df_train_filtered['Evaporation'], color='lightgreen')
plt.title('Boxplot de Evaporation (Filtrado)')
plt.xlabel('Evaporation')

# Ajustar el espacio entre subgráficos
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %% [markdown]
# Se observa una mejora en la distribución de los datos ✅

# %%
# Se actualiza df_train
df_train=df_train_filtered

# %% [markdown]
# #### Imputación de nulos en df_train

# %% [markdown]
# ##### Primeros análisis

# %%
num_missing_rows = df_train.isna().any(axis=1).sum()
print(f"Número de filas con al menos un valor NaN: {num_missing_rows}")
# Out:
# Número de filas con al menos un valor NaN: 5447

# %%
# Cantidad de valores faltantes
df_train.isna().sum().sort_values(ascending=False)
# Out:
# Sunshine            2918
# Cloud3pm            2830
# Cloud9am            2625
# Evaporation         2621
# WindGustDir         1368
# WindGustSpeed       1366
# WindDir9am           906
# WindDir3pm           295
# WindSpeed9am         251
# WindSpeed3pm         241
# Pressure3pm          234
# Rainfall             158
# RainToday            158
# Humidity9am           89
# Humidity3pm           42
# MinTemp               14
# MaxTemp                6
# RainTomorrow           0
# Date                   0
# Location               0
# RainfallTomorrow       0
# dtype: int64

# %% [markdown]
# Se analiza a continuación cada variable, con su variable más correlacionada, y la cantidad de nulos de cada una.

# %% [markdown]
# ##### Matriz de distancias geodésicas

# %% [markdown]
# Se construye una matriz con las distancias entre todas las ciudades del df original, que ayudará a comprender la posibilidad de adoptar valores de ciudades aledañas.

# %%
# Coordenadas de las ciudades
cities_coords_6 = {
    'Albury': (-36.0737, 146.9135),
    'Canberra': (-35.2809, 149.1300),
    'Melbourne': (-37.8136, 144.9631),
    'MelbourneAirport': (-37.6690, 144.8410),
    'Sydney': (-33.8688, 151.2093),
    'SydneyAirport': (-33.9399, 151.1753),
}

cities_coords = {
    'Adelaide': (-34.9285, 138.6007),
    'Albany': (-35.0228, 117.8814),
    'AliceSprings': (-23.6980, 133.8807),
    'Albury': (-36.0737, 146.9135),
    'BadgerysCreek': (-33.8817, 150.7440),
    'Ballarat': (-37.5622, 143.8503),
    'Bendigo': (-36.7570, 144.2784),
    'Brisbane': (-27.4698, 153.0251),
    'Cairns': (-16.9186, 145.7781),
    'Canberra': (-35.2809, 149.1300),
    'Cobar': (-31.4983, 145.8344),
    'CoffsHarbour': (-30.2963, 153.1157),
    'Darwin': (-12.4634, 130.8456),
    'Dartmoor': (-37.9225, 141.2760),
    'GoldCoast': (-28.0167, 153.4000),
    'Hobart': (-42.8821, 147.3272),
    'Katherine': (-14.4646, 132.2635),
    'Launceston': (-41.4341, 147.1374),
    'Melbourne': (-37.8136, 144.9631),
    'MelbourneAirport': (-37.6690, 144.8410),
    'Mildura': (-34.1847, 142.1625),
    'Moree': (-29.4658, 149.8407),
    'MountGambier': (-37.8284, 140.7804),
    'MountGinini': (-35.5294, 148.7744),
    'Newcastle': (-32.9272, 151.7765),
    'Nhil': (-36.3348, 141.6503),
    'NorahHead': (-33.2821, 151.5671),
    'NorfolkIsland': (-29.0408, 167.9547),
    'Nuriootpa': (-34.4694, 138.9939),
    'Penrith': (-33.7511, 150.6942),
    'Perth': (-31.9505, 115.8605),
    'PerthAirport': (-31.9403, 115.9672),
    'PearceRAAF': (-31.6736, 116.0174),
    'Portland': (-38.3463, 141.6042),
    'Richmond': (-33.5995, 150.7391),
    'Sale': (-38.1118, 147.0680),
    'SalmonGums': (-32.9815, 121.6438),
    'Sydney': (-33.8688, 151.2093),
    'SydneyAirport': (-33.9399, 151.1753),
    'Townsville': (-19.2580, 146.8169),
    'Tuggeranong': (-35.4244, 149.0888),
    'Uluru': (-25.3455, 131.0369),
    'WaggaWagga': (-35.1082, 147.3598),
    'Walpole': (-34.9777, 116.7338),
    'Watsonia': (-37.7110, 145.0830),
    'Williamtown': (-32.8150, 151.8428),
    'Witchcliffe': (-34.0261, 115.1003),
    'Wollongong': (-34.4278, 150.8931),
    'Woomera': (-31.1994, 136.8253)
}
# Crear un DataFrame vacío
# Tuggeranong            385.1     3101.62     198.49  1233.25
# Uluru                2183.36     1814.48    2160.52   861.88
# WaggaWagga            486.11     2949.82     332.13  1073.36
# Walpole              3239.71      183.43    3114.77   1918.4
# Watsonia              820.18     2726.66     637.49  1046.77
# Williamtown              0.0     3401.57     199.41  1428.97
# Witchcliffe          3401.57         0.0    3280.77  2059.05
# Wollongong            199.41     3280.77        0.0   1363.9
# Woomera              1428.97     2059.05     1363.9      0.0
#
# [49 rows x 49 columns]

# %%
# Crear un mapa centrado en Australia
mapa = folium.Map(location=[-25.2744, 133.7751], zoom_start=4)  # zoom_start nivel país

# Añadir marcadores naranjas para las ciudades en cities_coords_6
for city, coords in cities_coords_6.items():
    folium.Marker(
        location=coords,
        popup=city,
        icon=folium.Icon(color='orange')
    ).add_to(mapa)

# Añadir marcadores azules para las ciudades que están en cities_coords pero no en cities_coords_6
for city, coords in cities_coords.items():
    if city not in cities_coords_6:
        folium.Marker(
            location=coords,
            popup=city,
            icon=folium.Icon(color='blue')
        ).add_to(mapa)

# %%
# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a04c4fbf3972f015492846cdfe9239c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a04c4fbf3972f015492846cdfe9239c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a04c4fbf3972f015492846cdfe9239c = L.map(
#                 &quot;map_2a04c4fbf3972f015492846cdfe9239c&quot;,
#                 {
#                     center: [-25.2744, 133.7751],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_028fd421fba8b31ad3d72da8286ed581 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_028fd421fba8b31ad3d72da8286ed581.addTo(map_2a04c4fbf3972f015492846cdfe9239c);
#
#
#             var marker_d81d800135babf464e0efcf3eb6a04bb = L.marker(
#                 [-36.0737, 146.9135],
#                 {
# }
#             ).addTo(map_2a04c4fbf3972f015492846cdfe9239c);
#
#
#             var icon_a831f5ec6461adc3432806c48cf0a533 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d81d800135babf464e0efcf3eb6a04bb.setIcon(icon_a831f5ec6461adc3432806c48cf0a533);
#
#
#         var popup_88e502cf3935ccae535eba2e9b26993b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_828439c433f25ac49a20d1e3477e1190 = $(`&lt;div id=&quot;html_828439c433f25ac49a20d1e3477e1190&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albury&lt;/div&gt;`)[0];
#                 popup_88e502cf3935ccae535eba2e9b26993b.setContent(html_828439c433f25ac49a20d1e3477e1190);
#
#
#
#         marker_d81d800135babf464e0efcf3eb6a04bb.bindPopup(popup_88e502cf3935ccae535eba2e9b26993b)
#         ;
#
#
#
#
#             var marker_bd07d7ecd9320f1bcc2bfe87c0aded81 = L.marker(
#                 [-35.2809, 149.13],
#                 {
# }
#             ).addTo(map_2a04c4fbf3972f015492846cdfe9239c);
#
#
#             var icon_7c6a3a48211ad5911f49aaaa776a1347 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bd07d7ecd9320f1bcc2bfe87c0aded81.setIcon(icon_7c6a3a48211ad5911f49aaaa776a1347);
#
#
#         var popup_2060b1c0ecaa4471cdcdfc38bf91cf38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_307665c587c0454eb32f775a5f857d12 = $(`&lt;div id=&quot;html_307665c587c0454eb32f775a5f857d12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Canberra&lt;/div&gt;`)[0];
#                 popup_2060b1c0ecaa4471cdcdfc38bf91cf38.setContent(html_307665c587c0454eb32f775a5f857d12);
#
#
#
#         marker_bd07d7ecd9320f1bcc2bfe87c0aded81.bindPopup(popup_2060b1c0ecaa4471cdcdfc38bf91cf38)
#         ;
#
#
#
#
#             var marker_65ff5bdebe142702151f1ded6a93be56 = L.marker(
#                 [-37.8136, 144.9631],
#                 {
# }
#             ).addTo(map_2a04c4fbf3972f015492846cdfe9239c);
#
#
#             var icon_8cfb5ba109838c4f40817309b1708aa5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_65ff5bdebe142702151f1ded6a93be56.setIcon(icon_8cfb5ba109838c4f40817309b1708aa5);
#
#
#         var popup_2a76f5ec9fbe9569174b410b04962189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f035b764acef45f2abcc0dd70625824 = $(`&lt;div id=&quot;html_5f035b764acef45f2abcc0dd70625824&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Melbourne&lt;/div&gt;`)[0];
#                 popup_2a76f5ec9fbe9569174b410b04962189.setContent(html_5f035b764acef45f2abcc0dd70625824);
#
#
#
#         marker_65ff5bdebe142702151f1ded6a93be56.bindPopup(popup_2a76f5ec9fbe9569174b410b04962189)
#         ;
#
#
#
#
#             var marker_5efb665d423c3c4ed5a6f37b0f8548ec = L.marker(
#                 [-37.669, 144.841],
#                 {
# }
#             ).addTo(map_2a04c4fbf3972f015492846cdfe9239c);
#
#
#             var icon_0d5ada4a9d3233c978da284a6049026b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;:

# %% [markdown]
# ##### Análisis nan por distancias

# %% [markdown]
# Se crea la función general procesar_geo_nan, que permite analizar y reemplazar los datos nulos por aquellos del mismo día para ciudades vecinas, con un radio de km a definir.
#
# Luego, se hace un análisis pormenorizado de los demás valores nulos, reemplazando con datos de ciudades más lejanas pero en donde se observa una buena correlación de los datos, utilizando gráficos de dispersión para comparar entre ciudades.

# %%
# Transformaciones requeridas sobre df_full para correr las mismas funciones sobre df_full y df_train
df_full['RainToday'] = pd.to_numeric(df_full['RainToday'].replace({'Yes': 1, 'No': 0}), errors='coerce').astype('boolean')
df_full['RainTomorrow'] = pd.to_numeric(df_full['RainTomorrow'].replace({'Yes': 1, 'No': 0}), errors='coerce').astype('boolean')
df_full = df_full.drop(columns=['Temp9am'])
df_full = df_full.drop(columns=['Temp3pm'])
df_full = df_full.drop(columns=['Pressure9am'])

# %%
def recrear_geo_nan(df, df_data, loc_nan, loc_data, var):
    """
    Reemplaza los valores NaN para una variable específica en una localidad, utilizando los valores
    de la misma variable en otra localidad para el mismo día, y cuenta cuántos días únicos fueron usados para reemplazar esos NaN.

    Parámetros:
    df (DataFrame): El DataFrame que contiene los datos de la localidad con valores NaN.
    df_data (DataFrame): El DataFrame que contiene los datos de la localidad de donde se tomarán los valores para reemplazar.
    loc_nan (str): Nombre de la localidad que tiene valores NaN que deben ser reemplazados.
    loc_data (str): Nombre de la localidad de donde se tomarán los valores para reemplazar.
    var (str): Nombre de la variable para la cual se reemplazarán los NaN.

    Retorna:
    DataFrame: DataFrame con los valores NaN reemplazados donde fue posible.
    """
    # Crear copia del DataFrame para evitar modificar el original
    df_copy = df.copy()

    # Datos de la localidad con datos disponibles en df_data
    data_values = df_data[(df_data['Location'] == loc_data) & df_data[var].notnull()][['Date', var]]

    # Renombrar la columna de valores para evitar conflictos durante el merge
    data_values.rename(columns={var: f'{var}_replacement'}, inplace=True)

    # Datos de la localidad con NaNs en df
    nan_values = df_copy[(df_copy['Location'] == loc_nan) & df_copy[var].isnull()][['Date']]

    # Merge left para combinar los datos de df con los valores de df_data
    df_merged = pd.merge(df_copy, data_values, on='Date', how='left')

    # Condición para reemplazar NaNs
    condition = (df_merged['Location'] == loc_nan) & (df_merged[var].isnull())

    # Contar días únicos donde se reemplazan valores (nunique)
    days_used_for_replacement = pd.merge(nan_values, data_values, on='Date', how='inner')['Date'].nunique()

    # Reemplazo de los NaN
    df_merged.loc[condition, var] = df_merged.loc[condition, f'{var}_replacement']

    # Eliminar la columna de reemplazo
    df_merged.drop(columns=[f'{var}_replacement'], inplace=True)

    print(f"La cantidad de datos reemplazados fue {days_used_for_replacement}")
    return df_merged

# %%
def analisis_geo_nan(df, var, dist_matrix, cities_coords):
    """
    Analiza la distribución de valores NaN en una variable específica para distintas ciudades y determina,
    para cada una, la ciudad más cercana junto con la distancia correspondiente.

    Parámetros:
    df (DataFrame): DataFrame de donde se extraerán los datos.
    var (str): Variable para la cual se contarán los NaNs.
    dist_matrix (DataFrame): Matriz de distancias entre ciudades.
    cities_coords (dict): Diccionario de coordenadas de las ciudades.

    Retorna:
    DataFrame: Información combinada que incluye conteo de NaNs, ciudad más cercana y distancia.
    """
    # DataFrame para almacenar la ciudad más cercana y la distancia
    closest_city_and_distance = pd.DataFrame(index=cities_coords.keys(), columns=['Nearest City', 'Distance (km)'])

    # Encontrar la ciudad más cercana y la distancia para cada una
    for city in dist_matrix.columns:
        closest_city = dist_matrix[city].drop(city).idxmin()
        closest_distance = dist_matrix.at[city, closest_city]
        closest_city_and_distance.at[city, 'Nearest City'] = closest_city
        closest_city_and_distance.at[city, 'Distance (km)'] = closest_distance

    # Contar NaN en la variable específica y agrupar por ciudad
    nan_count_per_city = df[df[var].isna()]['Location'].value_counts()

    # Convertir la serie en un DataFrame
    nan_count_df = nan_count_per_city.reset_index()
    nan_count_df.columns = ['Location', f'{var} NaN Count']

    # Unir nan_count_df con closest_city_and_distance, manteniendo nan_count_df como el DataFrame principal
    complete_info = nan_count_df.merge(closest_city_and_distance, how='left', left_on='Location', right_index=True)

    return complete_info

# %%
def procesar_geo_nan(df, df_data, dist_matrix, cities_coords, distance_threshold=100):
    """
    Procesa los NaN en 'df' utilizando los valores de 'df_data' basándose en la proximidad geográfica definida
    por 'dist_matrix' y 'cities_coords', con un umbral de distancia especificado.

    Parámetros:
    df (DataFrame): DataFrame con datos que incluyen NaNs que necesitan ser procesados.
    df_data (DataFrame): DataFrame de donde se tomarán los datos para reemplazar los NaNs.
    dist_matrix (DataFrame): DataFrame que contiene las distancias entre localidades.
    cities_coords (dict): Diccionario con las coordenadas de las localidades.
    distance_threshold (int, opcional): Distancia máxima en km para considerar una ciudad cercana.

    Retorna:
    DataFrame: DataFrame con los valores NaN procesados.
    """
    excluded_columns = ['Date', 'Location','RainTomorrow','RainfallTomorrow']
    included_columns = [col for col in df.columns if col not in excluded_columns]

    print("Procesando las siguientes columnas:", included_columns)
    print("El rango fijado para ciudades cercanas es (km):", distance_threshold)

    for variable in included_columns:
        print(f"Analizando la variable: {variable}")
        geo_analysis = analisis_geo_nan(df, variable, dist_matrix, cities_coords)
        print("Resultado del análisis geográfico:\n", geo_analysis)

        for index, row in geo_analysis.iterrows():
            location = row['Location']
            if pd.isnull(row['Distance (km)']):
                continue
            # Ordenar ciudades por distancia, manteniendo solo las dentro del umbral
            possible_cities = dist_matrix[location].sort_values()
            possible_cities = possible_cities[(possible_cities > 0) & (possible_cities <= distance_threshold)]

            for closest_city, distance in possible_cities.items():
                if pd.notnull(distance):
                    print(f"Procesando la localidad: {location}")
                    print(f"Intentando con la ciudad más cercana {closest_city} a {distance} km.")
                    df = recrear_geo_nan(df, df_data, location, closest_city, variable)
                    if not df[df['Location'] == location][variable].isna().any():
                        print(f"Todos los NaNs fueron reemplazados para {location} en la variable {variable}.")
                        break
                else:
                    print(f"No se encontró ciudad cercana adecuada para {location}")

    remaining_nans = df.isna().sum().sort_values(ascending=False)
    print("NaN restantes después del procesamiento:\n", remaining_nans)

    # Crear una copia del DataFrame sin las columnas 'RainfallTomorrow' y 'RainTomorrow'
    df_filtered = df.drop(columns=excluded_columns)

    # Contar filas que contienen al menos un valor NaN en el DataFrame filtrado
    nan_rows_count_filtered = df_filtered.isna().any(axis=1).sum()
    print(f'Número de filas con al menos un valor NaN: {nan_rows_count_filtered}')

    return df

# %%
df_train = procesar_geo_nan(df_train, df_full, dist_matrix, cities_coords, 250) # quedaron 12 nulos
# Out:
# Procesando las siguientes columnas: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'RainToday']
# El rango fijado para ciudades cercanas es (km): 250
# Analizando la variable: MinTemp
# Resultado del análisis geográfico:
#     Location  MinTemp NaN Count   Nearest City Distance (km)
# 0    Albury                  6     WaggaWagga         114.5
# 1  Canberra                  5    Tuggeranong         16.36
# 2    Sydney                  3  SydneyAirport          8.49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 6
# Todos los NaNs fueron reemplazados para Albury en la variable MinTemp.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 5
# Todos los NaNs fueron reemplazados para Canberra en la variable MinTemp.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Sydney en la variable MinTemp.
# Analizando la variable: MaxTemp
# Resultado del análisis geográfico:
#     Location  MaxTemp NaN Count   Nearest City Distance (km)
# 0  Canberra                  3    Tuggeranong         16.36
# 1    Sydney                  2  SydneyAirport          8.49
# 2    Albury                  1     WaggaWagga         114.5
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Canberra en la variable MaxTemp.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Sydney en la variable MaxTemp.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable MaxTemp.
# Analizando la variable: Rainfall
# Resultado del análisis geográfico:
#      Location  Rainfall NaN Count   Nearest City Distance (km)
# 0  Melbourne                 127       Watsonia         15.53
# 1     Albury                  16     WaggaWagga         114.5
# 2   Canberra                  11    Tuggeranong         16.36
# 3     Sydney                   4  SydneyAirport          8.49
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 127
# Todos los NaNs fueron reemplazados para Melbourne en la variable Rainfall.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 15
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable Rainfall.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 11
# Todos los NaNs fueron reemplazados para Canberra en la variable Rainfall.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 4
# Todos los NaNs fueron reemplazados para Sydney en la variable Rainfall.
# Analizando la variable: Evaporation
# Resultado del análisis geográfico:
#          Location  Evaporation NaN Count   Nearest City Distance (km)
# 0         Albury                   2000     WaggaWagga         114.5
# 1       Canberra                    598    Tuggeranong         16.36
# 2         Sydney                     16  SydneyAirport          8.49
# 3  SydneyAirport                      7         Sydney          8.49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1967
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 31
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Bendigo a 248.19 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Albury en la variable Evaporation.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 596
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Canberra en la variable Evaporation.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 8
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 5
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 6
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Evaporation.
# Analizando la variable: Sunshine
# Resultado del análisis geográfico:
#             Location  Sunshine NaN Count   Nearest City Distance (km)
# 0            Albury                2000     WaggaWagga         114.5
# 1          Canberra                 900    Tuggeranong         16.36
# 2     SydneyAirport                   8         Sydney          8.49
# 3            Sydney                   8  SydneyAirport          8.49
# 4  MelbourneAirport                   1      Melbourne         19.32
# 5         Melbourne                   1       Watsonia         15.53
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1965
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 34
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable Sunshine.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 896
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Canberra en la variable Sunshine.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 5
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 5
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Ballarat a 88.27 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Bendigo a 112.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Sale a 201.96 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable Sunshine.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Ballarat a 102.04 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Bendigo a 132.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Sale a 187.91 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Sunshine.
# Analizando la variable: WindGustDir
# Resultado del análisis geográfico:
#             Location  WindGustDir NaN Count   Nearest City Distance (km)
# 0            Sydney                    989  SydneyAirport          8.49
# 1          Canberra                    298    Tuggeranong         16.36
# 2     SydneyAirport                     49         Sydney          8.49
# 3         Melbourne                     12       Watsonia         15.53
# 4  MelbourneAirport                     12      Melbourne         19.32
# 5            Albury                      8     WaggaWagga         114.5
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 633
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 22
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 32
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 298
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 289
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 4
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 24
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 23
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindGustDir.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 12
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindGustDir.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 12
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindGustDir.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 8
# Todos los NaNs fueron reemplazados para Albury en la variable WindGustDir.
# Analizando la variable: WindGustSpeed
# Resultado del análisis geográfico:
#             Location  WindGustSpeed NaN Count   Nearest City Distance (km)
# 0            Sydney                      989  SydneyAirport          8.49
# 1          Canberra                      296    Tuggeranong         16.36
# 2     SydneyAirport                       49         Sydney          8.49
# 3         Melbourne                       12       Watsonia         15.53
# 4  MelbourneAirport                       12      Melbourne         19.32
# 5            Albury                        8     WaggaWagga         114.5
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 633
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 22
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 32
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 299
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 288
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 4
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 24
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 23
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindGustSpeed.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 12
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindGustSpeed.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 12
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindGustSpeed.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 8
# Todos los NaNs fueron reemplazados para Albury en la variable WindGustSpeed.
# Analizando la variable: WindDir9am
# Resultado del análisis geográfico:
#             Location  WindDir9am NaN Count   Nearest City Distance (km)
# 0          Canberra                   431    Tuggeranong         16.36
# 1            Albury                   373     WaggaWagga         114.5
# 2            Sydney                    53  SydneyAirport          8.49
# 3         Melbourne                    23       Watsonia         15.53
# 4  MelbourneAirport                    22      Melbourne         19.32
# 5     SydneyAirport                     4         Sydney          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 272
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 104
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 22
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 30
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 344
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 22
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 3
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 3
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable WindDir9am.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 46
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 5
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 14
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Ballarat a 102.04 km.
# La cantidad de datos reemplazados fue 7
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Bendigo a 132.05 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Sale a 187.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 14
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Ballarat a 88.27 km.
# La cantidad de datos reemplazados fue 7
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Bendigo a 112.86 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindDir9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 3
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindDir9am.
# Analizando la variable: WindDir3pm
# Resultado del análisis geográfico:
#             Location  WindDir3pm NaN Count   Nearest City Distance (km)
# 0          Canberra                   214    Tuggeranong         16.36
# 1            Sydney                    32  SydneyAirport          8.49
# 2            Albury                    32     WaggaWagga         114.5
# 3  MelbourneAirport                     8      Melbourne         19.32
# 4         Melbourne                     8       Watsonia         15.53
# 5     SydneyAirport                     1         Sydney          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 210
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindDir3pm.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 29
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Sydney en la variable WindDir3pm.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 30
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable WindDir3pm.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 6
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Ballarat a 88.27 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindDir3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 6
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Ballarat a 102.04 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindDir3pm.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindDir3pm.
# Analizando la variable: WindSpeed9am
# Resultado del análisis geográfico:
#             Location  WindSpeed9am NaN Count   Nearest City Distance (km)
# 0          Canberra                     217    Tuggeranong         16.36
# 1            Sydney                      25  SydneyAirport          8.49
# 2            Albury                       4     WaggaWagga         114.5
# 3     SydneyAirport                       2         Sydney          8.49
# 4         Melbourne                       2       Watsonia         15.53
# 5  MelbourneAirport                       1      Melbourne         19.32
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 205
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 3
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 7
# Todos los NaNs fueron reemplazados para Canberra en la variable WindSpeed9am.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 25
# Todos los NaNs fueron reemplazados para Sydney en la variable WindSpeed9am.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 3
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable WindSpeed9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindSpeed9am.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Ballarat a 102.04 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindSpeed9am.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindSpeed9am.
# Analizando la variable: WindSpeed3pm
# Resultado del análisis geográfico:
#     Location  WindSpeed3pm NaN Count   Nearest City Distance (km)
# 0  Canberra                     211    Tuggeranong         16.36
# 1    Sydney                      24  SydneyAirport          8.49
# 2    Albury                       6     WaggaWagga         114.5
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 209
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindSpeed3pm.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 21
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Sydney en la variable WindSpeed3pm.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 6
# Todos los NaNs fueron reemplazados para Albury en la variable WindSpeed3pm.
# Analizando la variable: Humidity9am
# Resultado del análisis geográfico:
#             Location  Humidity9am NaN Count   Nearest City Distance (km)
# 0          Canberra                     60    Tuggeranong         16.36
# 1            Sydney                     14  SydneyAirport          8.49
# 2  MelbourneAirport                      8      Melbourne         19.32
# 3            Albury                      4     WaggaWagga         114.5
# 4         Melbourne                      2       Watsonia         15.53
# 5     SydneyAirport                      1         Sydney          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 59
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Humidity9am.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 14
# Todos los NaNs fueron reemplazados para Sydney en la variable Humidity9am.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 8
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable Humidity9am.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 4
# Todos los NaNs fueron reemplazados para Albury en la variable Humidity9am.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Melbourne en la variable Humidity9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Humidity9am.
# Analizando la variable: Humidity3pm
# Resultado del análisis geográfico:
#             Location  Humidity3pm NaN Count   Nearest City Distance (km)
# 0            Sydney                     13  SydneyAirport          8.49
# 1          Canberra                     11    Tuggeranong         16.36
# 2  MelbourneAirport                      9      Melbourne         19.32
# 3         Melbourne                      5       Watsonia         15.53
# 4            Albury                      3     WaggaWagga         114.5
# 5     SydneyAirport                      1         Sydney          8.49
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 12
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable Humidity3pm.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 10
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Humidity3pm.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 9
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable Humidity3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 5
# Todos los NaNs fueron reemplazados para Melbourne en la variable Humidity3pm.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Albury en la variable Humidity3pm.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Humidity3pm.
# Analizando la variable: Pressure3pm
# Resultado del análisis geográfico:
#          Location  Pressure3pm NaN Count   Nearest City Distance (km)
# 0       Canberra                    209    Tuggeranong         16.36
# 1         Sydney                     18  SydneyAirport          8.49
# 2         Albury                      3     WaggaWagga         114.5
# 3  SydneyAirport                      2         Sydney          8.49
# 4      Melbourne                      2       Watsonia         15.53
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 207
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Canberra en la variable Pressure3pm.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 18
# Todos los NaNs fueron reemplazados para Sydney en la variable Pressure3pm.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Albury en la variable Pressure3pm.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Pressure3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Melbourne en la variable Pressure3pm.
# Analizando la variable: Cloud9am
# Resultado del análisis geográfico:
#      Location  Cloud9am NaN Count   Nearest City Distance (km)
# 0     Albury                1185     WaggaWagga         114.5
# 1     Sydney                 545  SydneyAirport          8.49
# 2   Canberra                 538    Tuggeranong         16.36
# 3  Melbourne                 357       Watsonia         15.53
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1164
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 21
# Todos los NaNs fueron reemplazados para Albury en la variable Cloud9am.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 545
# Todos los NaNs fueron reemplazados para Sydney en la variable Cloud9am.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 537
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Cloud9am.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 357
# Todos los NaNs fueron reemplazados para Melbourne en la variable Cloud9am.
# Analizando la variable: Cloud3pm
# Resultado del análisis geográfico:
#      Location  Cloud3pm NaN Count   Nearest City Distance (km)
# 0     Albury                1122     WaggaWagga         114.5
# 1   Canberra                 757    Tuggeranong         16.36
# 2     Sydney                 545  SydneyAirport          8.49
# 3  Melbourne                 406       Watsonia         15.53
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1101
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 20
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable Cloud3pm.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 756
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Cloud3pm.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 545
# Todos los NaNs fueron reemplazados para Sydney en la variable Cloud3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 406
# Todos los NaNs fueron reemplazados para Melbourne en la variable Cloud3pm.
# Analizando la variable: RainToday
# Resultado del análisis geográfico:
#      Location  RainToday NaN Count   Nearest City Distance (km)
# 0  Melbourne                  127       Watsonia         15.53
# 1     Albury                   16     WaggaWagga         114.5
# 2   Canberra                   11    Tuggeranong         16.36
# 3     Sydney                    4  SydneyAirport          8.49
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 127
# Todos los NaNs fueron reemplazados para Melbourne en la variable RainToday.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 15
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable RainToday.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 11
# Todos los NaNs fueron reemplazados para Canberra en la variable RainToday.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 4
# Todos los NaNs fueron reemplazados para Sydney en la variable RainToday.
# NaN restantes después del procesamiento:
#  WindGustDir         6
# WindGustSpeed       4
# WindDir9am          3
# Sunshine            2
# Evaporation         1
# Date                0
# Humidity9am         0
# RainTomorrow        0
# RainToday           0
# Cloud3pm            0
# Cloud9am            0
# Pressure3pm         0
# Humidity3pm         0
# WindDir3pm          0
# WindSpeed3pm        0
# WindSpeed9am        0
# Location            0
# Rainfall            0
# MaxTemp             0
# MinTemp             0
# RainfallTomorrow    0
# dtype: int64
# Número de filas con al menos un valor NaN: 12

# %%
df_train = procesar_geo_nan(df_train, df_full, dist_matrix, cities_coords, 2000) # 6 valores faltantes imputados
# Out:
# Procesando las siguientes columnas: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'RainToday']
# El rango fijado para ciudades cercanas es (km): 2000
# Analizando la variable: MinTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MinTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: MaxTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MaxTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Rainfall
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Rainfall NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Evaporation
# Resultado del análisis geográfico:
#    Location  Evaporation NaN Count   Nearest City Distance (km)
# 0   Sydney                      1  SydneyAirport          8.49
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable Evaporation.
# Analizando la variable: Sunshine
# Resultado del análisis geográfico:
#          Location  Sunshine NaN Count   Nearest City Distance (km)
# 0  SydneyAirport                   1         Sydney          8.49
# 1         Sydney                   1  SydneyAirport          8.49
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Tuggeranong a 252.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana MountGinini a 281.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana WaggaWagga a 373.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Sunshine.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable Sunshine.
# Analizando la variable: WindGustDir
# Resultado del análisis geográfico:
#     Location  WindGustDir NaN Count   Nearest City Distance (km)
# 0  Canberra                      3    Tuggeranong         16.36
# 1    Sydney                      3  SydneyAirport          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorahHead a 315.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Newcastle a 357.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sale a 364.18 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Williamtown a 370.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Watsonia a 451.8 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MelbourneAirport a 466.79 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Bendigo a 466.93 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Melbourne a 467.02 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Cobar a 519.56 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Ballarat a 536.79 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Moree a 648.31 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Mildura a 649.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana CoffsHarbour a 666.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Nhil a 685.88 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Launceston a 704.82 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Portland a 752.42 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Dartmoor a 761.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGambier a 798.82 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Hobart a 858.1 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana GoldCoast a 901.29 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Nuriootpa a 930.66 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Brisbane a 941.76 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Adelaide a 960.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Woomera a 1231.76 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Townsville a 1790.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorfolkIsland a 1901.84 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana AliceSprings a 1953.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana CoffsHarbour a 435.09 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Albury a 462.23 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Moree a 505.15 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cobar a 568.4 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Sale a 600.77 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana GoldCoast a 681.69 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Watsonia a 698.62 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Bendigo a 706.8 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MelbourneAirport a 713.43 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Melbourne a 713.86 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Brisbane a 730.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Ballarat a 781.5 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Mildura a 835.98 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Nhil a 912.99 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Launceston a 913.03 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Portland a 996.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Dartmoor a 1002.5 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGambier a 1038.67 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Hobart a 1056.13 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Nuriootpa a 1127.56 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Adelaide a 1164.53 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Woomera a 1382.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Townsville a 1676.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorfolkIsland a 1676.81 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cairns a 1954.78 km.
# La cantidad de datos reemplazados fue 0
# Analizando la variable: WindGustSpeed
# Resultado del análisis geográfico:
#     Location  WindGustSpeed NaN Count   Nearest City Distance (km)
# 0  Canberra                        2    Tuggeranong         16.36
# 1    Sydney                        2  SydneyAirport          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorahHead a 315.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Newcastle a 357.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sale a 364.18 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Williamtown a 370.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Watsonia a 451.8 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MelbourneAirport a 466.79 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Bendigo a 466.93 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Melbourne a 467.02 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Cobar a 519.56 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Ballarat a 536.79 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Moree a 648.31 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Mildura a 649.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana CoffsHarbour a 666.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Nhil a 685.88 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Launceston a 704.82 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Portland a 752.42 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Dartmoor a 761.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGambier a 798.82 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Hobart a 858.1 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana GoldCoast a 901.29 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Nuriootpa a 930.66 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Brisbane a 941.76 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Adelaide a 960.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Woomera a 1231.76 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Townsville a 1790.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorfolkIsland a 1901.84 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana AliceSprings a 1953.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana CoffsHarbour a 435.09 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Albury a 462.23 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Moree a 505.15 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cobar a 568.4 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Sale a 600.77 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana GoldCoast a 681.69 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Watsonia a 698.62 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Bendigo a 706.8 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MelbourneAirport a 713.43 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Melbourne a 713.86 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Brisbane a 730.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Ballarat a 781.5 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Mildura a 835.98 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Nhil a 912.99 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Launceston a 913.03 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Portland a 996.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Dartmoor a 1002.5 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGambier a 1038.67 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Hobart a 1056.13 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Nuriootpa a 1127.56 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Adelaide a 1164.53 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Woomera a 1382.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Townsville a 1676.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorfolkIsland a 1676.81 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cairns a 1954.78 km.
# La cantidad de datos reemplazados fue 0
# Analizando la variable: WindDir9am
# Resultado del análisis geográfico:
#      Location  WindDir9am NaN Count   Nearest City Distance (km)
# 0     Sydney                     1  SydneyAirport          8.49
# 1   Canberra                     1    Tuggeranong         16.36
# 2  Melbourne                     1       Watsonia         15.53
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana CoffsHarbour a 435.09 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Albury a 462.23 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Moree a 505.15 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cobar a 568.4 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Sale a 600.77 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana GoldCoast a 681.69 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Watsonia a 698.62 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Bendigo a 706.8 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MelbourneAirport a 713.43 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Melbourne a 713.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Brisbane a 730.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Ballarat a 781.5 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Mildura a 835.98 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Nhil a 912.99 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Launceston a 913.03 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Portland a 996.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Dartmoor a 1002.5 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGambier a 1038.67 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Hobart a 1056.13 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Nuriootpa a 1127.56 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Adelaide a 1164.53 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Woomera a 1382.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Townsville a 1676.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorfolkIsland a 1676.81 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cairns a 1954.78 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorahHead a 315.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Newcastle a 357.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sale a 364.18 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Williamtown a 370.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Watsonia a 451.8 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MelbourneAirport a 466.79 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Bendigo a 466.93 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Melbourne a 467.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Cobar a 519.56 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Ballarat a 536.79 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Moree a 648.31 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Mildura a 649.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana CoffsHarbour a 666.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Nhil a 685.88 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Launceston a 704.82 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Portland a 752.42 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Dartmoor a 761.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGambier a 798.82 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Hobart a 858.1 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana GoldCoast a 901.29 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Nuriootpa a 930.66 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Brisbane a 941.76 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Adelaide a 960.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Woomera a 1231.76 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Townsville a 1790.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorfolkIsland a 1901.84 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana AliceSprings a 1953.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Ballarat a 102.04 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Bendigo a 132.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Sale a 187.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Albury a 259.73 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Portland a 300.55 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Dartmoor a 324.63 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Nhil a 337.19 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MountGambier a 368.24 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana WaggaWagga a 369.13 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MountGinini a 424.59 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Launceston a 443.17 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Tuggeranong a 454.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Canberra a 467.02 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindDir9am.
# Analizando la variable: WindDir3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindDir3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindSpeed9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindSpeed9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindSpeed3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindSpeed3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Humidity9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Humidity9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Humidity3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Humidity3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Pressure3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Pressure3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Cloud9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Cloud9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Cloud3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Cloud3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: RainToday
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, RainToday NaN Count, Nearest City, Distance (km)]
# Index: []
# NaN restantes después del procesamiento:
#  WindGustDir         4
# WindGustSpeed       2
# WindDir9am          2
# Date                0
# WindSpeed3pm        0
# RainTomorrow        0
# RainToday           0
# Cloud3pm            0
# Cloud9am            0
# Pressure3pm         0
# Humidity3pm         0
# Humidity9am         0
# WindDir3pm          0
# WindSpeed9am        0
# Location            0
# Sunshine            0
# Evaporation         0
# Rainfall            0
# MaxTemp             0
# MinTemp             0
# RainfallTomorrow    0
# dtype: int64
# Número de filas con al menos un valor NaN: 6

# %%
columnas_a_imputar = ["WindGustDir", "WindGustSpeed", "WindDir9am"]
imputer = SimpleImputer(strategy="most_frequent") # moda
imputer.fit(df_train[columnas_a_imputar])

df_train[columnas_a_imputar] = imputer.transform(df_train[columnas_a_imputar])
print(df_train[columnas_a_imputar].isna().sum())
# Out:
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# dtype: int64

# %% [markdown]
# #### Ajuste df_val y df_test

# %% [markdown]
# Se realizan los ajustes de atípicos e imputación de nans replicando las operaciones sobre df_train.

# %%
# 1. Eliminación de columnas en validación y prueba
columns_to_drop = ['Temp9am', 'Temp3pm', 'Pressure9am']
df_val = df_val.drop(columns=columns_to_drop)
df_test = df_test.drop(columns=columns_to_drop)

# 2. Eliminación del 1% de los valores más altos en Rainfall y Evaporation
# Para Rainfall
df_val_sorted_rainfall = df_val.sort_values(by='Rainfall', ascending=False)
num_to_remove_rainfall = int(len(df_val) * 0.01)  # 1% de las filas
df_val_filtered_rainfall = df_val_sorted_rainfall.iloc[num_to_remove_rainfall:]

df_test_sorted_rainfall = df_test.sort_values(by='Rainfall', ascending=False)
num_to_remove_rainfall = int(len(df_test) * 0.01)  # 1% de las filas
df_test_filtered_rainfall = df_test_sorted_rainfall.iloc[num_to_remove_rainfall:]

# Para Evaporation
df_val_sorted_evaporation = df_val_filtered_rainfall.sort_values(by='Evaporation', ascending=False)
num_to_remove_evaporation = int(len(df_val_filtered_rainfall) * 0.01)  # 1% de las filas
df_val_filtered = df_val_sorted_evaporation.iloc[num_to_remove_evaporation:]

df_test_sorted_evaporation = df_test_filtered_rainfall.sort_values(by='Evaporation', ascending=False)
num_to_remove_evaporation = int(len(df_test_filtered_rainfall) * 0.01)  # 1% de las filas
df_test_filtered = df_test_sorted_evaporation.iloc[num_to_remove_evaporation:]

# Actualizamos los conjuntos de validación y prueba
df_val = df_val_filtered
df_test = df_test_filtered

# Verificamos el tamaño de los conjuntos después de la eliminación de atípicos
print(f"Tamaño de df_val después de eliminar atípicos: {len(df_val)}")
print(f"Tamaño de df_test después de eliminar atípicos: {len(df_test)}")
# Out:
# Tamaño de df_val después de eliminar atípicos: 2675
# Tamaño de df_test después de eliminar atípicos: 2677

# %% [markdown]
# Imputación de nulos

# %% [markdown]
# Se cuenta la cantidad de filas con al menos un valor nan. Dicho valor debe ser menor al 3.7% del total de registros.

# %%
# Verificar NaN en validation
print("\n=== NaN en Validation ===")
print(df_val.isna().sum().sort_values(ascending=False))

# Verificar NaN en test
print("\n=== NaN en Test ===")
print(df_test.isna().sum().sort_values(ascending=False))

# Opcional: Total de NaN por conjunto
print("\nTotal de NaN:")
print(f"Train: {df_train.isna().sum().sum()}")
print(f"Val: {df_val.isna().sum().sum()}")
print(f"Test: {df_test.isna().sum().sum()}")
# Out:
# === NaN en Validation ===
# Evaporation         1070
# Sunshine            1065
# Cloud9am             623
# Cloud3pm             554
# WindDir9am           121
# WindGustDir           28
# WindGustSpeed         28
# RainToday             14
# Rainfall              14
# WindDir3pm             5
# Humidity3pm            3
# WindSpeed3pm           2
# Pressure3pm            1
# WindSpeed9am           1
# RainTomorrow           0
# Date                   0
# Humidity9am            0
# Location               0
# MaxTemp                0
# MinTemp                0
# RainfallTomorrow       0
# dtype: int64
#
# === NaN en Test ===
# Evaporation         937
# Sunshine            922
# Cloud9am            478
# Cloud3pm            446
# WindDir9am          156
# WindGustDir          27
# WindGustSpeed        27
# WindDir3pm           19
# Rainfall              9
# RainToday             9
# Humidity9am           3
# Humidity3pm           3
# Pressure3pm           3
# WindSpeed9am          2
# WindSpeed3pm          2
# MinTemp               2
# MaxTemp               1
# RainTomorrow          0
# Date                  0
# Location              0
# RainfallTomorrow      0
# dtype: int64
#
# Total de NaN:
# Train: 0
# Val: 3529
# Test: 3046

# %%
df_val = procesar_geo_nan(df_val, df_full, dist_matrix, cities_coords, 250) # quedaron 10 nulos
# Out:
# Procesando las siguientes columnas: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'RainToday']
# El rango fijado para ciudades cercanas es (km): 250
# Analizando la variable: MinTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MinTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: MaxTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MaxTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Rainfall
# Resultado del análisis geográfico:
#          Location  Rainfall NaN Count   Nearest City Distance (km)
# 0      Melbourne                   7       Watsonia         15.53
# 1       Canberra                   3    Tuggeranong         16.36
# 2         Sydney                   2  SydneyAirport          8.49
# 3         Albury                   1     WaggaWagga         114.5
# 4  SydneyAirport                   1         Sydney          8.49
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 7
# Todos los NaNs fueron reemplazados para Melbourne en la variable Rainfall.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Canberra en la variable Rainfall.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Sydney en la variable Rainfall.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable Rainfall.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Rainfall.
# Analizando la variable: Evaporation
# Resultado del análisis geográfico:
#             Location  Evaporation NaN Count   Nearest City Distance (km)
# 0            Albury                    530     WaggaWagga         114.5
# 1          Canberra                    525    Tuggeranong         16.36
# 2            Sydney                      7  SydneyAirport          8.49
# 3     SydneyAirport                      6         Sydney          8.49
# 4  MelbourneAirport                      2      Melbourne         19.32
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 528
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Albury en la variable Evaporation.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 523
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Canberra en la variable Evaporation.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 4
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Sydney en la variable Evaporation.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 4
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Evaporation.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Ballarat a 88.27 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Bendigo a 112.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Sale a 201.96 km.
# La cantidad de datos reemplazados fue 0
# Analizando la variable: Sunshine
# Resultado del análisis geográfico:
#          Location  Sunshine NaN Count   Nearest City Distance (km)
# 0         Albury                 530     WaggaWagga         114.5
# 1       Canberra                 525    Tuggeranong         16.36
# 2  SydneyAirport                   5         Sydney          8.49
# 3         Sydney                   5  SydneyAirport          8.49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 526
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 4
# Todos los NaNs fueron reemplazados para Albury en la variable Sunshine.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 521
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 4
# Todos los NaNs fueron reemplazados para Canberra en la variable Sunshine.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Analizando la variable: WindGustDir
# Resultado del análisis geográfico:
#     Location  WindGustDir NaN Count   Nearest City Distance (km)
# 0    Sydney                     17  SydneyAirport          8.49
# 1  Canberra                     10    Tuggeranong         16.36
# 2    Albury                      1     WaggaWagga         114.5
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 17
# Todos los NaNs fueron reemplazados para Sydney en la variable WindGustDir.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 10
# Todos los NaNs fueron reemplazados para Canberra en la variable WindGustDir.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable WindGustDir.
# Analizando la variable: WindGustSpeed
# Resultado del análisis geográfico:
#     Location  WindGustSpeed NaN Count   Nearest City Distance (km)
# 0    Sydney                       17  SydneyAirport          8.49
# 1  Canberra                       10    Tuggeranong         16.36
# 2    Albury                        1     WaggaWagga         114.5
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 17
# Todos los NaNs fueron reemplazados para Sydney en la variable WindGustSpeed.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 10
# Todos los NaNs fueron reemplazados para Canberra en la variable WindGustSpeed.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable WindGustSpeed.
# Analizando la variable: WindDir9am
# Resultado del análisis geográfico:
#             Location  WindDir9am NaN Count   Nearest City Distance (km)
# 0            Albury                    56     WaggaWagga         114.5
# 1          Canberra                    46    Tuggeranong         16.36
# 2  MelbourneAirport                    13      Melbourne         19.32
# 3         Melbourne                     2       Watsonia         15.53
# 4     SydneyAirport                     2         Sydney          8.49
# 5            Sydney                     2  SydneyAirport          8.49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 7
# Todos los NaNs fueron reemplazados para Albury en la variable WindDir9am.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 22
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 24
# Todos los NaNs fueron reemplazados para Canberra en la variable WindDir9am.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 7
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Ballarat a 88.27 km.
# La cantidad de datos reemplazados fue 5
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Bendigo a 112.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Sale a 201.96 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindDir9am.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Ballarat a 102.04 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindDir9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindDir9am.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Sydney en la variable WindDir9am.
# Analizando la variable: WindDir3pm
# Resultado del análisis geográfico:
#          Location  WindDir3pm NaN Count   Nearest City Distance (km)
# 0         Albury                     2     WaggaWagga         114.5
# 1  SydneyAirport                     1         Sydney          8.49
# 2         Sydney                     1  SydneyAirport          8.49
# 3       Canberra                     1    Tuggeranong         16.36
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Albury en la variable WindDir3pm.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindDir3pm.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable WindDir3pm.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindDir3pm.
# Analizando la variable: WindSpeed9am
# Resultado del análisis geográfico:
#    Location  WindSpeed9am NaN Count   Nearest City Distance (km)
# 0   Sydney                       1  SydneyAirport          8.49
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable WindSpeed9am.
# Analizando la variable: WindSpeed3pm
# Resultado del análisis geográfico:
#     Location  WindSpeed3pm NaN Count   Nearest City Distance (km)
# 0    Sydney                       1  SydneyAirport          8.49
# 1  Canberra                       1    Tuggeranong         16.36
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable WindSpeed3pm.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindSpeed3pm.
# Analizando la variable: Humidity9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Humidity9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Humidity3pm
# Resultado del análisis geográfico:
#          Location  Humidity3pm NaN Count Nearest City Distance (km)
# 0  SydneyAirport                      1       Sydney          8.49
# 1      Melbourne                      1     Watsonia         15.53
# 2       Canberra                      1  Tuggeranong         16.36
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Humidity3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Humidity3pm.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Humidity3pm.
# Analizando la variable: Pressure3pm
# Resultado del análisis geográfico:
#     Location  Pressure3pm NaN Count Nearest City Distance (km)
# 0  Canberra                      1  Tuggeranong         16.36
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Pressure3pm.
# Analizando la variable: Cloud9am
# Resultado del análisis geográfico:
#          Location  Cloud9am NaN Count   Nearest City Distance (km)
# 0         Albury                 295     WaggaWagga         114.5
# 1       Canberra                 290    Tuggeranong         16.36
# 2      Melbourne                  34       Watsonia         15.53
# 3  SydneyAirport                   2         Sydney          8.49
# 4         Sydney                   2  SydneyAirport          8.49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 292
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Albury en la variable Cloud9am.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 288
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Cloud9am.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 34
# Todos los NaNs fueron reemplazados para Melbourne en la variable Cloud9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Cloud9am.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable Cloud9am.
# Analizando la variable: Cloud3pm
# Resultado del análisis geográfico:
#      Location  Cloud3pm NaN Count Nearest City Distance (km)
# 0   Canberra                 262  Tuggeranong         16.36
# 1     Albury                 247   WaggaWagga         114.5
# 2  Melbourne                  45     Watsonia         15.53
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 260
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Cloud3pm.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 242
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 3
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable Cloud3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 45
# Todos los NaNs fueron reemplazados para Melbourne en la variable Cloud3pm.
# Analizando la variable: RainToday
# Resultado del análisis geográfico:
#          Location  RainToday NaN Count   Nearest City Distance (km)
# 0      Melbourne                    7       Watsonia         15.53
# 1       Canberra                    3    Tuggeranong         16.36
# 2         Sydney                    2  SydneyAirport          8.49
# 3         Albury                    1     WaggaWagga         114.5
# 4  SydneyAirport                    1         Sydney          8.49
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 7
# Todos los NaNs fueron reemplazados para Melbourne en la variable RainToday.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Canberra en la variable RainToday.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Sydney en la variable RainToday.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Albury en la variable RainToday.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable RainToday.
# NaN restantes después del procesamiento:
#  Sunshine            8
# Evaporation         2
# Date                0
# WindSpeed3pm        0
# RainTomorrow        0
# RainToday           0
# Cloud3pm            0
# Cloud9am            0
# Pressure3pm         0
# Humidity3pm         0
# Humidity9am         0
# WindDir3pm          0
# WindSpeed9am        0
# Location            0
# WindDir9am          0
# WindGustSpeed       0
# WindGustDir         0
# Rainfall            0
# MaxTemp             0
# MinTemp             0
# RainfallTomorrow    0
# dtype: int64
# Número de filas con al menos un valor NaN: 10

# %%
df_val = procesar_geo_nan(df_val, df_full, dist_matrix, cities_coords, 2000)
# Out:
# Procesando las siguientes columnas: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'RainToday']
# El rango fijado para ciudades cercanas es (km): 2000
# Analizando la variable: MinTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MinTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: MaxTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MaxTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Rainfall
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Rainfall NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Evaporation
# Resultado del análisis geográfico:
#             Location  Evaporation NaN Count Nearest City Distance (km)
# 0  MelbourneAirport                      2    Melbourne         19.32
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Ballarat a 88.27 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Bendigo a 112.86 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Sale a 201.96 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Albury a 255.89 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Portland a 294.02 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable Evaporation.
# Analizando la variable: Sunshine
# Resultado del análisis geográfico:
#          Location  Sunshine NaN Count   Nearest City Distance (km)
# 0  SydneyAirport                   4         Sydney          8.49
# 1         Sydney                   4  SydneyAirport          8.49
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Tuggeranong a 252.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana MountGinini a 281.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana WaggaWagga a 373.49 km.
# La cantidad de datos reemplazados fue 4
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Sunshine.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 4
# Todos los NaNs fueron reemplazados para Sydney en la variable Sunshine.
# Analizando la variable: WindGustDir
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindGustDir NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindGustSpeed
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindGustSpeed NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindDir9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindDir9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindDir3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindDir3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindSpeed9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindSpeed9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindSpeed3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindSpeed3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Humidity9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Humidity9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Humidity3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Humidity3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Pressure3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Pressure3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Cloud9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Cloud9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Cloud3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Cloud3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: RainToday
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, RainToday NaN Count, Nearest City, Distance (km)]
# Index: []
# NaN restantes después del procesamiento:
#  Date                0
# WindSpeed9am        0
# RainTomorrow        0
# RainToday           0
# Cloud3pm            0
# Cloud9am            0
# Pressure3pm         0
# Humidity3pm         0
# Humidity9am         0
# WindSpeed3pm        0
# WindDir3pm          0
# Location            0
# WindDir9am          0
# WindGustSpeed       0
# WindGustDir         0
# Sunshine            0
# Evaporation         0
# Rainfall            0
# MaxTemp             0
# MinTemp             0
# RainfallTomorrow    0
# dtype: int64
# Número de filas con al menos un valor NaN: 0

# %%
df_test = procesar_geo_nan(df_test, df_full, dist_matrix, cities_coords, 250) # quedaron 17 nulos
# Out:
# Procesando las siguientes columnas: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'RainToday']
# El rango fijado para ciudades cercanas es (km): 250
# Analizando la variable: MinTemp
# Resultado del análisis geográfico:
#          Location  MinTemp NaN Count Nearest City Distance (km)
# 0      Melbourne                  1     Watsonia         15.53
# 1  SydneyAirport                  1       Sydney          8.49
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable MinTemp.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable MinTemp.
# Analizando la variable: MaxTemp
# Resultado del análisis geográfico:
#      Location  MaxTemp NaN Count Nearest City Distance (km)
# 0  Melbourne                  1     Watsonia         15.53
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable MaxTemp.
# Analizando la variable: Rainfall
# Resultado del análisis geográfico:
#          Location  Rainfall NaN Count Nearest City Distance (km)
# 0         Albury                   3   WaggaWagga         114.5
# 1  SydneyAirport                   3       Sydney          8.49
# 2       Canberra                   2  Tuggeranong         16.36
# 3      Melbourne                   1     Watsonia         15.53
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Albury en la variable Rainfall.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Rainfall.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Canberra en la variable Rainfall.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Rainfall.
# Analizando la variable: Evaporation
# Resultado del análisis geográfico:
#          Location  Evaporation NaN Count   Nearest City Distance (km)
# 0       Canberra                    460    Tuggeranong         16.36
# 1         Albury                    458     WaggaWagga         114.5
# 2  SydneyAirport                     10         Sydney          8.49
# 3         Sydney                      9  SydneyAirport          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 330
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 14
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 113
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 330
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 128
# Todos los NaNs fueron reemplazados para Albury en la variable Evaporation.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 7
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 6
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Analizando la variable: Sunshine
# Resultado del análisis geográfico:
#          Location  Sunshine NaN Count   Nearest City Distance (km)
# 0       Canberra                 460    Tuggeranong         16.36
# 1         Albury                 458     WaggaWagga         114.5
# 2         Sydney                   2  SydneyAirport          8.49
# 3  SydneyAirport                   2         Sydney          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 40
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 417
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 40
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 418
# Todos los NaNs fueron reemplazados para Albury en la variable Sunshine.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Analizando la variable: WindGustDir
# Resultado del análisis geográfico:
#             Location  WindGustDir NaN Count   Nearest City Distance (km)
# 0            Sydney                     12  SydneyAirport          8.49
# 1          Canberra                     11    Tuggeranong         16.36
# 2  MelbourneAirport                      2      Melbourne         19.32
# 3         Melbourne                      1       Watsonia         15.53
# 4     SydneyAirport                      1         Sydney          8.49
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 12
# Todos los NaNs fueron reemplazados para Sydney en la variable WindGustDir.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 11
# Todos los NaNs fueron reemplazados para Canberra en la variable WindGustDir.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindGustDir.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindGustDir.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindGustDir.
# Analizando la variable: WindGustSpeed
# Resultado del análisis geográfico:
#             Location  WindGustSpeed NaN Count   Nearest City Distance (km)
# 0            Sydney                       12  SydneyAirport          8.49
# 1          Canberra                       11    Tuggeranong         16.36
# 2  MelbourneAirport                        2      Melbourne         19.32
# 3         Melbourne                        1       Watsonia         15.53
# 4     SydneyAirport                        1         Sydney          8.49
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 12
# Todos los NaNs fueron reemplazados para Sydney en la variable WindGustSpeed.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 11
# Todos los NaNs fueron reemplazados para Canberra en la variable WindGustSpeed.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindGustSpeed.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindGustSpeed.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindGustSpeed.
# Analizando la variable: WindDir9am
# Resultado del análisis geográfico:
#             Location  WindDir9am NaN Count   Nearest City Distance (km)
# 0            Albury                    88     WaggaWagga         114.5
# 1          Canberra                    47    Tuggeranong         16.36
# 2         Melbourne                    13       Watsonia         15.53
# 3  MelbourneAirport                     5      Melbourne         19.32
# 4     SydneyAirport                     2         Sydney          8.49
# 5            Sydney                     1  SydneyAirport          8.49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 80
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 8
# Todos los NaNs fueron reemplazados para Albury en la variable WindDir9am.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 13
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 33
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindDir9am.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 8
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 5
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindDir9am.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 4
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindDir9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindDir9am.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable WindDir9am.
# Analizando la variable: WindDir3pm
# Resultado del análisis geográfico:
#             Location  WindDir3pm NaN Count Nearest City Distance (km)
# 0            Albury                     6   WaggaWagga         114.5
# 1  MelbourneAirport                     5    Melbourne         19.32
# 2         Melbourne                     3     Watsonia         15.53
# 3          Canberra                     3  Tuggeranong         16.36
# 4     SydneyAirport                     2       Sydney          8.49
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 6
# Todos los NaNs fueron reemplazados para Albury en la variable WindDir3pm.
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Melbourne a 19.32 km.
# La cantidad de datos reemplazados fue 4
# Procesando la localidad: MelbourneAirport
# Intentando con la ciudad más cercana Watsonia a 21.85 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para MelbourneAirport en la variable WindDir3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana MelbourneAirport a 19.32 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable WindDir3pm.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 2
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindDir3pm.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindDir3pm.
# Analizando la variable: WindSpeed9am
# Resultado del análisis geográfico:
#          Location  WindSpeed9am NaN Count Nearest City Distance (km)
# 0  SydneyAirport                       1       Sydney          8.49
# 1       Canberra                       1  Tuggeranong         16.36
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindSpeed9am.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindSpeed9am.
# Analizando la variable: WindSpeed3pm
# Resultado del análisis geográfico:
#          Location  WindSpeed3pm NaN Count Nearest City Distance (km)
# 0  SydneyAirport                       1       Sydney          8.49
# 1       Canberra                       1  Tuggeranong         16.36
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable WindSpeed3pm.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable WindSpeed3pm.
# Analizando la variable: Humidity9am
# Resultado del análisis geográfico:
#          Location  Humidity9am NaN Count Nearest City Distance (km)
# 0      Melbourne                      1     Watsonia         15.53
# 1       Canberra                      1  Tuggeranong         16.36
# 2  SydneyAirport                      1       Sydney          8.49
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Humidity9am.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Humidity9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Humidity9am.
# Analizando la variable: Humidity3pm
# Resultado del análisis geográfico:
#          Location  Humidity3pm NaN Count Nearest City Distance (km)
# 0  SydneyAirport                      2       Sydney          8.49
# 1      Melbourne                      1     Watsonia         15.53
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Humidity3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Humidity3pm.
# Analizando la variable: Pressure3pm
# Resultado del análisis geográfico:
#          Location  Pressure3pm NaN Count   Nearest City Distance (km)
# 0         Sydney                      1  SydneyAirport          8.49
# 1  SydneyAirport                      1         Sydney          8.49
# 2      Melbourne                      1       Watsonia         15.53
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable Pressure3pm.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Pressure3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Pressure3pm.
# Analizando la variable: Cloud9am
# Resultado del análisis geográfico:
#          Location  Cloud9am NaN Count   Nearest City Distance (km)
# 0         Albury                 247     WaggaWagga         114.5
# 1       Canberra                 226    Tuggeranong         16.36
# 2         Sydney                   2  SydneyAirport          8.49
# 3  SydneyAirport                   2         Sydney          8.49
# 4      Melbourne                   1       Watsonia         15.53
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 82
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 57
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 57
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 51
# Todos los NaNs fueron reemplazados para Albury en la variable Cloud9am.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 90
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 57
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 23
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 12
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 43
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Sydney en la variable Cloud9am.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 1
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Cloud9am.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Cloud9am.
# Analizando la variable: Cloud3pm
# Resultado del análisis geográfico:
#      Location  Cloud3pm NaN Count Nearest City Distance (km)
# 0   Canberra                 224  Tuggeranong         16.36
# 1     Albury                 221   WaggaWagga         114.5
# 2  Melbourne                   1     Watsonia         15.53
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 109
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 50
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 21
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 17
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 27
# Todos los NaNs fueron reemplazados para Canberra en la variable Cloud3pm.
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 98
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana MountGinini a 178.71 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Tuggeranong a 209.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Canberra a 219.08 km.
# La cantidad de datos reemplazados fue 37
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Sale a 226.6 km.
# La cantidad de datos reemplazados fue 30
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana Watsonia a 244.2 km.
# La cantidad de datos reemplazados fue 56
# Todos los NaNs fueron reemplazados para Albury en la variable Cloud3pm.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable Cloud3pm.
# Analizando la variable: RainToday
# Resultado del análisis geográfico:
#          Location  RainToday NaN Count Nearest City Distance (km)
# 0         Albury                    3   WaggaWagga         114.5
# 1  SydneyAirport                    3       Sydney          8.49
# 2       Canberra                    2  Tuggeranong         16.36
# 3      Melbourne                    1     Watsonia         15.53
# Procesando la localidad: Albury
# Intentando con la ciudad más cercana WaggaWagga a 114.5 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Albury en la variable RainToday.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable RainToday.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Canberra en la variable RainToday.
# Procesando la localidad: Melbourne
# Intentando con la ciudad más cercana Watsonia a 15.53 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Melbourne en la variable RainToday.
# NaN restantes después del procesamiento:
#  Evaporation         9
# Sunshine            7
# Cloud9am            1
# Date                0
# WindSpeed3pm        0
# RainTomorrow        0
# RainToday           0
# Cloud3pm            0
# Pressure3pm         0
# Humidity3pm         0
# Humidity9am         0
# WindDir3pm          0
# WindSpeed9am        0
# Location            0
# WindDir9am          0
# WindGustSpeed       0
# WindGustDir         0
# Rainfall            0
# MaxTemp             0
# MinTemp             0
# RainfallTomorrow    0
# dtype: int64
# Número de filas con al menos un valor NaN: 17

# %%
df_test = procesar_geo_nan(df_test, df_full, dist_matrix, cities_coords, 2000)
# Out:
# Procesando las siguientes columnas: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'RainToday']
# El rango fijado para ciudades cercanas es (km): 2000
# Analizando la variable: MinTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MinTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: MaxTemp
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, MaxTemp NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Rainfall
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Rainfall NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Evaporation
# Resultado del análisis geográfico:
#          Location  Evaporation NaN Count   Nearest City Distance (km)
# 0         Sydney                      3  SydneyAirport          8.49
# 1  SydneyAirport                      3         Sydney          8.49
# 2       Canberra                      3    Tuggeranong         16.36
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana CoffsHarbour a 435.09 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Albury a 462.23 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Moree a 505.15 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cobar a 568.4 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Sale a 600.77 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana GoldCoast a 681.69 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Watsonia a 698.62 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Sydney en la variable Evaporation.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Tuggeranong a 252.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana MountGinini a 281.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana WaggaWagga a 373.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana CoffsHarbour a 443.57 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Albury a 455.31 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Moree a 511.96 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Cobar a 569.1 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sale a 592.59 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana GoldCoast a 690.17 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Watsonia a 691.21 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Evaporation.
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorahHead a 315.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Newcastle a 357.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sale a 364.18 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Williamtown a 370.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Watsonia a 451.8 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Canberra en la variable Evaporation.
# Analizando la variable: Sunshine
# Resultado del análisis geográfico:
#          Location  Sunshine NaN Count   Nearest City Distance (km)
# 0       Canberra                   3    Tuggeranong         16.36
# 1         Sydney                   2  SydneyAirport          8.49
# 2  SydneyAirport                   2         Sydney          8.49
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorahHead a 315.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Newcastle a 357.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sale a 364.18 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Williamtown a 370.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Watsonia a 451.8 km.
# La cantidad de datos reemplazados fue 3
# Todos los NaNs fueron reemplazados para Canberra en la variable Sunshine.
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana SydneyAirport a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana BadgerysCreek a 43.07 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Penrith a 49.45 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Richmond a 52.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Wollongong a 68.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana NorahHead a 73.06 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Newcastle a 117.01 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Williamtown a 130.91 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Canberra a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Tuggeranong a 259.94 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana MountGinini a 289.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana WaggaWagga a 379.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana CoffsHarbour a 435.09 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Albury a 462.23 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Moree a 505.15 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Cobar a 568.4 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Sale a 600.77 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana GoldCoast a 681.69 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Sydney
# Intentando con la ciudad más cercana Watsonia a 698.62 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para Sydney en la variable Sunshine.
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sydney a 8.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana BadgerysCreek a 40.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Penrith a 49.21 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Richmond a 55.3 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Wollongong a 60.05 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana NorahHead a 81.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Newcastle a 125.46 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Williamtown a 139.37 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Canberra a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Tuggeranong a 252.34 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana MountGinini a 281.83 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana WaggaWagga a 373.49 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana CoffsHarbour a 443.57 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Albury a 455.31 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Moree a 511.96 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Cobar a 569.1 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Sale a 592.59 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana GoldCoast a 690.17 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: SydneyAirport
# Intentando con la ciudad más cercana Watsonia a 691.21 km.
# La cantidad de datos reemplazados fue 2
# Todos los NaNs fueron reemplazados para SydneyAirport en la variable Sunshine.
# Analizando la variable: WindGustDir
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindGustDir NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindGustSpeed
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindGustSpeed NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindDir9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindDir9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindDir3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindDir3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindSpeed9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindSpeed9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: WindSpeed3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, WindSpeed3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Humidity9am
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Humidity9am NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Humidity3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Humidity3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Pressure3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Pressure3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: Cloud9am
# Resultado del análisis geográfico:
#     Location  Cloud9am NaN Count Nearest City Distance (km)
# 0  Canberra                   1  Tuggeranong         16.36
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Tuggeranong a 16.36 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana MountGinini a 42.47 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana WaggaWagga a 162.35 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Wollongong a 186.95 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana BadgerysCreek a 214.52 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Albury a 219.08 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Penrith a 222.32 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Richmond a 238.02 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana SydneyAirport a 239.41 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Sydney a 246.85 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana NorahHead a 315.44 km.
# La cantidad de datos reemplazados fue 0
# Procesando la localidad: Canberra
# Intentando con la ciudad más cercana Newcastle a 357.45 km.
# La cantidad de datos reemplazados fue 1
# Todos los NaNs fueron reemplazados para Canberra en la variable Cloud9am.
# Analizando la variable: Cloud3pm
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, Cloud3pm NaN Count, Nearest City, Distance (km)]
# Index: []
# Analizando la variable: RainToday
# Resultado del análisis geográfico:
#  Empty DataFrame
# Columns: [Location, RainToday NaN Count, Nearest City, Distance (km)]
# Index: []
# NaN restantes después del procesamiento:
#  Date                0
# WindSpeed9am        0
# RainTomorrow        0
# RainToday           0
# Cloud3pm            0
# Cloud9am            0
# Pressure3pm         0
# Humidity3pm         0
# Humidity9am         0
# WindSpeed3pm        0
# WindDir3pm          0
# Location            0
# WindDir9am          0
# WindGustSpeed       0
# WindGustDir         0
# Sunshine            0
# Evaporation         0
# Rainfall            0
# MaxTemp             0
# MinTemp             0
# RainfallTomorrow    0
# dtype: int64
# Número de filas con al menos un valor NaN: 0

# %% [markdown]
# #### Transformaciones de variables en los tres conjuntos

# %% [markdown]
# Transformación de WindGustDir, WindDir9am y WindDir3pm

# %% [markdown]
# Se reemplazan las tres variables categóricas en dos nuevas columnas, que indican el seno y coseno para cada variable, considerando a las direcciones de viento como ángulos, siendo N=0°, e incrementando los ángulos en el sentido de las agujas del reloj.

# %%
def calcular_componentes_viento(df, columna):
    direcciones = {
        'N': 0, 'NNE': 22.5, 'NE': 45, 'ENE': 67.5,
        'E': 90, 'ESE': 112.5, 'SE': 135, 'SSE': 157.5,
        'S': 180, 'SSW': 202.5, 'SW': 225, 'WSW': 247.5,
        'W': 270, 'WNW': 292.5, 'NW': 315, 'NNW': 337.5
    }

    # Convertir direcciones a ángulos en radianes
    df[f'Ángulo_{columna}'] = df[columna].map(direcciones) * (np.pi / 180)

    # Calcular componentes de seno y coseno
    df[f'{columna}_sen'] = np.sin(df[f'Ángulo_{columna}'])
    df[f'{columna}_cos'] = np.cos(df[f'Ángulo_{columna}'])

    # Eliminar columnas temporales
    df.drop(columns=[f'Ángulo_{columna}', columna], inplace=True)

    return df

# %%
# Aplicar a train
df_train = calcular_componentes_viento(df_train, 'WindGustDir')
df_train = calcular_componentes_viento(df_train, 'WindDir9am')
df_train = calcular_componentes_viento(df_train, 'WindDir3pm')

# Aplicar a validation
df_val = calcular_componentes_viento(df_val, 'WindGustDir')
df_val = calcular_componentes_viento(df_val, 'WindDir9am')
df_val = calcular_componentes_viento(df_val, 'WindDir3pm')

# Aplicar a test
df_test = calcular_componentes_viento(df_test, 'WindGustDir')
df_test = calcular_componentes_viento(df_test, 'WindDir9am')
df_test = calcular_componentes_viento(df_test, 'WindDir3pm')

# %% [markdown]
# Transformación de Date

# %%
def calcular_componentes_fecha(df, columna_fecha):
    # Convertir a datetime y calcular día del año
    df[columna_fecha] = pd.to_datetime(df[columna_fecha])
    df['Día_del_año'] = df[columna_fecha].dt.dayofyear

    # Calcular ángulos (asumiendo año de 360 días)
    df[f'Ángulo_{columna_fecha}'] = (df['Día_del_año'] / 360) * 360

    # Calcular seno y coseno (en radianes)
    radianes = np.deg2rad(df[f'Ángulo_{columna_fecha}'])
    df[f'{columna_fecha}_sen'] = np.sin(radianes)
    df[f'{columna_fecha}_cos'] = np.cos(radianes)

    # Eliminar columnas intermedias
    df.drop(columns=['Día_del_año', f'Ángulo_{columna_fecha}', columna_fecha], inplace=True)

    return df

# %%
# Aplicar a train
df_train = calcular_componentes_fecha(df_train, 'Date')

# Aplicar a validation
df_val = calcular_componentes_fecha(df_val, 'Date')

# Aplicar a test
df_test = calcular_componentes_fecha(df_test, 'Date')

# %% [markdown]
# Eliminación de Location

# %%
df_train.drop(columns=['Location'], inplace=True)
df_val.drop(columns=['Location'], inplace=True)
df_test.drop(columns=['Location'], inplace=True)

# %% [markdown]
# ### División de datos: X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# Se aplicarán diversos modelos a los datos, los cuales se dividen en:
# * X_train
# * y_train
# * X_val
# * y_val
# * X_test
# * y_test
#
# Se construye la función split para uso general.

# %%
def split(df_train, df_val, df_test, metodo='regresion'):
    if metodo == 'regresion':
        # Conjuntos de entrenamiento
        X_train = df_train.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_train = df_train[['RainfallTomorrow']]

        # Conjunto de validación
        X_val = df_val.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_val = df_val[['RainfallTomorrow']]

        # Conjunto de test
        X_test = df_test.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_test = df_test[['RainfallTomorrow']]

    elif metodo == 'clasificacion':
        # Conjuntos de entrenamiento
        X_train = df_train.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_train = df_train[['RainTomorrow']]

        # Conjunto de validación
        X_val = df_val.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_val = df_val[['RainTomorrow']]

        # Conjunto de test
        X_test = df_test.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_test = df_test[['RainTomorrow']]

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# ### 1.Modelos de regresión lineal

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split(df_train, df_val, df_test, metodo='regresion')

# %%
X_train.shape, X_test.shape, X_val.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((12496, 22), (2677, 22), (2675, 22), (12496, 1), (2675, 1), (2677, 1))

# %% [markdown]
# #### Método de mínimos cuadrados (OLS)

# %%
# Se crea un pipeline para estandarizar los datos y aplicar luego un modelo de regresión lineal
model = make_pipeline(StandardScaler(), LinearRegression())

# %%
#Se ajusta el modelo a los datos de entrenamiento
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
# Se grafican los coeficientes del modelo
df_coeficientes = pd.DataFrame({'predictor': X_train.columns, 'coef': model.steps[1][1].coef_.flatten()})
fig, ax = plt.subplots(figsize=(10, 4))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)
ax.set_xlabel('feature')
ax.set_ylabel('weights')
ax.set_title('Parámetros del modelo')
plt.show()

df_coeficientes[df_coeficientes.coef != 0]
# Out:
#           predictor      coef
# 0           MinTemp -0.685791
# 1           MaxTemp  1.436668
# 2          Rainfall  0.838359
# 3       Evaporation  0.036041
# 4          Sunshine -1.447905
# 5     WindGustSpeed  1.443523
# 6      WindSpeed9am -0.220621
# 7      WindSpeed3pm -0.726146
# 8       Humidity9am -0.260396
# 9       Humidity3pm  2.345417
# 10      Pressure3pm -0.384577
# 11         Cloud9am -0.516820
# 12         Cloud3pm  0.002805
# 13        RainToday  0.071439
# 14  WindGustDir_sen  0.299745
# 15  WindGustDir_cos -0.153348
# 16   WindDir9am_sen  0.194296
# 17   WindDir9am_cos -0.077652
# 18   WindDir3pm_sen -0.061830
# 19   WindDir3pm_cos  0.071246
# 20         Date_sen -0.073716
# 21         Date_cos  0.061702

# %% [markdown]
# Se observa que las variables Humidity3pm, Sunshine, WindGustSpeed  y MaxTemp son las que mayor peso tienen en el modelo.

# %%
# Se guardan las predicciones del modelo
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
y_pred_val = model.predict(X_val)  # Asumiendo que tienes X_val e y_val

# Se calculan los errores RMSE
rmse_ols_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
rmse_ols_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
rmse_ols_val = np.sqrt(mean_squared_error(y_val, y_pred_val))

print(f"RMSE train: {rmse_ols_train}")
print(f"RMSE validación: {rmse_ols_val}")
print(f"RMSE test: {rmse_ols_test}")

# Cálculo de R2
R2_ols_train = metrics.r2_score(y_train, y_pred_train)
R2_ols_test = metrics.r2_score(y_test, y_pred_test)
R2_ols_val = metrics.r2_score(y_val, y_pred_val)

print(f"\nR2 train: {R2_ols_train}")
print(f"R2 validación: {R2_ols_val}")
print(f"R2 test: {R2_ols_test}")
# Out:
# RMSE train: 6.010411602709434
# RMSE validación: 6.0059088646140815
# RMSE test: 6.193535317008064
#
# R2 train: 0.20794010985191902
# R2 validación: 0.23665899232548748
# R2 test: 0.19555371980134084

# %% [markdown]
# Se observa un bajo valor de R2, lo que determina que el modelo no logra explicar correctamente la variabilidad de los datos.

# %% [markdown]
# #### Gradiente descendiente

# %%
# Se convierten dataframes a arrays
y_train = y_train.to_numpy()
y_val = y_val.to_numpy()
y_test = y_test.to_numpy()

# Escalado de features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Se aplica el método del Gradiente Descendiente (GD), con sus variantes Gradiente Descendiente Estocástico (GDE) y Gradiente Descendiente Mini-Batch (GDB).
# No se observan mejoras en los valores de RMSE y R2 obtenidos, en comparación con los de Regresión Lineal.

# %% [markdown]
# ##### Gradiente Descendiente GD

# %%
def gradient_descent(X_train, y_train, X_val, y_val, X_test, y_test, lr=0.01, epochs=100, seed=semilla):
    """
    shapes:
        X_train = nxm
        y_train = nx1
        X_val = qxm
        y_val = qx1
        X_test = pxm
        y_test = px1
        W = mx1
    """

    # Obtener dimensiones de los datos
    n, m = X_train.shape
    q = X_val.shape[0]
    o = X_test.shape[0]

    # Agregar columna de unos (bias) a todos los conjuntos
    X_train = np.hstack((np.ones((n, 1)), X_train))
    X_val = np.hstack((np.ones((q, 1)), X_val))
    X_test = np.hstack((np.ones((o, 1)), X_test))

    # Inicializar pesos
    np.random.seed(seed)
    W = np.random.randn(m + 1).reshape(m + 1, 1)

    # Listas para almacenar métricas
    train_errors = []
    val_errors = []
    test_errors = []

    for i in range(epochs):
        # Cálculo de predicciones para todos los conjuntos
        prediction_train = X_train @ W
        prediction_val = X_val @ W
        prediction_test = X_test @ W

        # Cálculo de errores
        error_train = y_train - prediction_train
        error_val = y_val - prediction_val
        error_test = y_test - prediction_test

        # Almacenar RMSEs
        train_rmse = np.sqrt(np.mean(error_train**2))
        val_rmse = np.sqrt(np.mean(error_val**2))
        test_rmse = np.sqrt(np.mean(error_test**2))

        train_errors.append(train_rmse)
        val_errors.append(val_rmse)
        test_errors.append(test_rmse)

        # Actualización de pesos (solo con train)
        grad = (-2/n) * X_train.T @ error_train
        W -= lr * grad

    # Predicciones finales
    final_train_pred = np.matmul(X_train, W)
    final_val_pred = np.matmul(X_val, W)
    final_test_pred = np.matmul(X_test, W)

    # Métricas finales
    final_metrics = {
        'train_rmse': np.sqrt(np.mean((y_train - final_train_pred)**2)),
        'train_r2': r2_score(y_train, final_train_pred),
        'val_rmse': np.sqrt(np.mean((y_val - final_val_pred)**2)),
        'val_r2': r2_score(y_val, final_val_pred),
        'test_rmse': np.sqrt(np.mean((y_test - final_test_pred)**2)),
        'test_r2': r2_score(y_test, final_test_pred),
        'predictores': W
    }

    # Gráfico actualizado con validación
    plt.figure(figsize=(12, 6))
    plt.plot(train_errors, label='Entrenamiento')
    plt.plot(val_errors, label='Validación', linestyle='--')
    plt.plot(test_errors, label='Test', linestyle=':')
    plt.xlabel('Época')
    plt.ylabel('RMSE')
    plt.title('Evolución de Errores (GD)')
    plt.legend()
    plt.show()

    return final_metrics

# %%
resultados_gd = gradient_descent(
    X_train_scaled, y_train,
    X_val_scaled, y_val,
    X_test_scaled, y_test,
    epochs=500,
    lr=0.02
)

# Extracción de métricas
rmse_gd_train = resultados_gd['train_rmse']
rmse_gd_val = resultados_gd['val_rmse']
rmse_gd_test = resultados_gd['test_rmse']
R2_gd_train = resultados_gd['train_r2']
R2_gd_val = resultados_gd['val_r2']
R2_gd_test = resultados_gd['test_r2']

print("\n=== Métricas Gradiente Descendiente ===")
print(f"- RMSE Train: {rmse_gd_train:.4f}")
print(f"- RMSE Validación: {rmse_gd_val:.4f}")
print(f"- RMSE Test: {rmse_gd_test:.4f}")
print(f"\n- R2 Train: {R2_gd_train:.4f}")
print(f"- R2 Validación: {R2_gd_val:.4f}")
print(f"- R2 Test: {R2_gd_test:.4f}")
# Out:
# === Métricas Gradiente Descendiente ===
# - RMSE Train: 6.0114
# - RMSE Validación: 6.0105
# - RMSE Test: 6.1955
#
# - R2 Train: 0.2077
# - R2 Validación: 0.2355
# - R2 Test: 0.1951

# %% [markdown]
# ##### Gradiente Descendiente Estocástico SGD

# %%
def stochastic_gradient_descent(X_train, y_train, X_val, y_val, X_test, y_test,
                               lr=0.01, epochs=100, n_jobs=-1, seed=semilla):

    # Añadir columna de unos (bias) a las features
    X_train = np.c_[np.ones(X_train.shape[0]), X_train]
    X_val = np.c_[np.ones(X_val.shape[0]), X_val]
    X_test = np.c_[np.ones(X_test.shape[0]), X_test]

    # Inicializar pesos como vector 1D (m+1,)
    np.random.seed(seed)
    W = np.random.randn(X_train.shape[1])

    # Listas para almacenar errores
    train_errors, val_errors, test_errors = [], [], []

    # Función de actualización de pesos
    def update_weights(x, y, weights, lr):
        prediction = np.dot(x, weights)
        error = y - prediction
        gradient = -2 * error * x
        new_weights = weights - (lr * gradient)
        return new_weights, error**2

    # Entrenamiento
    for _ in tqdm(range(epochs), desc='Entrenamiento SGD'):
        # Mezclar datos
        idx = np.random.permutation(X_train.shape[0])
        X_shuffled, y_shuffled = X_train[idx], y_train[idx]

        # Actualización paralela de pesos
        results = Parallel(n_jobs=n_jobs)(
            delayed(update_weights)(X_shuffled[i], y_shuffled[i], W, lr)
            for i in range(X_shuffled.shape[0])
        )

        # Promediar pesos y calcular errores
        weights_list, squared_errors = zip(*results)
        W = np.mean(weights_list, axis=0)  # Vector 1D (m+1,)
        train_rmse = np.sqrt(np.mean(squared_errors))
        train_errors.append(train_rmse)

        # Calcular errores en validación y test
        for X, y, errors in [(X_val, y_val, val_errors), (X_test, y_test, test_errors)]:
            pred = X.dot(W)  # Vector 1D (n,)
            errors.append(np.sqrt(mean_squared_error(y, pred)))

    # Métricas finales
    metrics = {
        'train_rmse': np.sqrt(mean_squared_error(y_train, X_train.dot(W))),
        'train_r2': r2_score(y_train, X_train.dot(W)),
        'val_rmse': np.sqrt(mean_squared_error(y_val, X_val.dot(W))),
        'val_r2': r2_score(y_val, X_val.dot(W)),
        'test_rmse': np.sqrt(mean_squared_error(y_test, X_test.dot(W))),
        'test_r2': r2_score(y_test, X_test.dot(W)),
        'weights': W
    }

    # Gráfico
    plt.figure(figsize=(12, 6))
    plt.plot(train_errors, label='Entrenamiento')
    plt.plot(val_errors, label='Validación', linestyle='--')
    plt.plot(test_errors, label='Test', linestyle=':')
    plt.xlabel('Época')
    plt.ylabel('RMSE')
    plt.title('Evolución de Errores (SGD)')
    plt.legend()
    plt.show()

    return metrics

# %%
resultados_sgd = stochastic_gradient_descent(
    X_train_scaled, y_train,
    X_val_scaled, y_val,
    X_test_scaled, y_test,
    lr=0.02,
    epochs=500
)


# Extracción de métricas
rmse_sgd_train = resultados_sgd['train_rmse']
rmse_sgd_val = resultados_sgd['val_rmse']
rmse_sgd_test = resultados_sgd['test_rmse']
R2_sgd_train = resultados_sgd['train_r2']
R2_sgd_val = resultados_sgd['val_r2']
R2_sgd_test = resultados_sgd['test_r2']

# Imprimir métricas
print("\n=== Métricas Gradiente Descendiente Estocástico ===")
print(f"- RMSE Train: {rmse_sgd_train:.4f}")
print(f"- RMSE Validación: {rmse_sgd_val:.4f}")
print(f"- RMSE Test: {rmse_sgd_test:.4f}")
print(f"\n- R2 Train: {R2_sgd_train:.4f}")
print(f"- R2 Validación: {R2_sgd_val:.4f}")
print(f"- R2 Test: {R2_sgd_test:.4f}")
# Out:
# Entrenamiento SGD: 100%|██████████| 500/500 [13:08<00:00,  1.58s/it]
# === Métricas Gradiente Descendiente Estocástico ===
# - RMSE Train: 6.0114
# - RMSE Validación: 6.0105
# - RMSE Test: 6.1955
#
# - R2 Train: 0.2077
# - R2 Validación: 0.2355
# - R2 Test: 0.1951

# %% [markdown]
# ##### Gradiente Descendiente Mini-Batch

# %%
# Aplanar los arrays y_train, y_val, y_test
y_train = y_train.ravel()  # Convierte (n,1) a (n,)
y_val = y_val.ravel()
y_test = y_test.ravel()

# %%
def mini_batch_gradient_descent(X_train, y_train, X_val, y_val, X_test, y_test,
                               lr=0.01, epochs=100, batch_size=32, seed=semilla):

    # Añadir columna de unos (bias)
    X_train = np.c_[np.ones(X_train.shape[0]), X_train]
    X_val = np.c_[np.ones(X_val.shape[0]), X_val]
    X_test = np.c_[np.ones(X_test.shape[0]), X_test]

    # Inicializar pesos
    np.random.seed(seed)
    W = np.random.randn(X_train.shape[1])

    # Almacenar errores
    train_errors, val_errors, test_errors = [], [], []

    for _ in tqdm(range(epochs), desc='Entrenamiento Mini-batch GD'):
        # Mezclar datos
        idx = np.random.permutation(X_train.shape[0])
        X_shuffled, y_shuffled = X_train[idx], y_train[idx]  # y_shuffled ya es 1D

        # Procesar por mini-lotes
        for i in range(0, X_shuffled.shape[0], batch_size):
            X_batch = X_shuffled[i:i+batch_size]
            y_batch = y_shuffled[i:i+batch_size]  # 1D (batch_size,)

            # Calcular predicción y error
            predictions = X_batch.dot(W)  # 1D (batch_size,)
            error = y_batch - predictions  # 1D - 1D = 1D

            # Calcular gradiente (vectorizado)
            gradient = -2 * X_batch.T.dot(error) / len(y_batch)  # (features+1,)

            # Actualizar pesos
            W -= lr * gradient  # Ambos son 1D

        # Calcular errores después de cada época
        for X, y, errors in [(X_train, y_train, train_errors),
                            (X_val, y_val, val_errors),
                            (X_test, y_test, test_errors)]:
            pred = X.dot(W)
            errors.append(np.sqrt(mean_squared_error(y, pred)))

    # Métricas
    metrics = {
        'train_rmse': np.sqrt(mean_squared_error(y_train, X_train.dot(W))),
        'train_r2': r2_score(y_train, X_train.dot(W)),
        'val_rmse': np.sqrt(mean_squared_error(y_val, X_val.dot(W))),
        'val_r2': r2_score(y_val, X_val.dot(W)),
        'test_rmse': np.sqrt(mean_squared_error(y_test, X_test.dot(W))),
        'test_r2': r2_score(y_test, X_test.dot(W)),
        'weights': W
    }

    # Gráfico
    plt.figure(figsize=(12, 6))
    plt.plot(train_errors, label='Entrenamiento')
    plt.plot(val_errors, label='Validación', linestyle='--')
    plt.plot(test_errors, label='Test', linestyle=':')
    plt.xlabel('Época')
    plt.ylabel('RMSE')
    plt.title('Evolución de Errores (Mini-batch GD)')
    plt.legend()
    plt.show()

    return metrics

# %%
resultados_mbgd = mini_batch_gradient_descent(
    X_train_scaled, y_train,
    X_val_scaled, y_val,
    X_test_scaled, y_test,
    lr=0.01,
    epochs=400,
    batch_size=100)

# Extracción de métricas
rmse_mbgd_train = resultados_mbgd['train_rmse']
rmse_mbgd_val = resultados_mbgd['val_rmse']
rmse_mbgd_test = resultados_mbgd['test_rmse']
R2_mbgd_train = resultados_mbgd['train_r2']
R2_mbgd_val = resultados_mbgd['val_r2']
R2_mbgd_test = resultados_mbgd['test_r2']

print("\n=== Métricas Gradiente Descendiente Mini-Batch ===")
print(f"- RMSE Train: {rmse_mbgd_train:.4f}")
print(f"- RMSE Validación: {rmse_mbgd_val:.4f}")
print(f"- RMSE Test: {rmse_mbgd_test:.4f}")
print(f"\n- R2 Train: {R2_mbgd_train:.4f}")
print(f"- R2 Validación: {R2_mbgd_val:.4f}")
print(f"- R2 Test: {R2_mbgd_test:.4f}")
# Out:
# Entrenamiento Mini-batch GD: 100%|██████████| 400/400 [00:03<00:00, 132.43it/s]
# === Métricas Gradiente Descendiente Mini-Batch ===
# - RMSE Train: 6.0124
# - RMSE Validación: 6.0123
# - RMSE Test: 6.2031
#
# - R2 Train: 0.2074
# - R2 Validación: 0.2350
# - R2 Test: 0.1931

# %% [markdown]
# #### Lasso Regression

# %%
# Creación y entrenamiento del modelo
modelo = make_pipeline(
    StandardScaler(),  # Estandarización de los datos: media 0 y desviación estándar 1
    LassoCV(
        alphas=np.logspace(-10, 10, 200),  # Prueba 200 valores de alpha
        cv=10  # Validación cruzada de 10 folds
    )
)

# Entrenar el modelo con más datos
X_train_full = np.concatenate([X_train, X_val], axis=0)
y_train_full = np.concatenate([y_train, y_val], axis=0)
modelo.fit(X_train_full, y_train_full)

# Predicciones
y_train_full_pred = modelo.predict(X_train_full)
y_test_pred = modelo.predict(X_test)

# Métricas de evaluación
def calcular_metricas(y_real, y_pred):
    mse = mean_squared_error(y_real, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_real, y_pred)
    return rmse, r2

# Calcular métricas
train_lassocv_rmse, train_lassocv_r2 = calcular_metricas(y_train_full, y_train_full_pred)
test_lassocv_rmse, test_lassocv_r2 = calcular_metricas(y_test, y_test_pred)

# Mostrar resultados
print(f"El mejor valor de alpha seleccionado es: {round(modelo.named_steps['lassocv'].alpha_, 6)}") # aproximadamente 10^(-2)
print("Métricas del modelo LassoCV:")
print(f"  - Entrenamiento: RMSE = {train_lassocv_rmse:.4f}, R2 = {train_lassocv_r2:.4f}")
print(f"  - Prueba:        RMSE = {test_lassocv_rmse:.4f}, R2 = {test_lassocv_r2:.4f}")
# Out:
# El mejor valor de alpha seleccionado es: 0.008704
# Métricas del modelo LassoCV:
#   - Entrenamiento: RMSE = 6.0078, R2 = 0.2136
#   - Prueba:        RMSE = 6.1874, R2 = 0.1972

# %% [markdown]
# **Observación:** *¿Qué hace LassoCV?*
#
# Al utilizar cv=10, el modelo divide internamente el conjunto de train en 10 folds para validación cruzada. Prueba todos los valores de alpha en cada combinación de 9 folds para entrenar y 1 fold para validar. Selecciona el mejor alpha basado en el promedio del error (RMSE) de los 10 folds.
#
# Se concatenan `X_train` y `X_val` (y sus targets) para entrenar el modelo final, aprovechando la mayor cantidad de datos disponibles y mejorando su generalización. Las métricas reportadas en prueba reflejan el rendimiento en datos nunca utilizados durante el entrenamiento.

# %%
# Evolución de los parámetros en función de alpha
mod = modelo.named_steps['lassocv']
alphas = mod.alphas_

# Función para ajustar un modelo Lasso con un valor específico de alpha
def fit_lasso(alpha, X_train, y_train):
    modelo_aux = make_pipeline(StandardScaler(), Lasso(alpha=alpha))
    modelo_aux.fit(X_train, y_train)
    return modelo_aux.named_steps['lasso'].coef_.flatten()

# Paralelizar el ajuste de modelos para diferentes valores de alpha
coefs = Parallel(n_jobs=-1)(delayed(fit_lasso)(alpha, X_train_full, y_train_full) for alpha in alphas)

# Graficar la evolución de los coeficientes en función de alpha
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(alphas, coefs, label=X_train.columns)
ax.set_xscale('log')
ax.set_ylim([-0.5, None])
ax.set_xlabel('alpha')
ax.set_ylabel('parámetros')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Leyenda fuera del gráfico
ax.set_title('Coeficientes del modelo en función de la regularización')
plt.tight_layout()
plt.show()

# %%
# Definir la función para contar coeficientes no nulos
def count_non_zero_coefs(alpha, X_train, y_train):
    """
    Ajusta un modelo Lasso con un valor específico de alpha y cuenta los coeficientes no nulos.
    """
    modelo_aux = make_pipeline(StandardScaler(), Lasso(alpha=alpha))
    modelo_aux.fit(X_train, y_train)
    coef_no_cero = np.sum(modelo_aux.named_steps['lasso'].coef_.flatten() != 0)
    return coef_no_cero

# Obtener los valores de alpha usados en LassoCV
alphas = modelo.named_steps['lassocv'].alphas_

# Paralelizar el cálculo del número de predictores no nulos para cada alpha
n_predictores = Parallel(n_jobs=-1)(delayed(count_non_zero_coefs)(alpha, X_train_full, y_train_full) for alpha in alphas)

# Graficar los resultados
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(alphas, n_predictores)
ax.set_xscale('log')  # Escala logarítmica para el eje x (alpha)
ax.set_ylim([-0.5, None])
ax.set_xlabel('alpha')
ax.set_ylabel('Número de predictores')
ax.set_title('Features incluidas en función de la regularización (Lasso)')
plt.show()

# %%
# Calcular el RMSE de validación cruzada (promedio de los folds)
rmse_cv = np.sqrt(mod.mse_path_.mean(axis=1))  # Convertir MSE a RMSE

# Identificar el mejor alpha (el que minimiza el RMSE)
min_rmse = np.min(rmse_cv)  # Menor RMSE
optimo = mod.alphas_[np.argmin(rmse_cv)]  # Alpha óptimo

# Graficar la evolución del RMSE en función de alpha

fig, ax = plt.subplots(figsize=(15,5))
ax.plot(mod.alphas_, rmse_cv)
ax.set_xscale('log')
ax.set_ylim([2,None])
ax.set_title('Evolución del error en función de la regularización Lasso')
ax.set_xlabel('alpha')
ax.set_ylabel('RMSE (CV)')
plt.show()

# Mostrar el valor óptimo de alpha y el RMSE mínimo
print(f"Alpha óptimo: {optimo:.6f}")
print(f"RMSE mínimo (Validación Cruzada): {min_rmse:.4f}")
# Out:
# Alpha óptimo: 0.008704
# RMSE mínimo (Validación Cruzada): 6.0425

# %% [markdown]
# **Observación:** El valor mínimo obtenido de RMSE (6.0425) en cross validation, difiere del RMSE obtenido al evaluar el modelo en el conjunto de train, ya que una vez hallado alpha óptimo, Lasso CV reentrena utilizando todos los datos de train con dicho alpha. Obteniendo así una mejor performance (6.0078).

# %%
# Crear un DataFrame con los coeficientes del modelo
df_coeficientes = pd.DataFrame({
    'predictor': X_train.columns,  # Nombres de las características
    'coef': mod.coef_.flatten()    # Coeficientes del modelo Lasso
})

# Graficar los coeficientes
fig, ax = plt.subplots(figsize=(15, 5))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)  # Rotar etiquetas del eje x
ax.set_xlabel('Feature')
ax.set_ylabel('Coeficiente')
ax.set_title('Coeficientes del modelo Lasso')
plt.show()

# Filtrar coeficientes no nulos
coeficientes_no_nulos = df_coeficientes[df_coeficientes.coef != 0]
print("Coeficientes no nulos:")
print(coeficientes_no_nulos)
# Out:
# Coeficientes no nulos:
#           predictor      coef
# 0           MinTemp -0.708239
# 1           MaxTemp  1.417345
# 2          Rainfall  0.830488
# 3       Evaporation  0.067993
# 4          Sunshine -1.399093
# 5     WindGustSpeed  1.552170
# 6      WindSpeed9am -0.227827
# 7      WindSpeed3pm -0.804514
# 8       Humidity9am -0.243847
# 9       Humidity3pm  2.311099
# 10      Pressure3pm -0.400609
# 11         Cloud9am -0.410957
# 13        RainToday  0.102887
# 14  WindGustDir_sen  0.232297
# 15  WindGustDir_cos -0.156819
# 16   WindDir9am_sen  0.215065
# 17   WindDir9am_cos -0.123296
# 18   WindDir3pm_sen -0.026617
# 19   WindDir3pm_cos  0.071697
# 20         Date_sen -0.047659

# %% [markdown]
# #### Ridge Regression

# %%
# Generar valores de alpha desde 10^-5 hasta 10^10
alphas = np.logspace(-5, 10, 200)

# Crear el modelo RidgeCV con los alphas definidos
modelo = make_pipeline(
    StandardScaler(), # Estandarización de los datos: media 0 y desviación estándar 1
    RidgeCV(alphas=alphas, cv=10)
)

# Entrenar el modelo
modelo.fit(X_train_full, y_train_full)

# Obtener los alphas usados (son los mismos que se pasaron)
alphas_used = modelo.named_steps['ridgecv'].alphas
coefs = []

# Ajustar modelos para cada alpha y guardar coeficientes
for alpha in alphas_used:
    modelo_aux = make_pipeline(StandardScaler(), Ridge(alpha=alpha))
    modelo_aux.fit(X_train_full, y_train_full)
    coefs.append(modelo_aux.named_steps['ridge'].coef_.flatten())

# Graficar
fig, ax = plt.subplots(figsize=(15, 8))
for i, col in enumerate(X_train.columns):
    ax.plot(alphas_used, [coef[i] for coef in coefs], label=col)

# Configurar ejes para cubrir hasta 10^10
ax.set_xscale('log')
ax.set_xlim([1e-5, 1e10]) # Límites manuales del eje x
ax.set_xlabel('Alphas')
ax.set_ylabel('Coeficientes')
ax.set_title('Coeficientes del modelo en función de la regularización (Ridge)')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Predicciones
y_train_full_pred = modelo.predict(X_train_full)
y_test_pred = modelo.predict(X_test)

# Métricas de evaluación
def calcular_metricas(y_real, y_pred):
    mse = mean_squared_error(y_real, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_real, y_pred)
    return rmse, r2

# Calcular métricas
train_ridgecv_rmse, train_ridgecv_r2 = calcular_metricas(y_train_full, y_train_full_pred)
test_ridgecv_rmse, test_ridgecv_r2 = calcular_metricas(y_test, y_test_pred)

# Mostrar resultados
print(f"El mejor valor de alpha seleccionado es: {round(modelo.named_steps['ridgecv'].alpha_, 6)}") # aproximadamente 10^(-2)
print("Métricas del modelo RidgeCV:")
print(f"  - Entrenamiento: RMSE = {train_ridgecv_rmse:.4f}, R2 = {train_ridgecv_r2:.4f}")
print(f"  - Prueba:        RMSE = {test_ridgecv_rmse:.4f}, R² = {test_ridgecv_r2:.4f}")
# Out:
# El mejor valor de alpha seleccionado es: 243.744415
# Métricas del modelo RidgeCV:
#   - Entrenamiento: RMSE = 6.0088, R2 = 0.2134
#   - Prueba:        RMSE = 6.1905, R² = 0.1963

# %%
# Crear un DataFrame con los coeficientes del modelo
df_coeficientes = pd.DataFrame({
    'predictor': X_train.columns,  # Nombres de las características
    'coef': mod.coef_.flatten()    # Coeficientes del modelo Lasso
})

# Graficar los coeficientes
fig, ax = plt.subplots(figsize=(15, 5))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)  # Rotar etiquetas del eje x
ax.set_xlabel('Feature')
ax.set_ylabel('Coeficiente')
ax.set_title('Coeficientes del modelo Ridge')
plt.show()

# Filtrar coeficientes no nulos
coeficientes_no_nulos = df_coeficientes[df_coeficientes.coef != 0]
print("Coeficientes no nulos:")
print(coeficientes_no_nulos)
# Out:
# Coeficientes no nulos:
#           predictor      coef
# 0           MinTemp -0.708239
# 1           MaxTemp  1.417345
# 2          Rainfall  0.830488
# 3       Evaporation  0.067993
# 4          Sunshine -1.399093
# 5     WindGustSpeed  1.552170
# 6      WindSpeed9am -0.227827
# 7      WindSpeed3pm -0.804514
# 8       Humidity9am -0.243847
# 9       Humidity3pm  2.311099
# 10      Pressure3pm -0.400609
# 11         Cloud9am -0.410957
# 13        RainToday  0.102887
# 14  WindGustDir_sen  0.232297
# 15  WindGustDir_cos -0.156819
# 16   WindDir9am_sen  0.215065
# 17   WindDir9am_cos -0.123296
# 18   WindDir3pm_sen -0.026617
# 19   WindDir3pm_cos  0.071697
# 20         Date_sen -0.047659

# %% [markdown]
# #### ElasticNet

# %% [markdown]
# Nota: l1_ratio es un parámetro en el modelo de regresión ElasticNet que controla la proporción entre la penalización L1 (norma Lasso) y la penalización L2 (norma Ridge). Cuando l1_ratio es 0, ElasticNet se comporta como una regresión Ridge, y cuando l1_ratio es 1, se comporta como una regresión Lasso.

# %%
# Creación y entrenamiento del modelo
modelo = make_pipeline(
    StandardScaler(),  # Estandarización de los datos
    ElasticNetCV(
        l1_ratio=[0, 0.1, 0.5, 0.7, 0.9, 0.95, 0.99],  # Rangos de mezcla L1/L2
        alphas=np.logspace(-10, 10, 200),  # 200 valores de regularización
        cv=10
    )
)

# Entrenar el modelo
modelo.fit(X_train_full, y_train_full)

# Obtener el modelo entrenado
mod = modelo.named_steps['elasticnetcv']

# Mejores parámetros encontrados
print("═"*50)
print(f"Mejor valor de alpha encontrado: {mod.alpha_:.6f}")
print(f"Mejor valor de l1_ratio encontrado: {mod.l1_ratio_:.4f}")
print("═"*50)

# Predicciones
y_train_full_pred = modelo.predict(X_train_full)
y_test_pred = modelo.predict(X_test)

# Función para cálculo de métricas
def calcular_metricas(y_real, y_pred):
    mse = mean_squared_error(y_real, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_real, y_pred)
    return rmse, r2

# Cálculo de métricas
train_elasticnetcv_rmse, train_elasticnetcv_r2 = calcular_metricas(y_train_full, y_train_full_pred)
test_elasticnetcv_rmse, test_elasticnetcv_r2 = calcular_metricas(y_test, y_test_pred)

# Resultados
print("═"*50)
print("Métricas del modelo ElasticNetCV:")
print(f"  - Entrenamiento: RMSE = {train_elasticnetcv_rmse:.4f} | R2 = {train_elasticnetcv_r2:.4f}")
print(f"  - Prueba:        RMSE = {test_elasticnetcv_rmse:.4f} | R2 = {test_elasticnetcv_r2:.4f}")
print("═"*50)
# Out:
# ══════════════════════════════════════════════════
# Mejor valor de alpha encontrado: 0.008704
# Mejor valor de l1_ratio encontrado: 0.9900
# ══════════════════════════════════════════════════
# ══════════════════════════════════════════════════
# Métricas del modelo ElasticNetCV:
#   - Entrenamiento: RMSE = 6.0078 | R2 = 0.2136
#   - Prueba:        RMSE = 6.1874 | R2 = 0.1972
# ══════════════════════════════════════════════════

# %%
# Coeficientes del modelo ElasticNetCV
df_coeficientes = pd.DataFrame({
    'predictor': X_train.columns, # Nombres de las características
    'coef': mod.coef_.flatten()  # Acceder a los coeficientes del modelo
})

# Gráfico de coeficientes
fig, ax = plt.subplots(figsize=(15, 5))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)
ax.set_xlabel('Feature')
ax.set_ylabel('Coeficiente')
ax.set_title('Coeficientes del modelo ElasticNetCV')
#plt.tight_layout()
plt.show()

print("Características relevantes (coeficientes != 0):")
coeficientes_no_nulos = df_coeficientes[df_coeficientes.coef != 0]
print(coeficientes_no_nulos)
# Out:
# Características relevantes (coeficientes != 0):
#           predictor      coef
# 0           MinTemp -0.707960
# 1           MaxTemp  1.416834
# 2          Rainfall  0.830443
# 3       Evaporation  0.068152
# 4          Sunshine -1.399167
# 5     WindGustSpeed  1.552012
# 6      WindSpeed9am -0.227943
# 7      WindSpeed3pm -0.804491
# 8       Humidity9am -0.243912
# 9       Humidity3pm  2.310811
# 10      Pressure3pm -0.400709
# 11         Cloud9am -0.411054
# 13        RainToday  0.103054
# 14  WindGustDir_sen  0.232482
# 15  WindGustDir_cos -0.157034
# 16   WindDir9am_sen  0.215127
# 17   WindDir9am_cos -0.123350
# 18   WindDir3pm_sen -0.026784
# 19   WindDir3pm_cos  0.071966
# 20         Date_sen -0.047715

# %% [markdown]
# #### Resumen: Modelos de Regresión

# %% [markdown]
# Se confecciona una tabla comparativa con los distintos modelos aplicados.

# %%
df_comparacion_reg = pd.DataFrame({
    'Modelo': ['OLS', 'GD', 'SGD', 'GDMB', 'Ridge', 'Lasso', 'Elastic-net'],

    'Train RMSE': [rmse_ols_train, rmse_gd_train, rmse_sgd_train, rmse_mbgd_train, train_lassocv_rmse, train_ridgecv_rmse, train_elasticnetcv_rmse],
    'Val RMSE': [rmse_ols_val, rmse_gd_val, rmse_sgd_val, rmse_mbgd_val, np.nan, np.nan, np.nan],
    'Test RMSE': [rmse_ols_test, rmse_gd_test, rmse_sgd_test, rmse_mbgd_test, test_lassocv_rmse, test_ridgecv_rmse, test_elasticnetcv_rmse],

    'Train R2': [R2_ols_train, R2_gd_train, R2_sgd_train, R2_mbgd_train, train_lassocv_r2, train_ridgecv_r2, train_elasticnetcv_r2],
    'Val R2': [R2_ols_val, R2_gd_val, R2_sgd_val, R2_mbgd_val, np.nan, np.nan, np.nan],
    'Test R2': [R2_ols_test, R2_gd_test, R2_sgd_test, R2_mbgd_test, test_lassocv_r2, test_ridgecv_r2, test_elasticnetcv_r2]
})

# Mostrar el DataFrame
df_comparacion_reg
# Out:
#         Modelo  Train RMSE  Val RMSE  Test RMSE  Train R2    Val R2   Test R2
# 0          OLS    6.010412  6.005909   6.193535  0.207940  0.236659  0.195554
# 1           GD    6.011354  6.010504   6.195455  0.207692  0.235491  0.195055
# 2          SGD    6.011354  6.010504   6.195455  0.207692  0.235491  0.195055
# 3         GDMB    6.012450  6.012347   6.203139  0.207403  0.235022  0.193057
# 4        Ridge    6.007773       NaN   6.187358  0.213638       NaN  0.197158
# 5        Lasso    6.008794       NaN   6.190489  0.213371       NaN  0.196345
# 6  Elastic-net    6.007772       NaN   6.187378  0.213638       NaN  0.197152

# %% [markdown]
# **Insights obtenidos**
#
# **Rendimiento general en datos no vistos:**
#
# Ridge tiene el mejor RMSE en test (6.187), seguido por Elastic-Net.
# Estos son los modelos que generalizan *ligeramente* mejor.
#
# R2 en test es consistentemente bajo (~0.193–0.197) para todos los modelos, indicando que ningún modelo captura significativamente la varianza de los datos. Esto podría deberse a un subajuste (underfitting) por limitaciones del modelo lineal.
#
# **Sobreajuste (Overfitting):**
#
# La regularización (Ridge, Lasso, Elastic-net) no reduce *drásticamente* el error en test, lo que indica que el modelo lineal básico (OLS) ya es suficientemente simple para estos datos.
#
# **Validación Cruzada vs Conjunto de Validación:**
#
# Ridge, Lasso y Elastic-net no tienen métricas de validación porque usan validación cruzada interna (CV). El conjunto de validación original se fusionó con el de entrenamiento para maximizar los datos disponibles.
#
# Aún no se hizo uso del conjunto de validación para la optimización de hiperparámetros. Sí se corrieron modelos aplicando regularización con cross validation y la mejora fue mínima.
#
# **Limitaciones:**
#
# Los modelos explican sólo ~20% de la varianza, lo que indica que el problema puede requerir enfoques no lineales o más variables predictoras.

# %% [markdown]
# ### 2.Modelos de Regresión Logística

# %% [markdown]
# **Nota:** Las soluciones que se explorarán en adelante no contemplarán conjunto de validación, por una cuestión de escasez de tiempos.

# %%
df_train = pd.concat([df_train, df_val], axis=0)

# %%
#df_train.shape #(15171, 24)
#df_test.shape #(2677, 24)

# %% [markdown]
# Como se vio anteriormente existe un desbalance entre las clases RainTomorrow=True (llueve) y RainTomorrow=False (no llueve).

# %%
# Contar el número de ocurrencias de cada categoría en la columna 'RainTomorrow'
conteo_categorias = df_train['RainTomorrow'].value_counts() # False 11800 vs. True 3371

# Calcular la proporción de cada categoría
proporcion_no = round(conteo_categorias[0] / len(df_train), 2)
proporcion_yes = round(conteo_categorias[1] / len(df_train), 2)
print("Proporción de 'RainTomorrow' igual a 0 (No):", proporcion_no)
print("Proporción de 'RainTomorrow' igual a 1 (Yes):", proporcion_yes)
# Out:
# Proporción de 'RainTomorrow' igual a 0 (No): 0.78
# Proporción de 'RainTomorrow' igual a 1 (Yes): 0.22

# %% [markdown]
# Se observa que para el conjunto de test, el valor rtest es similiar a rtrain, lo cual es un buen indicador de que el desbalance de las clases se mantiene en la misma proporción.
# Si bien no se deberían ver los valores del conjunto de test, es una buena práctica hacer este chequeo para no incurrir en errores de predicción.

# %%
conteo_categorias = df_train['RainTomorrow'].value_counts()
rtrain=conteo_categorias[0] /conteo_categorias[1]
print("Relación entre clases rtrain:", rtrain)
# Out:
# Relación entre clases rtrain: 3.5004449718184514

# %%
conteo_categorias = df_test['RainTomorrow'].value_counts()
rtest=conteo_categorias[0] /conteo_categorias[1]
print("Relación entre clases rtest:", rtest)
# Out:
# Relación entre clases rtest: 3.2357594936708862

# %% [markdown]
# Se entrenan modelos de regresión logística (previa estandarización de los datos) y se imprimen las matrices de confusión.
#
# Accuracy no será tenida en cuenta ya que no presenta buenos resultados ante conjuntos de datos con clases desbalanceadas.
#
# Convenciones:
# * Caso positivo significa que llueve
# * Orden de los valores en la matriz de confusión: [[TN , FN] , [FP , TP]]

# %%
def matriz_conf (y_test,y_pred):
    plt.figure(figsize=(6, 5))
    sns.heatmap(confusion_matrix(y_pred, y_test), annot=True, cmap="Blues", fmt="d", xticklabels=["No llueve", "Llueve"], yticklabels=["No llueve", "Llueve"]).set(title='Matriz de Confusión', xlabel='Valores reales', ylabel='Valores predichos')
    return plt.show()

# %% [markdown]
# Se crean los conjuntos de datos para entrenamiento y testeo:
# * X_train
# * y_train
# * X_test
# * y_test

# %%
def split(df_train, df_test, metodo='clasificacion'):
    if metodo == 'regresion':
        # Conjuntos de entrenamiento
        X_train = df_train.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_train = df_train[['RainfallTomorrow']]

        # Conjunto de test
        X_test = df_test.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_test = df_test[['RainfallTomorrow']]

    elif metodo == 'clasificacion':
        # Conjuntos de entrenamiento
        X_train = df_train.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_train = df_train[['RainTomorrow']]

        # Conjunto de test
        X_test = df_test.drop(['RainTomorrow', 'RainfallTomorrow'], axis=1)
        y_test = df_test[['RainTomorrow']]

    return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = split(df_train, df_test)

# %%
# Define el modelo de regresión logística
logreg = make_pipeline(
    StandardScaler(),
    LogisticRegression(random_state=semilla, class_weight='balanced') # por defecto usa penalty=l2
)

# Entrenamiento del modelo
logreg.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = logreg.predict(X_test)

# Mostrar la matriz de confusión
conf_matrix = matriz_conf(y_test, y_pred)

# Mostrar reporte de clasificación
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.77      0.84      2045
#          1.0       0.51      0.76      0.61       632
#
#     accuracy                           0.77      2677
#    macro avg       0.71      0.77      0.72      2677
# weighted avg       0.82      0.77      0.78      2677

# %% [markdown]
# De los días que no llovió, el modelo identifica correctamente el 77% de los casos. De forma similar, identifica correctamente el 76% de los días que llovió.

# %% [markdown]
# Se prueba otro modelo utilizando para el entrenamiento un conjunto oversampleado, lo que quiere decir que se incrementa el número de registros de la clase minoritaria para balancear el conjunto de datos de entrenamiento.

# %%
# Aplicar oversampling al conjunto de entrenamiento
oversampler = RandomOverSampler(random_state=semilla)
X_train_ovs, y_train_ovs = oversampler.fit_resample(X_train, y_train)

# %%
# Antes del oversampleo tenía 11800 False vs. 3371 True
# Verificar la distribución de clases en y_train
print("Distribución de clases después del oversampling:")
print(np.unique(y_train_ovs, return_counts=True))

# Verificar las dimensiones de X_train
print("\nDimensiones de X_train después del oversampling:")
print(X_train_ovs.shape)
# Out:
# Distribución de clases después del oversampling:
# (array([False,  True]), array([11800, 11800]))
#
# Dimensiones de X_train después del oversampling:
# (23600, 22)

# %%
# Define el modelo de regresión logística
logreg_ovs = make_pipeline(
    StandardScaler(),
    LogisticRegression(random_state=semilla)
)

# Entrenamiento del modelo
logreg_ovs.fit(X_train_ovs, y_train_ovs)

# Realizar predicciones en el conjunto de prueba
y_pred = logreg_ovs.predict(X_test)

# Mostrar la matriz de confusión
conf_matrix = matriz_conf(y_test, y_pred)

# Mostrar reporte de clasificación
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.78      0.84      2045
#          1.0       0.51      0.76      0.61       632
#
#     accuracy                           0.77      2677
#    macro avg       0.71      0.77      0.72      2677
# weighted avg       0.82      0.77      0.78      2677

# %% [markdown]
# Se observa una mejora marginal, al aumentar TP en 1 y TN en 6. Las métricas no varían en comparación con el modelo anterior que utiliza la ponderación de clases.

# %% [markdown]
# #### Optimización del umbral

# %% [markdown]
# Se selecciona el modelo de regresión logística logreg_ovs con oversampling para la clase minoritaria para continuar con el análisis de optimización de umbral.

# %% [markdown]
# **Hasta aquí el entrenamiento de los modelos fue con un valor de umbral por defecto de 0.5.**
#
# Se grafica la curva ROC para el modelo logreg_ovs.

# %%
# Obtener las probabilidades de predicción para la clase positiva
y_pred_proba = logreg_ovs.predict_proba(X_test)[:, 1]

# Calcular la curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calcular el área bajo la curva ROC (AUC)
roc_auc = roc_auc_score(y_test, y_pred_proba)

# Graficar la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Curva ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2, label='Clasificador aleatorio')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Se utiliza la curva ROC para identificar un valor de umbral que permita una combinación de valores para TPR y FPR más adecuada.

# %%
y_pred_proba = logreg_ovs.predict_proba(X_test)[:, 1]
fpr, tpr, umbral = roc_curve(y_test, y_pred_proba)
target_tpr = 0.8

# Buscamos el índice del valor más cercano a target_tpr en el array de TPR
index = np.argmax(tpr >= target_tpr)
umbral_asociado = umbral[index]
fpr_asociado = fpr[index]
tpr_asociado = tpr[index]
print("TPR utilizado:", tpr_asociado)
print("Umbral elegido:", umbral_asociado)

#Se utiliza el umbral calculado para obtener las nuevas predicciones:
y_pred = (y_pred_proba >= umbral_asociado).astype(int)

# Mostrar la matriz de confusión
conf_matrix = matriz_conf(y_test, y_pred)

# Mostrar reporte de clasificación
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# TPR utilizado: 0.8006329113924051
# Umbral elegido: 0.44301487620164637
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.73      0.82      2045
#          1.0       0.48      0.80      0.60       632
#
#     accuracy                           0.75      2677
#    macro avg       0.70      0.77      0.71      2677
# weighted avg       0.82      0.75      0.76      2677

# %% [markdown]
# #### Resumen: Modelos de Clasificación

# %% [markdown]
# Se confeccciona una tabla comparativa con los distintos modelos aplicados.

# %%
# Crear el DataFrame con los modelos y sus métricas
df_comparacion_logreg = pd.DataFrame({
    'Modelo': ['LogReg_Balanceado', 'LogReg_OverSamp', 'LogReg_OverSamp_Umbral'],
    'Umbral': [0.5, 0.5, umbral_asociado],
    'TPR': ['0.759', '0.759', '0.8']
})

# Mostrar el DataFrame
df_comparacion_logreg
# Out:
#                    Modelo    Umbral    TPR
# 0       LogReg_Balanceado  0.500000  0.759
# 1         LogReg_OverSamp  0.500000  0.759
# 2  LogReg_OverSamp_Umbral  0.443015    0.8

# %% [markdown]
# **Insights obtenidos**
#
# El objetivo es predecir correctamente los días de lluvia, por eso se elige el modelo con umbral optimizado. Este último permite al modelo incrementar la detección correcta de días lluviosos a costa de una mayor tasa de falsos positivos.
#
# El supuesto base es que es más caro que llueva y no estar preparados, versus a estar preparados y que no llueva.

# %% [markdown]
# ### 3.Redes neuronales

# %% [markdown]
# #### Entrenamiento de modelos para Clasificación y Regresión

# %% [markdown]
# Se entrenan redes neuronales para resolver los problemas de regresión y clasificación. Se definen previamente las siguientes funciones:

# %%
# Función para la fijación de la semilla
def set_seed(seed=semilla):
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)

set_seed()

# %%
def recall_min(y_true, y_pred):
    y_true = tf.cast(y_true, tf.int32)
    y_pred = tf.round(y_pred)
    y_pred = tf.cast(y_pred, tf.int32)

    y_true = tf.squeeze(y_true)
    y_pred = tf.squeeze(y_pred)

    unique_labels, _, unique_count = tf.unique_with_counts(y_true)

    def class_recall(cls):
        cls_true = tf.cast(tf.equal(y_true, cls), tf.float32)
        cls_pred = tf.cast(tf.equal(y_pred, cls), tf.float32)
        recall = tf.reduce_sum(cls_true * cls_pred) / (tf.reduce_sum(cls_true) + tf.keras.backend.epsilon())
        return recall

    recalls = tf.map_fn(class_recall, unique_labels, dtype=tf.float32)
    min_recall = tf.reduce_min(recalls)
    return min_recall

# %%
# Crear y entrenar el modelo final con los mejores hiperparámetros
def create_best_model(best_params, metodo='clasificacion'):
    num_layers = best_params['num_layers']
    epochs = best_params['epochs']
    batch_size = best_params['batch_size']
    optimizer = best_params.get('optimizer', 'adam')

    if metodo == 'clasificacion':
        loss = BinaryCrossentropy()
        metrics = [recall_min]
        output_units = best_params.get('output_units', 1)
        output_activation = 'sigmoid'
    elif metodo == 'regresion':
        loss = MeanSquaredError()
        metrics = [MSE()]
        output_units = best_params.get('output_units', 1)
        output_activation = 'linear'
    else:
        raise ValueError("problem_type debe ser 'clasificacion' o 'regresion'")

    model = Sequential()
    for i in range(num_layers):
        num_units = best_params[f'n_units_layer_{i}']
        dropout_rate = best_params[f'dropout_rate_layer_{i}']
        model.add(Dense(num_units, activation='relu'))
        model.add(Dropout(dropout_rate))

    model.add(Dense(output_units, activation=output_activation))

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    return model, epochs, batch_size

# %%
# Función general para el entrenamiento de redes neuronales
def nn_model(X_train, y_train, X_test, y_test, metodo='clasificacion'):
    set_seed(50)

    if metodo=='clasificacion':
        direccion='maximize'
    elif metodo=='regresion':
        direccion='minimize'

    # Crear un estudio de Optuna
    study = optuna.create_study(direction=direccion, sampler=optuna.samplers.TPESampler(seed=50))
    if metodo == 'clasificacion':
        study.optimize(objective_clasificador, n_trials=10)
    elif metodo == 'regresion':
        study.optimize(objective_regresor, n_trials=10)
    # Obtener los mejores hiperparámetros
    best_params = study.best_params

    # Crear y entrenar el modelo final
    best_model, best_epochs, best_batch_size = create_best_model(best_params,metodo)
    best_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=best_epochs, batch_size=best_batch_size, verbose=1)

    return best_model, study

# %% [markdown]
# La optimización de hiperparámetros se realiza con Optuna. Este método se elige por sobre Grid Search y Random Search por ser el más eficiente de los tres.

# %% [markdown]
# #### Resolución del problema de Clasificación

# %%
def objective_clasificador(trial):
    set_seed()
    num_layers = trial.suggest_int('num_layers', 1, 3)
    model = Sequential()
    for i in range(num_layers):
        num_units = trial.suggest_int(f'n_units_layer_{i}', 10, 100) # la cantidad de neuronas de cada capa tambien se puede pasar como hiperparámetro
        # activations = trial.suggest_categorical(f'')
        model.add(Dense(num_units, activation='relu')) # capas densas con activacion ReLU
        dropout_rate = trial.suggest_float(f'dropout_rate_layer_{i}', 0.4, 0.6)
        model.add(Dropout(dropout_rate))
    # capa de salida
    model.add(Dense(1, activation='sigmoid'))
    # compilar
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[recall_min])
    # entrenar
    epochs = trial.suggest_int('epochs', 10, 100)
    batch_size = trial.suggest_int('batch_size', 2048, 2048)
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1)
    # evaluar
    score = model.evaluate(X_test, y_test, verbose=0)
    return score[1]

# %%
X_train, y_train, X_test, y_test = split(df_train, df_test,'clasificacion')
oversampler = RandomOverSampler(random_state=42)
X_train, y_train = oversampler.fit_resample(X_train, y_train)
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
y_train = y_train.astype(float)
y_test = y_test.astype(float)
best_model_nn_clas, study = nn_model(X_train, y_train,X_test, y_test,'clasificacion')
# Out:
# [I 2025-02-23 20:52:46,375] A new study created in memory with name: no-name-6c6a6a82-4c9c-4898-aa02-ad614fb9e405
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/deprecation.py:660: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.8559 - recall_min: 0.4071 - val_loss: 0.6848 - val_recall_min: 0.4884
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7278 - recall_min: 0.5169 - val_loss: 0.6092 - val_recall_min: 0.5386
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6625 - recall_min: 0.6045 - val_loss: 0.5684 - val_recall_min: 0.5697
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6116 - recall_min: 0.6552 - val_loss: 0.5482 - val_recall_min: 0.5965
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5866 - recall_min: 0.6928 - val_loss: 0.5354 - val_recall_min: 0.6157
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5678 - recall_min: 0.6990 - val_loss: 0.5249 - val_recall_min: 0.6136
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5567 - recall_min: 0.7160 - val_loss: 0.5156 - val_recall_min: 0.6095
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5441 - recall_min: 0.7253 - val_loss: 0.5122 - val_recall_min: 0.6042
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5408 - recall_min: 0.7329 - val_loss: 0.5090 - val_recall_min: 0.6220
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5310 - recall_min: 0.7350 - val_loss: 0.5088 - val_recall_min: 0.6183
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5184 - recall_min: 0.7410 - val_loss: 0.5035 - val_recall_min: 0.6196
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5240 - recall_min: 0.7415 - val_loss: 0.5000 - val_recall_min: 0.6277
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5178 - recall_min: 0.7398 - val_loss: 0.4969 - val_recall_min: 0.6287
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5140 - recall_min: 0.7493 - val_loss: 0.4957 - val_recall_min: 0.6230
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5110 - recall_min: 0.7518 - val_loss: 0.4964 - val_recall_min: 0.6220
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5052 - recall_min: 0.7553 - val_loss: 0.4937 - val_recall_min: 0.6239
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5035 - recall_min: 0.7602 - val_loss: 0.4911 - val_recall_min: 0.6320
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4991 - recall_min: 0.7562 - val_loss: 0.4897 - val_recall_min: 0.6330
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4977 - recall_min: 0.7592 - val_loss: 0.4888 - val_recall_min: 0.6333
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4969 - recall_min: 0.7622 - val_loss: 0.4884 - val_recall_min: 0.6340
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4953 - recall_min: 0.7604 - val_loss: 0.4851 - val_recall_min: 0.6359
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4904 - recall_min: 0.7602 - val_loss: 0.4840 - val_recall_min: 0.6369
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4874 - recall_min: 0.7672 - val_loss: 0.4845 - val_recall_min: 0.6376
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4912 - recall_min: 0.7653 - val_loss: 0.4858 - val_recall_min: 0.6332
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4873 - recall_min: 0.7657 - val_loss: 0.4843 - val_recall_min: 0.6345
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4823 - recall_min: 0.7703 - val_loss: 0.4841 - val_recall_min: 0.6342
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4822 - recall_min: 0.7667 - val_loss: 0.4847 - val_recall_min: 0.6389
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4825 - recall_min: 0.7669 - val_loss: 0.4839 - val_recall_min: 0.6453
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4515 - recall_min: 0.7755 - val_loss: 0.4666 - val_recall_min: 0.6738
# [I 2025-02-23 20:53:10,898] Trial 0 finished with value: 0.6337922811508179 and parameters: {'num_layers': 2, 'n_units_layer_0': 30, 'dropout_rate_layer_0': 0.45109478475144227, 'n_units_layer_1': 46, 'dropout_rate_layer_1': 0.4754630195382248, 'epochs': 100, 'batch_size': 2048}. Best is trial 0 with value: 0.6337922811508179.
# Epoch 1/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.7772 - recall_min: 0.4232 - val_loss: 0.5754 - val_recall_min: 0.5696
# Epoch 2/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6455 - recall_min: 0.6248 - val_loss: 0.5294 - val_recall_min: 0.5722
# Epoch 3/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5953 - recall_min: 0.6770 - val_loss: 0.5211 - val_recall_min: 0.6012
# Epoch 4/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5674 - recall_min: 0.7040 - val_loss: 0.5122 - val_recall_min: 0.6042
# Epoch 5/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5463 - recall_min: 0.7209 - val_loss: 0.5012 - val_recall_min: 0.6105
# Epoch 6/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5347 - recall_min: 0.7329 - val_loss: 0.4986 - val_recall_min: 0.6232
# Epoch 7/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5231 - recall_min: 0.7370 - val_loss: 0.4966 - val_recall_min: 0.6330
# Epoch 8/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5173 - recall_min: 0.7452 - val_loss: 0.4911 - val_recall_min: 0.6363
# Epoch 9/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5145 - recall_min: 0.7445 - val_loss: 0.4849 - val_recall_min: 0.6339
# Epoch 10/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5058 - recall_min: 0.7523 - val_loss: 0.4827 - val_recall_min: 0.6399
# Epoch 11/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5026 - recall_min: 0.7561 - val_loss: 0.4830 - val_recall_min: 0.6386
# Epoch 12/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4981 - recall_min: 0.7565 - val_loss: 0.4787 - val_recall_min: 0.6460
# Epoch 13/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4948 - recall_min: 0.7582 - val_loss: 0.4748 - val_recall_min: 0.6553
# Epoch 14/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4900 - recall_min: 0.7649 - val_loss: 0.4744 - val_recall_min: 0.6530
# Epoch 15/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4825 - recall_min: 0.7683 - val_loss: 0.4781 - val_recall_min: 0.6500
# Epoch 16/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4872 - recall_min: 0.7636 - val_loss: 0.4736 - val_recall_min: 0.6523
# Epoch 17/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4839 - recall_min: 0.7660 - val_loss: 0.4708 - val_recall_min: 0.6463
# Epoch 18/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4815 - recall_min: 0.7679 - val_loss: 0.4685 - val_recall_min: 0.6463
# Epoch 19/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4819 - recall_min: 0.7690 - val_loss: 0.4674 - val_recall_min: 0.6473
# Epoch 20/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4804 - recall_min: 0.7680 - val_loss: 0.4689 - val_recall_min: 0.6473
# Epoch 21/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4763 - recall_min: 0.7705 - val_loss: 0.4680 - val_recall_min: 0.6466
# Epoch 22/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4760 - recall_min: 0.7726 - val_loss: 0.4692 - val_recall_min: 0.6463
# Epoch 23/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4739 - recall_min: 0.7667 - val_loss: 0.4649 - val_recall_min: 0.6483
# Epoch 24/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4692 - recall_min: 0.7724 - val_loss: 0.4652 - val_recall_min: 0.6520
# Epoch 25/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4712 - recall_min: 0.7731 - val_loss: 0.4646 - val_recall_min: 0.6523
# Epoch 26/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4658 - recall_min: 0.7681 - val_loss: 0.4645 - val_recall_min: 0.6628
# Epoch 27/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4682 - recall_min: 0.7733 - val_loss: 0.4633 - val_recall_min: 0.6628
# Epoch 28/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4677 - recall_min: 0.7709 - val_loss: 0.4626 - val_recall_min: 0.6618
# Epoch 29/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4664 - recall_min: 0.7709 - val_loss: 0.4647 - val_recall_min: 0.6614
# Epoch 30/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4647 - recall_min: 0.7709 - val_loss: 0.4668 - val_recall_min: 0.6712
# Epoch 31/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4672 - recall_min: 0.7773 - val_loss: 0.4662 - val_recall_min: 0.6601
# Epoch 32/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4658 - recall_min: 0.7748 - val_loss: 0.4653 - val_recall_min: 0.6658
# Epoch 33/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4641 - recall_min: 0.7733 - val_loss: 0.4662 - val_recall_min: 0.6756
# Epoch 34/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4637 - recall_min: 0.7696 - val_loss: 0.4658 - val_recall_min: 0.6705
# Epoch 35/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4617 - recall_min: 0.7706 - val_loss: 0.4633 - val_recall_min: 0.6712
# Epoch 36/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4610 - recall_min: 0.7780 - val_loss: 0.4645 - val_recall_min: 0.6655
# Epoch 37/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4588 - recall_min: 0.7778 - val_loss: 0.4633 - val_recall_min: 0.6769
# Epoch 38/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4595 - recall_min: 0.7767 - val_loss: 0.4615 - val_recall_min: 0.6772
# Epoch 39/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4558 - recall_min: 0.7804 - val_loss: 0.4651 - val_recall_min: 0.6870
# Epoch 40/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4592 - recall_min: 0.7761 - val_loss: 0.4665 - val_recall_min: 0.6870
# Epoch 41/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4577 - recall_min: 0.7747 - val_loss: 0.4642 - val_recall_min: 0.6816
# Epoch 42/42
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4557 - recall_min: 0.7776 - val_loss: 0.4602 - val_recall_min: 0.6836
# [I 2025-02-23 20:53:24,171] Trial 1 finished with value: 0.6345757246017456 and parameters: {'num_layers': 2, 'n_units_layer_0': 80, 'dropout_rate_layer_0': 0.5521073376017769, 'n_units_layer_1': 38, 'dropout_rate_layer_1': 0.4693082409125395, 'epochs': 42, 'batch_size': 2048}. Best is trial 1 with value: 0.6345757246017456.
# Epoch 1/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.7379 - recall_min: 0.5259 - val_loss: 0.6150 - val_recall_min: 0.5932
# Epoch 2/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6154 - recall_min: 0.6481 - val_loss: 0.5597 - val_recall_min: 0.5658
# Epoch 3/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5673 - recall_min: 0.6956 - val_loss: 0.5340 - val_recall_min: 0.5659
# Epoch 4/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5388 - recall_min: 0.7193 - val_loss: 0.5223 - val_recall_min: 0.5968
# Epoch 5/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5246 - recall_min: 0.7361 - val_loss: 0.5156 - val_recall_min: 0.6038
# Epoch 6/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5169 - recall_min: 0.7390 - val_loss: 0.5109 - val_recall_min: 0.6179
# Epoch 7/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5075 - recall_min: 0.7462 - val_loss: 0.5059 - val_recall_min: 0.6246
# Epoch 8/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5014 - recall_min: 0.7536 - val_loss: 0.5038 - val_recall_min: 0.6263
# Epoch 9/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4942 - recall_min: 0.7559 - val_loss: 0.5001 - val_recall_min: 0.6393
# Epoch 10/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4910 - recall_min: 0.7532 - val_loss: 0.4969 - val_recall_min: 0.6340
# Epoch 11/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4849 - recall_min: 0.7631 - val_loss: 0.4936 - val_recall_min: 0.6413
# Epoch 12/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4831 - recall_min: 0.7634 - val_loss: 0.4907 - val_recall_min: 0.6423
# Epoch 13/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4779 - recall_min: 0.7633 - val_loss: 0.4908 - val_recall_min: 0.6379
# Epoch 14/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4787 - recall_min: 0.7641 - val_loss: 0.4899 - val_recall_min: 0.6379
# Epoch 15/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4744 - recall_min: 0.7746 - val_loss: 0.4873 - val_recall_min: 0.6393
# Epoch 16/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4713 - recall_min: 0.7700 - val_loss: 0.4855 - val_recall_min: 0.6446
# Epoch 17/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4726 - recall_min: 0.7666 - val_loss: 0.4855 - val_recall_min: 0.6490
# Epoch 18/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4719 - recall_min: 0.7710 - val_loss: 0.4845 - val_recall_min: 0.6503
# Epoch 19/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4687 - recall_min: 0.7739 - val_loss: 0.4828 - val_recall_min: 0.6570
# Epoch 20/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4685 - recall_min: 0.7728 - val_loss: 0.4817 - val_recall_min: 0.6587
# Epoch 21/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4653 - recall_min: 0.7786 - val_loss: 0.4816 - val_recall_min: 0.6584
# Epoch 22/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4665 - recall_min: 0.7754 - val_loss: 0.4814 - val_recall_min: 0.6691
# Epoch 23/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4631 - recall_min: 0.7725 - val_loss: 0.4798 - val_recall_min: 0.6695
# Epoch 24/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4613 - recall_min: 0.7729 - val_loss: 0.4794 - val_recall_min: 0.6634
# Epoch 25/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4635 - recall_min: 0.7770 - val_loss: 0.4780 - val_recall_min: 0.6644
# Epoch 26/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4588 - recall_min: 0.7782 - val_loss: 0.4784 - val_recall_min: 0.6641
# Epoch 27/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4593 - recall_min: 0.7803 - val_loss: 0.4777 - val_recall_min: 0.6644
# Epoch 28/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4578 - recall_min: 0.7761 - val_loss: 0.4769 - val_recall_min: 0.6594
# Epoch 29/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4554 - recall_min: 0.7841 - val_loss: 0.4759 - val_recall_min: 0.6597
# Epoch 30/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4559 - recall_min: 0.7788 - val_loss: 0.4747 - val_recall_min: 0.6597
# Epoch 31/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4564 - recall_min: 0.7794 - val_loss: 0.4733 - val_recall_min: 0.6614
# Epoch 32/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4564 - recall_min: 0.7806 - val_loss: 0.4737 - val_recall_min: 0.6600
# Epoch 33/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4551 - recall_min: 0.7827 - val_loss: 0.4726 - val_recall_min: 0.6610
# Epoch 34/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4506 - recall_min: 0.7827 - val_loss: 0.4731 - val_recall_min: 0.6614
# Epoch 35/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4540 - recall_min: 0.7800 - val_loss: 0.4738 - val_recall_min: 0.6714
# Epoch 36/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4536 - recall_min: 0.7840 - val_loss: 0.4728 - val_recall_min: 0.6721
# Epoch 37/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4494 - recall_min: 0.7850 - val_loss: 0.4731 - val_recall_min: 0.6741
# Epoch 38/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4517 - recall_min: 0.7825 - val_loss: 0.4738 - val_recall_min: 0.6744
# Epoch 39/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4503 - recall_min: 0.7815 - val_loss: 0.4718 - val_recall_min: 0.6751
# Epoch 40/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4501 - recall_min: 0.7822 - val_loss: 0.4717 - val_recall_min: 0.6748
# Epoch 41/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4477 - recall_min: 0.7876 - val_loss: 0.4727 - val_recall_min: 0.6741
# Epoch 42/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4492 - recall_min: 0.7879 - val_loss: 0.4725 - val_recall_min: 0.6744
# Epoch 43/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4450 - recall_min: 0.7887 - val_loss: 0.4716 - val_recall_min: 0.6741
# Epoch 44/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4467 - recall_min: 0.7862 - val_loss: 0.4702 - val_recall_min: 0.6754
# Epoch 45/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4460 - recall_min: 0.7833 - val_loss: 0.4694 - val_recall_min: 0.6758
# Epoch 46/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4454 - recall_min: 0.7817 - val_loss: 0.4706 - val_recall_min: 0.6801
# Epoch 47/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4443 - recall_min: 0.7862 - val_loss: 0.4705 - val_recall_min: 0.6758
# Epoch 48/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4461 - recall_min: 0.7818 - val_loss: 0.4696 - val_recall_min: 0.6761
# Epoch 49/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4454 - recall_min: 0.7853 - val_loss: 0.4699 - val_recall_min: 0.6811
# Epoch 50/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4457 - recall_min: 0.7858 - val_loss: 0.4713 - val_recall_min: 0.6791
# Epoch 51/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4474 - recall_min: 0.7885 - val_loss: 0.4689 - val_recall_min: 0.6761
# Epoch 52/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4455 - recall_min: 0.7859 - val_loss: 0.4678 - val_recall_min: 0.6710
# Epoch 53/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4443 - recall_min: 0.7860 - val_loss: 0.4672 - val_recall_min: 0.6710
# Epoch 54/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4434 - recall_min: 0.7874 - val_loss: 0.4683 - val_recall_min: 0.6758
# Epoch 55/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4438 - recall_min: 0.7886 - val_loss: 0.4688 - val_recall_min: 0.6758
# Epoch 56/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4419 - recall_min: 0.7891 - val_loss: 0.4670 - val_recall_min: 0.6710
# Epoch 57/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4453 - recall_min: 0.7852 - val_loss: 0.4672 - val_recall_min: 0.6758
# Epoch 58/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4457 - recall_min: 0.7892 - val_loss: 0.4677 - val_recall_min: 0.6818
# Epoch 59/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4444 - recall_min: 0.7882 - val_loss: 0.4677 - val_recall_min: 0.6815
# Epoch 60/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4422 - recall_min: 0.7905 - val_loss: 0.4671 - val_recall_min: 0.6821
# [I 2025-02-23 20:53:38,519] Trial 2 finished with value: 0.6495274305343628 and parameters: {'num_layers': 1, 'n_units_layer_0': 98, 'dropout_rate_layer_0': 0.581835687598498, 'epochs': 60, 'batch_size': 2048}. Best is trial 2 with value: 0.6495274305343628.
# Epoch 1/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.7564 - recall_min: 0.5051 - val_loss: 0.6135 - val_recall_min: 0.5905
# Epoch 2/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6304 - recall_min: 0.6395 - val_loss: 0.5562 - val_recall_min: 0.5731
# Epoch 3/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5670 - recall_min: 0.6954 - val_loss: 0.5295 - val_recall_min: 0.5673
# Epoch 4/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5402 - recall_min: 0.7234 - val_loss: 0.5169 - val_recall_min: 0.5763
# Epoch 5/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5229 - recall_min: 0.7367 - val_loss: 0.5118 - val_recall_min: 0.5985
# Epoch 6/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5097 - recall_min: 0.7405 - val_loss: 0.5050 - val_recall_min: 0.6014
# Epoch 7/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5033 - recall_min: 0.7460 - val_loss: 0.5002 - val_recall_min: 0.6105
# Epoch 8/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4972 - recall_min: 0.7514 - val_loss: 0.4981 - val_recall_min: 0.6182
# Epoch 9/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4913 - recall_min: 0.7570 - val_loss: 0.4945 - val_recall_min: 0.6255
# Epoch 10/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4851 - recall_min: 0.7651 - val_loss: 0.4898 - val_recall_min: 0.6272
# Epoch 11/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4833 - recall_min: 0.7621 - val_loss: 0.4855 - val_recall_min: 0.6393
# Epoch 12/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4780 - recall_min: 0.7604 - val_loss: 0.4847 - val_recall_min: 0.6406
# Epoch 13/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4724 - recall_min: 0.7704 - val_loss: 0.4865 - val_recall_min: 0.6386
# Epoch 14/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4718 - recall_min: 0.7716 - val_loss: 0.4835 - val_recall_min: 0.6412
# Epoch 15/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4726 - recall_min: 0.7676 - val_loss: 0.4819 - val_recall_min: 0.6365
# Epoch 16/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4691 - recall_min: 0.7687 - val_loss: 0.4805 - val_recall_min: 0.6382
# Epoch 17/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4672 - recall_min: 0.7681 - val_loss: 0.4805 - val_recall_min: 0.6426
# Epoch 18/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4652 - recall_min: 0.7727 - val_loss: 0.4787 - val_recall_min: 0.6547
# Epoch 19/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4671 - recall_min: 0.7728 - val_loss: 0.4767 - val_recall_min: 0.6563
# Epoch 20/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4638 - recall_min: 0.7755 - val_loss: 0.4777 - val_recall_min: 0.6607
# Epoch 21/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4620 - recall_min: 0.7746 - val_loss: 0.4781 - val_recall_min: 0.6657
# Epoch 22/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4598 - recall_min: 0.7741 - val_loss: 0.4772 - val_recall_min: 0.6657
# Epoch 23/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4617 - recall_min: 0.7687 - val_loss: 0.4769 - val_recall_min: 0.6664
# Epoch 24/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4602 - recall_min: 0.7756 - val_loss: 0.4769 - val_recall_min: 0.6664
# Epoch 25/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4603 - recall_min: 0.7762 - val_loss: 0.4760 - val_recall_min: 0.6661
# Epoch 26/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4598 - recall_min: 0.7771 - val_loss: 0.4751 - val_recall_min: 0.6667
# Epoch 27/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4539 - recall_min: 0.7728 - val_loss: 0.4745 - val_recall_min: 0.6667
# Epoch 28/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4545 - recall_min: 0.7778 - val_loss: 0.4747 - val_recall_min: 0.6667
# Epoch 29/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4547 - recall_min: 0.7793 - val_loss: 0.4743 - val_recall_min: 0.6674
# Epoch 30/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4527 - recall_min: 0.7791 - val_loss: 0.4741 - val_recall_min: 0.6671
# Epoch 31/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4541 - recall_min: 0.7818 - val_loss: 0.4724 - val_recall_min: 0.6671
# Epoch 32/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4502 - recall_min: 0.7775 - val_loss: 0.4713 - val_recall_min: 0.6671
# Epoch 33/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4507 - recall_min: 0.7778 - val_loss: 0.4718 - val_recall_min: 0.6667
# Epoch 34/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4502 - recall_min: 0.7770 - val_loss: 0.4724 - val_recall_min: 0.6671
# Epoch 35/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4510 - recall_min: 0.7786 - val_loss: 0.4715 - val_recall_min: 0.6681
# Epoch 36/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4500 - recall_min: 0.7810 - val_loss: 0.4700 - val_recall_min: 0.6630
# Epoch 37/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4509 - recall_min: 0.7803 - val_loss: 0.4700 - val_recall_min: 0.6681
# Epoch 38/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4482 - recall_min: 0.7843 - val_loss: 0.4691 - val_recall_min: 0.6687
# Epoch 39/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4480 - recall_min: 0.7803 - val_loss: 0.4684 - val_recall_min: 0.6694
# Epoch 40/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4480 - recall_min: 0.7841 - val_loss: 0.4682 - val_recall_min: 0.6691
# Epoch 41/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4481 - recall_min: 0.7837 - val_loss: 0.4674 - val_recall_min: 0.6697
# Epoch 42/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4487 - recall_min: 0.7814 - val_loss: 0.4692 - val_recall_min: 0.6681
# Epoch 43/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4451 - recall_min: 0.7822 - val_loss: 0.4691 - val_recall_min: 0.6700
# Epoch 44/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4469 - recall_min: 0.7799 - val_loss: 0.4692 - val_recall_min: 0.6694
# Epoch 45/45
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4470 - recall_min: 0.7837 - val_loss: 0.4682 - val_recall_min: 0.6694
# [I 2025-02-23 20:53:50,520] Trial 3 finished with value: 0.6335004568099976 and parameters: {'num_layers': 1, 'n_units_layer_0': 90, 'dropout_rate_layer_0': 0.5349146131644528, 'epochs': 45, 'batch_size': 2048}. Best is trial 2 with value: 0.6495274305343628.
# Epoch 1/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.8224 - recall_min: 0.4166 - val_loss: 0.6268 - val_recall_min: 0.5978
# Epoch 2/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6951 - recall_min: 0.5733 - val_loss: 0.5801 - val_recall_min: 0.5635
# Epoch 3/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6394 - recall_min: 0.6293 - val_loss: 0.5572 - val_recall_min: 0.5752
# Epoch 4/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5999 - recall_min: 0.6678 - val_loss: 0.5367 - val_recall_min: 0.5764
# Epoch 5/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5782 - recall_min: 0.6919 - val_loss: 0.5282 - val_recall_min: 0.5879
# Epoch 6/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5651 - recall_min: 0.7112 - val_loss: 0.5238 - val_recall_min: 0.5956
# Epoch 7/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5518 - recall_min: 0.7123 - val_loss: 0.5185 - val_recall_min: 0.5995
# Epoch 8/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5414 - recall_min: 0.7255 - val_loss: 0.5115 - val_recall_min: 0.5965
# Epoch 9/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5296 - recall_min: 0.7307 - val_loss: 0.5071 - val_recall_min: 0.5995
# Epoch 10/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5311 - recall_min: 0.7273 - val_loss: 0.5041 - val_recall_min: 0.5998
# Epoch 11/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5259 - recall_min: 0.7343 - val_loss: 0.5025 - val_recall_min: 0.6062
# Epoch 12/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5196 - recall_min: 0.7400 - val_loss: 0.4991 - val_recall_min: 0.6139
# Epoch 13/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5129 - recall_min: 0.7487 - val_loss: 0.4945 - val_recall_min: 0.6235
# Epoch 14/14
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5104 - recall_min: 0.7508 - val_loss: 0.4935 - val_recall_min: 0.6302
# [I 2025-02-23 20:53:57,242] Trial 4 finished with value: 0.6045433878898621 and parameters: {'num_layers': 2, 'n_units_layer_0': 57, 'dropout_rate_layer_0': 0.5856001855633105, 'n_units_layer_1': 61, 'dropout_rate_layer_1': 0.5336675137553359, 'epochs': 14, 'batch_size': 2048}. Best is trial 2 with value: 0.6495274305343628.
# Epoch 1/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.8793 - recall_min: 0.3910 - val_loss: 0.6408 - val_recall_min: 0.4327
# Epoch 2/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8061 - recall_min: 0.4431 - val_loss: 0.6044 - val_recall_min: 0.5008
# Epoch 3/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7431 - recall_min: 0.4988 - val_loss: 0.5761 - val_recall_min: 0.5197
# Epoch 4/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6913 - recall_min: 0.5311 - val_loss: 0.5557 - val_recall_min: 0.5347
# Epoch 5/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6660 - recall_min: 0.5555 - val_loss: 0.5408 - val_recall_min: 0.5360
# Epoch 6/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6299 - recall_min: 0.5994 - val_loss: 0.5283 - val_recall_min: 0.5370
# Epoch 7/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6162 - recall_min: 0.6136 - val_loss: 0.5193 - val_recall_min: 0.5455
# Epoch 8/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6045 - recall_min: 0.6241 - val_loss: 0.5144 - val_recall_min: 0.5412
# Epoch 9/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5847 - recall_min: 0.6598 - val_loss: 0.5102 - val_recall_min: 0.5523
# Epoch 10/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5757 - recall_min: 0.6650 - val_loss: 0.5072 - val_recall_min: 0.5497
# Epoch 11/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5667 - recall_min: 0.6752 - val_loss: 0.5051 - val_recall_min: 0.5601
# Epoch 12/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5628 - recall_min: 0.6881 - val_loss: 0.5028 - val_recall_min: 0.5608
# Epoch 13/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5579 - recall_min: 0.6970 - val_loss: 0.5007 - val_recall_min: 0.5718
# Epoch 14/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5465 - recall_min: 0.7086 - val_loss: 0.4993 - val_recall_min: 0.5766
# Epoch 15/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5402 - recall_min: 0.7138 - val_loss: 0.4983 - val_recall_min: 0.5769
# Epoch 16/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5349 - recall_min: 0.7242 - val_loss: 0.4981 - val_recall_min: 0.5823
# Epoch 17/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5317 - recall_min: 0.7258 - val_loss: 0.4974 - val_recall_min: 0.5876
# Epoch 18/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5277 - recall_min: 0.7295 - val_loss: 0.4973 - val_recall_min: 0.5870
# Epoch 19/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5224 - recall_min: 0.7344 - val_loss: 0.4958 - val_recall_min: 0.5876
# Epoch 20/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5256 - recall_min: 0.7301 - val_loss: 0.4948 - val_recall_min: 0.5873
# Epoch 21/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5192 - recall_min: 0.7350 - val_loss: 0.4941 - val_recall_min: 0.5937
# Epoch 22/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5162 - recall_min: 0.7433 - val_loss: 0.4935 - val_recall_min: 0.5923
# Epoch 23/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5216 - recall_min: 0.7336 - val_loss: 0.4934 - val_recall_min: 0.5923
# Epoch 24/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5158 - recall_min: 0.7389 - val_loss: 0.4936 - val_recall_min: 0.5984
# Epoch 25/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5134 - recall_min: 0.7455 - val_loss: 0.4934 - val_recall_min: 0.6038
# Epoch 26/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5133 - recall_min: 0.7455 - val_loss: 0.4921 - val_recall_min: 0.6041
# Epoch 27/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5086 - recall_min: 0.7425 - val_loss: 0.4912 - val_recall_min: 0.6101
# Epoch 28/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5103 - recall_min: 0.7502 - val_loss: 0.4910 - val_recall_min: 0.6162
# Epoch 29/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5064 - recall_min: 0.7510 - val_loss: 0.4899 - val_recall_min: 0.6219
# Epoch 30/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5024 - recall_min: 0.7504 - val_loss: 0.4887 - val_recall_min: 0.6219
# Epoch 31/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5014 - recall_min: 0.7511 - val_loss: 0.4875 - val_recall_min: 0.6222
# Epoch 32/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5017 - recall_min: 0.7492 - val_loss: 0.4878 - val_recall_min: 0.6219
# Epoch 33/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4996 - recall_min: 0.7527 - val_loss: 0.4884 - val_recall_min: 0.6202
# Epoch 34/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5006 - recall_min: 0.7517 - val_loss: 0.4880 - val_recall_min: 0.6199
# Epoch 35/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5026 - recall_min: 0.7478 - val_loss: 0.4880 - val_recall_min: 0.6199
# Epoch 36/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4976 - recall_min: 0.7509 - val_loss: 0.4878 - val_recall_min: 0.6192
# Epoch 37/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4995 - recall_min: 0.7529 - val_loss: 0.4881 - val_recall_min: 0.6243
# Epoch 38/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4958 - recall_min: 0.7523 - val_loss: 0.4871 - val_recall_min: 0.6246
# Epoch 39/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4970 - recall_min: 0.7528 - val_loss: 0.4860 - val_recall_min: 0.6253
# Epoch 40/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4933 - recall_min: 0.7578 - val_loss: 0.4854 - val_recall_min: 0.6263
# Epoch 41/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4942 - recall_min: 0.7492 - val_loss: 0.4858 - val_recall_min: 0.6263
# Epoch 42/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4930 - recall_min: 0.7501 - val_loss: 0.4852 - val_recall_min: 0.6212
# Epoch 43/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4923 - recall_min: 0.7623 - val_loss: 0.4847 - val_recall_min: 0.6216
# Epoch 44/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4904 - recall_min: 0.7544 - val_loss: 0.4845 - val_recall_min: 0.6209
# Epoch 45/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4908 - recall_min: 0.7505 - val_loss: 0.4842 - val_recall_min: 0.6155
# Epoch 46/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4935 - recall_min: 0.7541 - val_loss: 0.4841 - val_recall_min: 0.6256
# Epoch 47/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4871 - recall_min: 0.7604 - val_loss: 0.4837 - val_recall_min: 0.6259
# Epoch 48/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4870 - recall_min: 0.7566 - val_loss: 0.4831 - val_recall_min: 0.6266
# Epoch 49/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4884 - recall_min: 0.7502 - val_loss: 0.4830 - val_recall_min: 0.6273
# Epoch 50/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4846 - recall_min: 0.7582 - val_loss: 0.4827 - val_recall_min: 0.6276
# Epoch 51/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4846 - recall_min: 0.7585 - val_loss: 0.4826 - val_recall_min: 0.6209
# Epoch 52/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4890 - recall_min: 0.7561 - val_loss: 0.4820 - val_recall_min: 0.6219
# Epoch 53/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4812 - recall_min: 0.7546 - val_loss: 0.4821 - val_recall_min: 0.6212
# Epoch 54/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4845 - recall_min: 0.7497 - val_loss: 0.4823 - val_recall_min: 0.6222
# Epoch 55/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4839 - recall_min: 0.7544 - val_loss: 0.4820 - val_recall_min: 0.6222
# Epoch 56/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4835 - recall_min: 0.7573 - val_loss: 0.4812 - val_recall_min: 0.6229
# Epoch 57/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4864 - recall_min: 0.7563 - val_loss: 0.4814 - val_recall_min: 0.6225
# Epoch 58/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4816 - recall_min: 0.7570 - val_loss: 0.4814 - val_recall_min: 0.6225
# Epoch 59/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4839 - recall_min: 0.7558 - val_loss: 0.4811 - val_recall_min: 0.6225
# Epoch 60/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4838 - recall_min: 0.7560 - val_loss: 0.4813 - val_recall_min: 0.6235
# Epoch 61/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4811 - recall_min: 0.7574 - val_loss: 0.4811 - val_recall_min: 0.6235
# Epoch 62/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4833 - recall_min: 0.7575 - val_loss: 0.4811 - val_recall_min: 0.6232
# Epoch 63/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4794 - recall_min: 0.7550 - val_loss: 0.4801 - val_recall_min: 0.6286
# Epoch 64/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4791 - recall_min: 0.7556 - val_loss: 0.4796 - val_recall_min: 0.6286
# Epoch 65/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4804 - recall_min: 0.7565 - val_loss: 0.4792 - val_recall_min: 0.6336
# Epoch 66/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4787 - recall_min: 0.7563 - val_loss: 0.4788 - val_recall_min: 0.6346
# Epoch 67/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4758 - recall_min: 0.7582 - val_loss: 0.4789 - val_recall_min: 0.6346
# Epoch 68/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4800 - recall_min: 0.7563 - val_loss: 0.4783 - val_recall_min: 0.6350
# Epoch 69/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4814 - recall_min: 0.7584 - val_loss: 0.4781 - val_recall_min: 0.6343
# Epoch 70/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4762 - recall_min: 0.7601 - val_loss: 0.4778 - val_recall_min: 0.6346
# Epoch 71/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4764 - recall_min: 0.7565 - val_loss: 0.4776 - val_recall_min: 0.6340
# Epoch 72/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4773 - recall_min: 0.7588 - val_loss: 0.4782 - val_recall_min: 0.6340
# Epoch 73/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4757 - recall_min: 0.7603 - val_loss: 0.4782 - val_recall_min: 0.6336
# Epoch 74/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4772 - recall_min: 0.7556 - val_loss: 0.4783 - val_recall_min: 0.6333
# Epoch 75/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4717 - recall_min: 0.7618 - val_loss: 0.4778 - val_recall_min: 0.6333
# Epoch 76/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4757 - recall_min: 0.7620 - val_loss: 0.4776 - val_recall_min: 0.6390
# Epoch 77/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4748 - recall_min: 0.7579 - val_loss: 0.4777 - val_recall_min: 0.6390
# Epoch 78/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4774 - recall_min: 0.7574 - val_loss: 0.4779 - val_recall_min: 0.6387
# Epoch 79/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4748 - recall_min: 0.7564 - val_loss: 0.4781 - val_recall_min: 0.6383
# Epoch 80/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4759 - recall_min: 0.7582 - val_loss: 0.4771 - val_recall_min: 0.6444
# Epoch 81/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4769 - recall_min: 0.7560 - val_loss: 0.4759 - val_recall_min: 0.6397
# Epoch 82/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4749 - recall_min: 0.7608 - val_loss: 0.4751 - val_recall_min: 0.6407
# Epoch 83/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4730 - recall_min: 0.7605 - val_loss: 0.4746 - val_recall_min: 0.6403
# Epoch 84/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4738 - recall_min: 0.7616 - val_loss: 0.4750 - val_recall_min: 0.6454
# Epoch 85/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4746 - recall_min: 0.7537 - val_loss: 0.4759 - val_recall_min: 0.6447
# Epoch 86/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4744 - recall_min: 0.7589 - val_loss: 0.4760 - val_recall_min: 0.6450
# Epoch 87/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4727 - recall_min: 0.7597 - val_loss: 0.4750 - val_recall_min: 0.6460
# Epoch 88/94
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4745 - recall_min: 0.7538 - val_loss: 0.4755 - val_recall_min: 0.6407
# Epoch 89/94
# ...
# Epoch 13/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5399 - recall_min: 0.7269 - val_loss: 0.4965 - val_recall_min: 0.6014
# Epoch 14/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5367 - recall_min: 0.7312 - val_loss: 0.4949 - val_recall_min: 0.6081
# Epoch 15/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5260 - recall_min: 0.7379 - val_loss: 0.4928 - val_recall_min: 0.6098
# Epoch 16/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5294 - recall_min: 0.7342 - val_loss: 0.4913 - val_recall_min: 0.6168
# Epoch 17/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5214 - recall_min: 0.7427 - val_loss: 0.4898 - val_recall_min: 0.6229
# Epoch 18/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5199 - recall_min: 0.7487 - val_loss: 0.4878 - val_recall_min: 0.6279
# Epoch 19/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5162 - recall_min: 0.7438 - val_loss: 0.4863 - val_recall_min: 0.6279
# Epoch 20/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5100 - recall_min: 0.7514 - val_loss: 0.4855 - val_recall_min: 0.6377
# Epoch 21/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5126 - recall_min: 0.7499 - val_loss: 0.4845 - val_recall_min: 0.6367
# Epoch 22/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5085 - recall_min: 0.7533 - val_loss: 0.4830 - val_recall_min: 0.6390
# Epoch 23/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5082 - recall_min: 0.7548 - val_loss: 0.4822 - val_recall_min: 0.6390
# Epoch 24/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5076 - recall_min: 0.7547 - val_loss: 0.4817 - val_recall_min: 0.6340
# Epoch 25/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5009 - recall_min: 0.7595 - val_loss: 0.4798 - val_recall_min: 0.6397
# Epoch 26/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4995 - recall_min: 0.7597 - val_loss: 0.4788 - val_recall_min: 0.6400
# Epoch 27/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4972 - recall_min: 0.7617 - val_loss: 0.4798 - val_recall_min: 0.6387
# Epoch 28/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4991 - recall_min: 0.7554 - val_loss: 0.4784 - val_recall_min: 0.6440
# Epoch 29/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4954 - recall_min: 0.7605 - val_loss: 0.4765 - val_recall_min: 0.6346
# Epoch 30/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4943 - recall_min: 0.7639 - val_loss: 0.4756 - val_recall_min: 0.6400
# Epoch 31/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4931 - recall_min: 0.7594 - val_loss: 0.4748 - val_recall_min: 0.6393
# Epoch 32/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4951 - recall_min: 0.7643 - val_loss: 0.4737 - val_recall_min: 0.6383
# Epoch 33/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4939 - recall_min: 0.7612 - val_loss: 0.4734 - val_recall_min: 0.6390
# Epoch 34/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4881 - recall_min: 0.7637 - val_loss: 0.4742 - val_recall_min: 0.6454
# Epoch 35/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4855 - recall_min: 0.7639 - val_loss: 0.4745 - val_recall_min: 0.6450
# Epoch 36/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4863 - recall_min: 0.7688 - val_loss: 0.4735 - val_recall_min: 0.6444
# Epoch 37/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4859 - recall_min: 0.7680 - val_loss: 0.4718 - val_recall_min: 0.6450
# Epoch 38/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4892 - recall_min: 0.7681 - val_loss: 0.4717 - val_recall_min: 0.6504
# Epoch 39/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4856 - recall_min: 0.7646 - val_loss: 0.4713 - val_recall_min: 0.6565
# Epoch 40/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4828 - recall_min: 0.7635 - val_loss: 0.4706 - val_recall_min: 0.6558
# Epoch 41/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4813 - recall_min: 0.7702 - val_loss: 0.4693 - val_recall_min: 0.6568
# Epoch 42/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4867 - recall_min: 0.7683 - val_loss: 0.4701 - val_recall_min: 0.6508
# Epoch 43/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4859 - recall_min: 0.7659 - val_loss: 0.4704 - val_recall_min: 0.6608
# Epoch 44/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4817 - recall_min: 0.7711 - val_loss: 0.4714 - val_recall_min: 0.6659
# Epoch 45/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4816 - recall_min: 0.7677 - val_loss: 0.4684 - val_recall_min: 0.6622
# Epoch 46/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4805 - recall_min: 0.7677 - val_loss: 0.4679 - val_recall_min: 0.6558
# Epoch 47/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4797 - recall_min: 0.7673 - val_loss: 0.4696 - val_recall_min: 0.6602
# Epoch 48/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4796 - recall_min: 0.7692 - val_loss: 0.4695 - val_recall_min: 0.6652
# Epoch 49/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4780 - recall_min: 0.7689 - val_loss: 0.4658 - val_recall_min: 0.6555
# Epoch 50/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4780 - recall_min: 0.7664 - val_loss: 0.4661 - val_recall_min: 0.6662
# Epoch 51/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4798 - recall_min: 0.7746 - val_loss: 0.4673 - val_recall_min: 0.6656
# Epoch 52/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4787 - recall_min: 0.7719 - val_loss: 0.4675 - val_recall_min: 0.6656
# Epoch 53/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4787 - recall_min: 0.7682 - val_loss: 0.4675 - val_recall_min: 0.6662
# Epoch 54/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4769 - recall_min: 0.7699 - val_loss: 0.4663 - val_recall_min: 0.6656
# Epoch 55/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4745 - recall_min: 0.7684 - val_loss: 0.4660 - val_recall_min: 0.6642
# Epoch 56/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4767 - recall_min: 0.7713 - val_loss: 0.4667 - val_recall_min: 0.6649
# Epoch 57/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4762 - recall_min: 0.7713 - val_loss: 0.4661 - val_recall_min: 0.6649
# Epoch 58/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4747 - recall_min: 0.7687 - val_loss: 0.4647 - val_recall_min: 0.6659
# Epoch 59/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4757 - recall_min: 0.7757 - val_loss: 0.4640 - val_recall_min: 0.6662
# Epoch 60/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4764 - recall_min: 0.7707 - val_loss: 0.4662 - val_recall_min: 0.6652
# Epoch 61/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4723 - recall_min: 0.7739 - val_loss: 0.4677 - val_recall_min: 0.6656
# Epoch 62/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4751 - recall_min: 0.7701 - val_loss: 0.4666 - val_recall_min: 0.6669
# Epoch 63/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4733 - recall_min: 0.7730 - val_loss: 0.4654 - val_recall_min: 0.6672
# Epoch 64/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4731 - recall_min: 0.7724 - val_loss: 0.4656 - val_recall_min: 0.6675
# Epoch 65/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4752 - recall_min: 0.7754 - val_loss: 0.4651 - val_recall_min: 0.6679
# Epoch 66/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4712 - recall_min: 0.7720 - val_loss: 0.4644 - val_recall_min: 0.6675
# Epoch 67/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4752 - recall_min: 0.7719 - val_loss: 0.4649 - val_recall_min: 0.6675
# Epoch 68/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4715 - recall_min: 0.7727 - val_loss: 0.4649 - val_recall_min: 0.6726
# Epoch 69/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4691 - recall_min: 0.7753 - val_loss: 0.4640 - val_recall_min: 0.6723
# Epoch 70/70
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4690 - recall_min: 0.7753 - val_loss: 0.4639 - val_recall_min: 0.6719
# [I 2025-02-23 20:55:32,274] Trial 9 finished with value: 0.6274150609970093 and parameters: {'num_layers': 2, 'n_units_layer_0': 33, 'dropout_rate_layer_0': 0.5677991777408355, 'n_units_layer_1': 26, 'dropout_rate_layer_1': 0.4454228341393782, 'epochs': 70, 'batch_size': 2048}. Best is trial 2 with value: 0.6495274305343628.
# Epoch 1/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.7169 - recall_min: 0.4175 - val_loss: 0.6251 - val_recall_min: 0.5909
# Epoch 2/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6165 - recall_min: 0.6199 - val_loss: 0.5481 - val_recall_min: 0.5663
# Epoch 3/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5589 - recall_min: 0.7038 - val_loss: 0.5245 - val_recall_min: 0.5820
# Epoch 4/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5339 - recall_min: 0.7267 - val_loss: 0.5166 - val_recall_min: 0.5951
# Epoch 5/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5225 - recall_min: 0.7410 - val_loss: 0.5105 - val_recall_min: 0.6125
# Epoch 6/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5110 - recall_min: 0.7450 - val_loss: 0.5054 - val_recall_min: 0.6209
# Epoch 7/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5053 - recall_min: 0.7477 - val_loss: 0.5002 - val_recall_min: 0.6286
# Epoch 8/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4942 - recall_min: 0.7562 - val_loss: 0.4963 - val_recall_min: 0.6319
# Epoch 9/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4949 - recall_min: 0.7540 - val_loss: 0.4927 - val_recall_min: 0.6399
# Epoch 10/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4868 - recall_min: 0.7600 - val_loss: 0.4909 - val_recall_min: 0.6513
# Epoch 11/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4841 - recall_min: 0.7655 - val_loss: 0.4892 - val_recall_min: 0.6503
# Epoch 12/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4813 - recall_min: 0.7622 - val_loss: 0.4878 - val_recall_min: 0.6520
# Epoch 13/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4785 - recall_min: 0.7675 - val_loss: 0.4843 - val_recall_min: 0.6647
# Epoch 14/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4782 - recall_min: 0.7664 - val_loss: 0.4817 - val_recall_min: 0.6614
# Epoch 15/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4754 - recall_min: 0.7680 - val_loss: 0.4823 - val_recall_min: 0.6553
# Epoch 16/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4746 - recall_min: 0.7680 - val_loss: 0.4807 - val_recall_min: 0.6550
# Epoch 17/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4680 - recall_min: 0.7710 - val_loss: 0.4808 - val_recall_min: 0.6540
# Epoch 18/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4704 - recall_min: 0.7682 - val_loss: 0.4801 - val_recall_min: 0.6597
# Epoch 19/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4699 - recall_min: 0.7696 - val_loss: 0.4791 - val_recall_min: 0.6614
# Epoch 20/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4628 - recall_min: 0.7737 - val_loss: 0.4784 - val_recall_min: 0.6630
# Epoch 21/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4642 - recall_min: 0.7783 - val_loss: 0.4773 - val_recall_min: 0.6643
# Epoch 22/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4641 - recall_min: 0.7738 - val_loss: 0.4774 - val_recall_min: 0.6643
# Epoch 23/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4627 - recall_min: 0.7749 - val_loss: 0.4765 - val_recall_min: 0.6647
# Epoch 24/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4621 - recall_min: 0.7772 - val_loss: 0.4750 - val_recall_min: 0.6643
# Epoch 25/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4585 - recall_min: 0.7754 - val_loss: 0.4755 - val_recall_min: 0.6694
# Epoch 26/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4578 - recall_min: 0.7806 - val_loss: 0.4746 - val_recall_min: 0.6694
# Epoch 27/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4612 - recall_min: 0.7805 - val_loss: 0.4735 - val_recall_min: 0.6764
# Epoch 28/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4585 - recall_min: 0.7791 - val_loss: 0.4736 - val_recall_min: 0.6764
# Epoch 29/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4550 - recall_min: 0.7825 - val_loss: 0.4752 - val_recall_min: 0.6687
# Epoch 30/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4572 - recall_min: 0.7820 - val_loss: 0.4741 - val_recall_min: 0.6748
# Epoch 31/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4546 - recall_min: 0.7770 - val_loss: 0.4732 - val_recall_min: 0.6758
# Epoch 32/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4554 - recall_min: 0.7816 - val_loss: 0.4724 - val_recall_min: 0.6764
# Epoch 33/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4531 - recall_min: 0.7805 - val_loss: 0.4720 - val_recall_min: 0.6815
# Epoch 34/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4513 - recall_min: 0.7797 - val_loss: 0.4727 - val_recall_min: 0.6808
# Epoch 35/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4538 - recall_min: 0.7768 - val_loss: 0.4722 - val_recall_min: 0.6801
# Epoch 36/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4529 - recall_min: 0.7817 - val_loss: 0.4711 - val_recall_min: 0.6818
# Epoch 37/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4505 - recall_min: 0.7861 - val_loss: 0.4710 - val_recall_min: 0.6811
# Epoch 38/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4503 - recall_min: 0.7806 - val_loss: 0.4713 - val_recall_min: 0.6795
# Epoch 39/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4502 - recall_min: 0.7776 - val_loss: 0.4699 - val_recall_min: 0.6811
# Epoch 40/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4517 - recall_min: 0.7798 - val_loss: 0.4692 - val_recall_min: 0.6815
# Epoch 41/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4494 - recall_min: 0.7843 - val_loss: 0.4686 - val_recall_min: 0.6821
# Epoch 42/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4466 - recall_min: 0.7820 - val_loss: 0.4708 - val_recall_min: 0.6801
# Epoch 43/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4461 - recall_min: 0.7821 - val_loss: 0.4699 - val_recall_min: 0.6855
# Epoch 44/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4491 - recall_min: 0.7839 - val_loss: 0.4686 - val_recall_min: 0.6858
# Epoch 45/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4502 - recall_min: 0.7795 - val_loss: 0.4672 - val_recall_min: 0.6872
# Epoch 46/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4485 - recall_min: 0.7853 - val_loss: 0.4690 - val_recall_min: 0.6858
# Epoch 47/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4482 - recall_min: 0.7858 - val_loss: 0.4703 - val_recall_min: 0.6845
# Epoch 48/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4496 - recall_min: 0.7826 - val_loss: 0.4676 - val_recall_min: 0.6805
# Epoch 49/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4458 - recall_min: 0.7864 - val_loss: 0.4687 - val_recall_min: 0.6848
# Epoch 50/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4470 - recall_min: 0.7841 - val_loss: 0.4677 - val_recall_min: 0.6805
# Epoch 51/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4442 - recall_min: 0.7855 - val_loss: 0.4665 - val_recall_min: 0.6815
# Epoch 52/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4472 - recall_min: 0.7825 - val_loss: 0.4683 - val_recall_min: 0.6896
# Epoch 53/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4442 - recall_min: 0.7850 - val_loss: 0.4694 - val_recall_min: 0.6886
# Epoch 54/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4452 - recall_min: 0.7886 - val_loss: 0.4674 - val_recall_min: 0.6925
# Epoch 55/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4434 - recall_min: 0.7841 - val_loss: 0.4657 - val_recall_min: 0.6892
# Epoch 56/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4460 - recall_min: 0.7870 - val_loss: 0.4658 - val_recall_min: 0.6882
# Epoch 57/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4437 - recall_min: 0.7873 - val_loss: 0.4661 - val_recall_min: 0.6888
# Epoch 58/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4424 - recall_min: 0.7876 - val_loss: 0.4661 - val_recall_min: 0.6878
# Epoch 59/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4429 - recall_min: 0.7906 - val_loss: 0.4660 - val_recall_min: 0.6882
# Epoch 60/60
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4407 - recall_min: 0.7894 - val_loss: 0.4656 - val_recall_min: 0.6885

# %%
def logreg_metrics (y_test,y_pred):
    tpr = recall_score(y_test, y_pred)
    print('TPR:',tpr)
    f1 = f1_score(y_test, y_pred)
    print('f1:',f1)
    return tpr, f1

# %%
# Optimización del umbral
def mejor_umbral(model, X_test, y_test, thresholds):
    best_threshold = None
    best_tpr = 0.8

    for threshold in thresholds:
        y_pred_proba = model.predict(X_test).flatten()
        y_pred = (y_pred_proba >= threshold).astype(int)

        recall, f1 = logreg_metrics(y_test, y_pred)

        # Guardar el mejor umbral basado en el mínimo valor de especificidad y TPR
        if recall > best_tpr:
            best_tpr = recall
            best_threshold = threshold
    return best_threshold

# %%
# Definir un rango de umbrales para probar
thresholds = np.arange(0.40, 0.6, 0.001)

best_threshold = mejor_umbral(best_model_nn_clas, X_test, y_test, thresholds)
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# TPR: 0.8306962025316456
# f1: 0.6051873198847262
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# TPR: 0.8306962025316456
# f1: 0.6058857472590883
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# TPR: 0.8306962025316456
# f1: 0.6058857472590883
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# TPR: 0.8306962025316456
# f1: 0.6062355658198614
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.8306962025316456
# f1: 0.6065857885615251
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.8306962025316456
# f1: 0.608342989571263
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7151898734177216
# f1: 0.6361717100633357
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7151898734177216
# f1: 0.6366197183098592
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7151898734177216
# f1: 0.6366197183098592
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7151898734177216
# f1: 0.6370683579985905
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7120253164556962
# f1: 0.635593220338983
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7120253164556962
# f1: 0.6364922206506365
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7120253164556962
# f1: 0.6364922206506365
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7120253164556962
# f1: 0.6364922206506365
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7120253164556962
# f1: 0.6364922206506365
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7120253164556962
# f1: 0.6369426751592356
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7120253164556962
# f1: 0.6378454996456414
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7104430379746836
# f1: 0.6368794326241135
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7104430379746836
# f1: 0.6377840909090909
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7104430379746836
# f1: 0.6377840909090909
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7104430379746836
# f1: 0.6382373845060412
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7088607594936709
# f1: 0.6377224199288256
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7072784810126582
# f1: 0.637660485021398
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7072784810126582
# f1: 0.6390278770550393
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7072784810126582
# f1: 0.6394849785407726
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7072784810126582
# f1: 0.6394849785407726
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7072784810126582
# f1: 0.6394849785407726
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7072784810126582
# f1: 0.6394849785407726
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7041139240506329
# f1: 0.6375358166189111
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7041139240506329
# f1: 0.6384505021520803
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7041139240506329
# f1: 0.639367816091954
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7041139240506329
# f1: 0.6398274622573688
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7025316455696202
# f1: 0.6393088552915767
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.7009493670886076
# f1: 0.638788752703677
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# TPR: 0.6993670886075949
# f1: 0.6378066378066378
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# TPR: 0.6993670886075949
# f1: 0.6382671480144404

# %%
y_pred = best_model_nn_clas.predict(X_test)
y_pred = (y_pred >= best_threshold).astype(int)

best_params = study.best_params
print(best_params)
tpr_nn, f1_nn = logreg_metrics(y_test,y_pred)
matriz_conf(y_test,y_pred)
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# {'num_layers': 1, 'n_units_layer_0': 98, 'dropout_rate_layer_0': 0.581835687598498, 'epochs': 60, 'batch_size': 2048}
# TPR: 0.8306962025316456
# f1: 0.6051873198847262

# %% [markdown]
# ##### **Insights obtenidos**

# %% [markdown]
# Se obtiene un modelo superador que acertará en un 83% en los días lluviosos, a costa de una mala precisión en cuanto a lluvia = True, acertando correctamente el 48% de las veces que pronostica lluvia.
# Sin embargo, la mayoría de los días en los cuales no se pronostica lluvia, efectivamente no llueve.

# %% [markdown]
# #### Resolución del problema de Regresión

# %%
def objective_regresor(trial):
    num_layers = trial.suggest_int('num_layers', 1, 3)
    model = Sequential()
    for i in range(num_layers):
        num_units = trial.suggest_int(f'n_units_layer_{i}', 10, 100) # la cantidad de neuronas de cada capa también se puede pasar como hiperparámetro
        # activations = trial.suggest_categorical(f'')
        model.add(Dense(num_units, activation='relu')) # capas densas con activacion ReLU
        dropout_rate = trial.suggest_float(f'dropout_rate_layer_{i}', 0, 0.6)
        model.add(Dropout(dropout_rate))
    # capa de salida
    model.add(Dense(1, activation='linear'))
    # compilar
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    # entrenar
    epochs = trial.suggest_int('epochs', 10, 100)
    batch_size = trial.suggest_int('batch_size', 256, 512)
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1)
    # evaluar
    score = model.evaluate(X_test, y_test, verbose=0)
    return score[1]

# %%
X_train, y_train, X_test, y_test = split(df_train, df_test,'regresion')
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

best_model_nn_reg, study = nn_model(X_train, y_train,X_test, y_test,'regresion')
# Out:
# [I 2025-02-23 20:56:40,050] A new study created in memory with name: no-name-47d1b271-53ed-4392-a6bf-9767cbb5defb
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 41.9784 - mean_squared_error: 41.9784 - val_loss: 43.6175 - val_mean_squared_error: 43.6175
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9052 - mean_squared_error: 34.9052 - val_loss: 39.6273 - val_mean_squared_error: 39.6273
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32
74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.3152 - mean_squared_error: 29.3152 - val_loss: 35.4810 - val_mean_squared_error: 35.4810
# Epoch 26/74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.1690 - mean_squared_error: 29.1690 - val_loss: 35.4340 - val_mean_squared_error: 35.4340
# Epoch 27/74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.9400 - mean_squared_error: 28.9400 - val_loss: 35.4126 - val_mean_squared_error: 35.4126
# Epoch 28/74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.8946 - mean_squared_error: 28.8946 - val_loss: 35.3598 - val_mean_squared_error: 35.3598
# Epoch 29/74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.9069 - mean_squared_error: 28.9069 - val_loss: 35.2675 - val_mean_squared_error: 35.2675
# Epoch 30/74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.8065 - mean_squared_error: 28.8065 - val_loss: 35.2465 - val_mean_squared_error: 35.2465
# Epoch 31/74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8582 - mean_squared_error: 28.8582 - val_loss: 35.1900 - val_mean_squared_error: 35.1900
# Epoch 32/74
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8104 - mean_squared_error: 28.8104 - val_loss: 35.1373 - val_mean_squared_error: 35.1373
# Epoch 33/74
# ...
# Epoch 15/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.6547 - mean_squared_error: 29.6547 - val_loss: 36.1515 - val_mean_squared_error: 36.1515
# Epoch 16/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1094 - mean_squared_error: 30.1094 - val_loss: 36.0680 - val_mean_squared_error: 36.0680
# Epoch 17/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.8106 - mean_squared_error: 29.8106 - val_loss: 36.0099 - val_mean_squared_error: 36.0099
# Epoch 18/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0363 - mean_squared_error: 30.0363 - val_loss: 35.9228 - val_mean_squared_error: 35.9228
# Epoch 19/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.3429 - mean_squared_error: 29.3429 - val_loss: 35.8318 - val_mean_squared_error: 35.8318
# Epoch 20/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.5730 - mean_squared_error: 29.5730 - val_loss: 35.7929 - val_mean_squared_error: 35.7929
# Epoch 21/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.7274 - mean_squared_error: 29.7274 - val_loss: 35.7405 - val_mean_squared_error: 35.7405
# Epoch 22/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.2805 - mean_squared_error: 29.2805 - val_loss: 35.6849 - val_mean_squared_error: 35.6849
# Epoch 23/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.5639 - mean_squared_error: 29.5639 - val_loss: 35.6574 - val_mean_squared_error: 35.6574
# Epoch 24/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.1705 - mean_squared_error: 29.1705 - val_loss: 35.5908 - val_mean_squared_error: 35.5908
# Epoch 25/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.1368 - mean_squared_error: 29.1368 - val_loss: 35.5456 - val_mean_squared_error: 35.5456
# Epoch 26/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.1269 - mean_squared_error: 29.1269 - val_loss: 35.4931 - val_mean_squared_error: 35.4931
# Epoch 27/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.9238 - mean_squared_error: 28.9238 - val_loss: 35.4579 - val_mean_squared_error: 35.4579
# Epoch 28/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.1117 - mean_squared_error: 29.1117 - val_loss: 35.4340 - val_mean_squared_error: 35.4340
# Epoch 29/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.6758 - mean_squared_error: 28.6758 - val_loss: 35.3987 - val_mean_squared_error: 35.3987
# Epoch 30/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.7072 - mean_squared_error: 28.7072 - val_loss: 35.3590 - val_mean_squared_error: 35.3590
# Epoch 31/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.3476 - mean_squared_error: 29.3476 - val_loss: 35.3263 - val_mean_squared_error: 35.3263
# Epoch 32/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.7318 - mean_squared_error: 28.7318 - val_loss: 35.2768 - val_mean_squared_error: 35.2768
# Epoch 33/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0893 - mean_squared_error: 29.0893 - val_loss: 35.2481 - val_mean_squared_error: 35.2481
# Epoch 34/97
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28
21
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.7271 - mean_squared_error: 28.7271 - val_loss: 34.5740 - val_mean_squared_error: 34.5740
# Epoch 16/21
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.9776 - mean_squared_error: 29.9776 - val_loss: 34.4941 - val_mean_squared_error: 34.4941
# Epoch 17/21
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.5340 - mean_squared_error: 29.5340 - val_loss: 34.1676 - val_mean_squared_error: 34.1676
# Epoch 18/21
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.1708 - mean_squared_error: 29.1708 - val_loss: 34.2407 - val_mean_squared_error: 34.2407
# Epoch 19/21
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.2241 - mean_squared_error: 29.2241 - val_loss: 34.1081 - val_mean_squared_error: 34.1081
# Epoch 20/21
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.7073 - mean_squared_error: 28.7073 - val_loss: 34.1964 - val_mean_squared_error: 34.1964
# Epoch 21/21
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.5611 - mean_squared_error: 28.5611 - val_loss: 34.3786 - val_mean_squared_error: 34.3786

# %%
best_params = study.best_params
print(best_params)
# Se guardan las predicciones del modelo
y_pred_train = best_model_nn_reg.predict(X_train)
y_pred_test = best_model_nn_reg.predict(X_test)

# Se calcula el error de train del modelo con rmse para mantener la misma escala que la variable a predecir
rmse_nn_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
rmse_nn_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

print(f"El error rmse_nn_train es: {rmse_nn_train}")
print(f"El error rmse_nn_test es: {rmse_nn_test}")

R2_nn_train = metrics.r2_score(y_train, y_pred_train)
print(f"El valor de R2_nn_train: {R2_nn_train}")
R2_nn_test = metrics.r2_score(y_test, y_pred_test)
print(f"El valor de R2_nn_test: {R2_nn_test}")
# Out:
# {'num_layers': 3, 'n_units_layer_0': 89, 'dropout_rate_layer_0': 0.478030357968641, 'n_units_layer_1': 49, 'dropout_rate_layer_1': 0.5507269314950339, 'n_units_layer_2': 81, 'dropout_rate_layer_2': 0.435450167009563, 'epochs': 21, 'batch_size': 491}
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# El error rmse_nn_train es: 5.523444579037632
# El error rmse_nn_test es: 5.863324189966015
# El valor de R2_nn_train: 0.3353155851364136
# El valor de R2_nn_test: 0.2790459394454956

# %% [markdown]
# ##### **Insights obtenidos**

# %% [markdown]
# Se observa una ligera mejora en los valores del error y la varianza explicada. El último modelo es significativamente más complejo, y siguiendo el principio de parcimonia, puede no justificarse su implementación.

# %% [markdown]
# #### SHAP: Explicabilidad de los modelos de redes

# %% [markdown]
# Se utiliza SHAP para explicar la contribución de las variables en los modelos de regresión y clasificación. SHAP asigna un valor de importancia a cada característica, indicando cómo influye en las predicciones del modelo, lo que permite interpretar y entender mejor su comportamiento, incluso en arquitecturas complejas como las redes neuronales.

# %%
# Establece el estilo de matplotlib
plt.rcdefaults()
plt.rcParams.update({
    'figure.facecolor': 'white',
    'axes.facecolor': 'white',
    'savefig.facecolor': 'white'
})

plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=8)
plt.rc('axes', titlesize=12)
plt.rc('axes', labelsize=12)

# %% [markdown]
# ##### Explicabilidad para Regresión

# %%
X_train, y_train, X_test, y_test = split(df_train, df_test, 'regresion')
feature_names = X_train.columns.values

# Reducir la cantidad de muestras para reducir el tiempo de ejecución de SHAP
n_train = int(len(df_train) * 0.02)
n_test = int(len(df_test) * 0.02)
# Se resetea el índice para que sean consecutivos y comiencen en cero
X_train = X_train.sample(n=n_train, random_state=semilla).reset_index(drop=True)
X_test = X_test.sample(n=n_test, random_state=semilla).reset_index(drop=True)

# Escalar los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convertir los arrays escalados de nuevo a DataFrames utilizando los nombres de las características
X_train_scaled = pd.DataFrame(X_train_scaled, columns=feature_names)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=feature_names)

# Crear un objeto explainer SHAP usando KernelExplainer
explainer = shap.KernelExplainer(best_model_nn_reg, X_train_scaled.values, feature_names=feature_names)

# Calcular los valores SHAP para un conjunto de ejemplos de prueba
shap_values = explainer.shap_values(X_test_scaled.values)
shap_values = np.squeeze(shap_values)

# Verificar la forma de los valores SHAP
print(shap_values.shape)
# Out:
# WARNING:shap:Using 303 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/53 [00:00<?, ?it/s]
# (53, 22)

# %% [markdown]
# ###### Interpretabilidad local

# %% [markdown]
# Se generan dos gráficas para interpretar la explicabilidad a nivel local, específicamente para la instancia correspondiente al index del conjunto de datos. De igual manera, es destacable que su aplicación resulta especialmente útil en entornos productivos.

# %%
# Se selecciona un índice aleatorio
index=25
shap_values[index]

rounded_shap_values = np.round(shap_values[index], 3)
rounded_X_test = np.round(X_test_scaled.iloc[index], 3)

# Genera la gráfica
shap.force_plot(explainer.expected_value, rounded_shap_values, rounded_X_test,
                feature_names=feature_names, matplotlib=True, figsize=(18, 4), text_rotation=90)

# %% [markdown]
# El gráfico anterior es un gráfico de fuerza, que muestra cómo las características contribuyen a la predicción del valor de la variable target RainfallTomorrow. Se puede observar cómo impactan las distintas variables de manera positiva (en rojo) y negativa (en azul).
# Las variables con mayor incidencia son las descritas en el gráfico, para el caso particular del elemento en la posición index.
#
# Se observa un mayor peso de las variables que empujan hacia valores más bajos.
#
# Principales variables con incidencia positiva:
# * Date_cos
# * Pressure3pm
# * WindGustSpeed
#
# Principales variables con incidencia negativa:
# * Humidity3pm
# * WindSpeed3pm
# * Cloud3pm
# * WindSpeed9am
# * WindGustDir_sen
# * WindGustDir_cos
#
# Es así que, por ejemplo, valores más altos de WindGustSpeed tienen un peso positivo sobre la variable RainfallTomorrow.
#
# En contraposición, valores altos para Humidity3pm incidirán de manera negativa en el valor de la variable objetivo.

# %%
explanation = shap.Explanation(rounded_shap_values, base_values=explainer.expected_value, feature_names=feature_names)
print("Gráfico de valores SHAP")
shap.plots.bar(explanation, max_display=20)
# Out:
# Gráfico de valores SHAP

# %% [markdown]
# El gráfico anterior es un gráfico de resumen de SHAP para la instancia individual elegida, donde se muestra cómo las características específicas contribuyen a la predicción en particular.
# Este gráfico permite observar de manera más detallada el mismo comportamiento de las variables explicativas.

# %% [markdown]
# ###### Interpretabilidad global

# %% [markdown]
# Se analiza la incidencia de las variables explicativas a nivel global, es decir para todas las muestras del conjunto de datos.

# %%
explanation = shap.Explanation(values=shap_values, base_values=explainer.expected_value, feature_names=feature_names, data=X_test)
print('Gráfico de valores SHAP')
shap.plots.bar(explanation, max_display=30)
# Out:
# Gráfico de valores SHAP

# %% [markdown]
# Se observan diferencias con respecto a la interpretabilidad local. En el gráfico de importancia global de las variables, todas las variables explicativas están ordenadas según su contribución promedio al modelo.
# En primer lugar todas las variables inciden de manera positiva en el valor de la variable objetivo.
#
# La variable Humidity3pm es la de mayor contribución en ambos análisis (local y global), pero en sentidos opuestos.
#
# Principales variables con incidencia positiva:
# * Humidity3pm
# * Sunshine
# * WindGustSpeed

# %%
plt.rcParams.update({'font.size': 12, 'axes.labelsize': 'large', 'xtick.labelsize': 'medium', 'ytick.labelsize': 'medium'})
shap.plots.beeswarm(explanation, max_display=30)

# %% [markdown]
# La gráfica muestra las variables explicativas ordenadas según su importancia global en el modelo, considerando su impacto en la predicción de la probabilidad de lluvia para el día siguiente ("RainfallTomorrow"). A continuación, se analizan las principales variables:
#
# En primer lugar, se encuentra la variable **Humidity3pm**, donde los valores más altos tienen una incidencia positiva en la probabilidad de lluvia al día siguiente, mientras que los valores más bajos tienen un impacto negativo. Esto sugiere que una mayor humedad en la tarde está asociada con una mayor probabilidad de lluvia al día siguiente.
#
# En segundo lugar, aparece la variable **Sunshine**, donde los valores más altos tienen una incidencia negativa en la probabilidad de lluvia al día siguiente, y los valores más bajos tienen un impacto positivo. Esto es coherente con la expectativa de que días más soleados están asociados con una menor probabilidad de lluvia al día siguiente.
#
# La variable **WindGustSpeed** muestra que los valores más altos tienen una incidencia positiva en la probabilidad de lluvia al día siguiente, mientras que los valores más bajos tienen un impacto negativo. Esto indica que ráfagas de viento más fuertes pueden estar relacionadas con una mayor posibilidad de lluvia.
#
# La variable **Rainfall** tiene un comportamiento similar, donde los valores más altos aumentan la probabilidad de lluvia al día siguiente, mientras que los valores más bajos la disminuyen. Esto es consistente con la idea de que la lluvia actual puede ser un indicador de condiciones meteorológicas que favorecen la lluvia al día siguiente.
#
# La variable **Cloud3pm** también muestra un patrón donde los valores más altos (mayor nubosidad) tienen una incidencia positiva en la probabilidad de lluvia al día siguiente, mientras que los valores más bajos (menor nubosidad) tienen un impacto negativo. Esto sugiere que una mayor nubosidad en la tarde está asociada con una mayor probabilidad de lluvia al día siguiente.
#
# En resumen, las variables más importantes en el modelo están relacionadas con la humedad, el sol, la velocidad del viento, la lluvia y la nubosidad.

# %% [markdown]
# ##### Explicabilidad para Clasificación

# %%
X_train, y_train, X_test, y_test = split(df_train, df_test, 'clasificacion')
feature_names = X_train.columns.values

# Aplicar oversampling
oversampler = RandomOverSampler(random_state=semilla)
X_train, y_train = oversampler.fit_resample(X_train, y_train)

# Reducir la cantidad de muestras para reducir el tiempo de ejecución de SHAP
n_train = int(len(df_train) * 0.02)
n_test = int(len(df_test) * 0.02)
X_train = X_train.sample(n=n_train, random_state=semilla).reset_index(drop=True) # se resetea el índice para que sean consecutivos y comiencen en cero
X_test = X_test.sample(n=n_test, random_state=semilla).reset_index(drop=True)

# Escalar los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convertir los arrays escalados de nuevo a DataFrames de pandas utilizando los nombres de las características
X_train_scaled = pd.DataFrame(X_train_scaled, columns=feature_names)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=feature_names)

# Crear un objeto explainer SHAP usando KernelExplainer
explainer = shap.KernelExplainer(best_model_nn_clas, X_train_scaled.values)

# Calcular los valores SHAP para un conjunto de ejemplos de prueba
shap_values = explainer.shap_values(X_test_scaled.values)
shap_values = np.squeeze(shap_values)
print(shap_values.shape)
# Out:
# WARNING:shap:Using 303 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/53 [00:00<?, ?it/s]
# (53, 22)

# %% [markdown]
# ###### Interpretabilidad local

# %%
index=25
shap_values[index]

rounded_shap_values = np.round(shap_values[index], 3)
rounded_X_test = np.round(X_test_scaled.iloc[index], 3)

# Genera el gráfico de SHAP con valores redondeados
shap.force_plot(explainer.expected_value, rounded_shap_values, rounded_X_test,
                feature_names=feature_names, matplotlib=True, figsize=(18, 4), text_rotation=90)

# %% [markdown]
# Del gráfico de fuerza anterior se puede observar cómo impactan las variables de manera positiva (en rojo) y negativa (en azul).
# Las variables con mayor incidencia son las descritas en el gráfico, para el caso particular del elemento en la posición index.
#
# Resultan más las variables que empujan la predicción hacia la clase 0 (RainTomorrow=False).
#
# Principales variables con incidencia positiva:
# * Sunshine
# * WindGustSpeed
# * Pressure3pm
#
# Principales variables con incidencia negativa:
# * Humidity3pm
# * Humidity9am
# * WindDir3pm_sen
# * Otras
#
# Es importante destacar que la mayoría de las variables obtenidas también son relevantes para el análisis local en el modelo de regresión.

# %%
explanation = shap.Explanation(values=shap_values[index], base_values=explainer.expected_value, feature_names=feature_names)
shap.plots.bar(explanation, max_display=20)

# %% [markdown]
# La gráfica anterior permite observar con más detalle lo expuesto previamente.

# %% [markdown]
# ###### Interpretabilidad global

# %%
explanation = shap.Explanation(values=shap_values, base_values=explainer.expected_value, feature_names=feature_names, data=X_test)
print('Gráfico de valores SHAP')
shap.plots.bar(explanation, max_display=30)
# Out:
# Gráfico de valores SHAP

# %% [markdown]
# A continuación, se presentan las conclusiones clave:
#
# 1. **Humidity3pm** es la variable más importante, con un valor de +0.11. Esto indica que la humedad en la tarde tiene un impacto significativo en la predicción del modelo, sugiriendo que niveles más altos de humedad están asociados con una mayor probabilidad de lluvia al día siguiente.
#
# 2. **Sunshine** también es una variable importante, con un valor de +0.1.
#
# 3. **WindGustSpeed** tiene un valor de +0.09, lo que indica que la velocidad de las ráfagas de viento es un factor relevante.
#
# Las variables más importantes para el modelo son **Humidity3pm**, **Sunshine**, y **WindGustSpeed**. Estas variables están relacionadas con condiciones meteorológicas que influyen en la probabilidad de lluvia al día siguiente.

# %% [markdown]
# #### Explicabilidad del modelo: Conclusiones

# %% [markdown]
# En cuanto al análisis global, son lógicas las incidencias de las variables de mayor peso en las variables target. Por ejemplo, es razonable suponer que valores mayores de Sunshine impactan negativamente en la probabilidad de que llueva al día siguiente.
#
# Por otro lado se observa que las variables de mayor peso para predecir las variables target son las mismas para el modelo de regresión y clasificación.
# * Humidity3pm
# * Sunshine
# * WindGustSpeed

# %% [markdown]
# ### Comparación de modelos

# %% [markdown]
# #### Regresión

# %%
# Crear el DataFrame con los modelos y sus métricas
df_comparacion_reg = df_comparacion_reg.copy()
df_comparacion_reg.loc[len(df_comparacion_reg)] = ['Redes Neuronales', rmse_nn_train, np.nan, rmse_nn_test, R2_nn_train, np.nan, R2_nn_test]
df_comparacion_reg
# Out:
#              Modelo  Train RMSE  Val RMSE  Test RMSE  Train R2    Val R2  \
# 0               OLS    6.010412  6.005909   6.193535  0.207940  0.236659
# 1                GD    6.011354  6.010504   6.195455  0.207692  0.235491
# 2               SGD    6.011354  6.010504   6.195455  0.207692  0.235491
# 3              GDMB    6.012450  6.012347   6.203139  0.207403  0.235022
# 4             Ridge    6.007773       NaN   6.187358  0.213638       NaN
# 5             Lasso    6.008794       NaN   6.190489  0.213371       NaN
# 6       Elastic-net    6.007772       NaN   6.187378  0.213638       NaN
# 7  Redes Neuronales    5.523445       NaN   5.863324  0.335316       NaN
#
#     Test R2
# 0  0.195554
# 1  0.195055
# 2  0.195055
# 3  0.193057
# 4  0.197158
# 5  0.196345
# 6  0.197152
# 7  0.279046

# %% [markdown]
# En la tabla anterior se resumen todos los modelos desarrollados para el problema de regresión. RMSE tiene la ventaja de ser un valor fácilmente interpretable al tratarse de mm de lluvia. La métrica R2 también es sencilla de analizar, ya que su variación es de 0 a 1, siendo R2=1 el valor para un modelo con una capacidad perfecta de predicción.
#
# En este análisis interesa particularmente el valor de test R2. Se puede observar que el modelo de redes logra capturar más variabilidad, pero aún así no alcanza una calidad aceptable de predicción (R2>0.6 por ejemplo). Hay que considerar también que se trata de una solución que agrega considerable complejidad.

# %% [markdown]
# #### Clasificación

# %%
# Crear el DataFrame con los modelos y sus métricas
df_comparacion_clas = df_comparacion_logreg.copy()
df_comparacion_clas.loc[len(df_comparacion_clas)] = ['Redes Neuronales', best_threshold, tpr_nn]
df_comparacion_clas
# Out:
#                    Modelo    Umbral       TPR
# 0       LogReg_Balanceado  0.500000     0.759
# 1         LogReg_OverSamp  0.500000     0.759
# 2  LogReg_OverSamp_Umbral  0.443015       0.8
# 3        Redes Neuronales  0.400000  0.830696

# %% [markdown]
# En la tabla anterior se resumen todos los modelos desarrollados para la resolución del problema de clasificación.
#
# El enfoque adoptado ha sido el de maximizar TPR (recall), es decir, maximizar la detección de verdaderos positivos (días de lluvia). Teniendo esto en consideración, el modelo de Redes Neuronales resulta el mejor, aunque por poco margen.

# %% [markdown]
# ### **MLOps (falta implementación)**

# %% [markdown]
# ### Conclusiones finales

# %% [markdown]
# En este trabajo práctico, se desarrollaron una serie de modelos para la predicción de lluvia en Australia, empleando técnicas de Machine Learning y Deep Learning. A lo largo del proyecto, se llevó a cabo un análisis exhaustivo de los datos, se implementaron modelos de regresión y clasificación, y se optimizaron hiperparámetros con el objetivo de mejorar la precisión de las predicciones. Para ello, se utilizaron herramientas como scikit-learn y TensorFlow para el entrenamiento de redes neuronales.
#
# Durante el desarrollo, se buscó mejorar la performance de los modelos mediante la evaluación de diversas métricas, según el problema en cuestión. Además, se aplicaron técnicas de optimización y validación cruzada para ajustar los modelos, evitando el sobreajuste y buscando mejorar su capacidad predictiva. Sin embargo, a pesar de estos esfuerzos, no se logró alcanzar un modelo con un rendimiento satisfactorio, lo que sugiere que podrían requerirse enfoques más avanzados, como algoritmos basados en árboles y ensambles, como por ejemplo RandomForest, XGBoost o LGBM. A su vez, se hubiese podido continuar la exploración con redes neuronales de haber contado con más tiempo.
#
# Aunque los resultados no fueron los esperados, el proceso permitió identificar áreas de mejora y reforzar la comprensión de los desafíos asociados a la predicción meteorológica, sentando las bases para futuras iteraciones y mejoras.
